# %% [markdown]
# # Assignment 2b Notebook: Automated Design of AI Agents with Genetic Programming
# This notebook will guide you through the process of implementing genetic programming (GP). This assignment will utilize components you implemented previously during Assignment Series 1, as well as the parse trees you implemented during Assignment 2a. From your previous assignments, copy over the most recent versions of the following files:
# * `base_evolution.py`
# * `selection.py`
# * `tree_genotype.py`
#
# **If you implemented your parse trees in a separate file, copy that file over as well.** In addition, you will need to import this file in the following code cell.
#
# As usual, be careful not to overwrite any of the other provided files, as we may have modified them between assignments. Make sure you are in the `EC-env` environment. If you are not, terminate the notebook server, run `conda activate EC-env`, and restart the notebook server.
#
# To begin the assignment, execute the following cell.

# %%
# Configure this notebook to automatically reload modules as they're modified
# https://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# !pip install snake-eyes-parser
# !pip install pytest

import warnings
warnings.filterwarnings('ignore') # hopefully stop any pedantic warnings

import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (12.0, 12.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'

import os
import statistics
from scipy import stats
from snake_eyes import read_config
from fitness import play_GPac
from tree_genotype import *
from selection import *
from gpac_population_evaluation import *
from genetic_programming import *
from base_evolution import *

print('The first cell has been executed!')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Requirement already satisfied: snake-eyes-parser in /home/jordyn/anaconda3/envs/EC-env/lib/python3.11/site-packages (0.1.0)
# Requirement already satisfied: pytest in /home/jordyn/anaconda3/envs/EC-env/lib/python3.11/site-packages (7.4.2)
# Requirement already satisfied: iniconfig in /home/jordyn/anaconda3/envs/EC-env/lib/python3.11/site-packages (from pytest) (2.0.0)
# Requirement already satisfied: packaging in /home/jordyn/anaconda3/envs/EC-env/lib/python3.11/site-packages (from pytest) (23.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /home/jordyn/anaconda3/envs/EC-env/lib/python3.11/site-packages (from pytest) (1.3.0)
# The first cell has been executed!

# %% [markdown]
# ## Recombination
# Assuming you've correctly implemented population initialization in Assignment 2a, we'll begin this assignment by implementing recombination with subtree crossover. Like Assignment Series 1, your recombination method should take a mate as input and recombine the `genes` members of `self` and `mate`, assign the recombined tree to the `genes` member variable of `child`, and then return `child`.
#
# Recall that this assignment series involves a configurable maximum depth, specified in the config files, and this applies to children produced with recombination and mutation. How you do this is up to you, but you must guarantee that the children your algorithms produce do not go beyond the configured max depth.
#
# How you implement subtree crossover in practice depends on your implementation of the parse tree genotype and is thus open-ended. Implement the `TreeGenotype.recombine` function in `tree_genotype.py`, then test your implementation by executing the following cell. This cell will use the same tree checker as Assignment 2a to verify that your trees are structurally correct.

# %%
config = read_config('configs/2b_green_config.txt', globals(), locals())

# Initialize a population of 100 individuals.
population = TreeGenotype.initialization(100, **config['problem'])
# Perform recombination to make 50 children.
children = list()
for idx in range(0, len(population), 2):
    child = population[idx].recombine(population[idx+1], **config['problem'])
    children.append(child)

# Save the child trees to files.
os.makedirs('tree_tests/', exist_ok=True)
for idx, individual in enumerate(children):
    with open(f'tree_tests/tree{idx}r.txt', 'w') as f:
        f.write(individual.to_string())

# !python tree_check.py tree_tests/tree*r.txt

del config, population, children
# Out:
# tree_tests/tree0r.txt: PASS
# tree_tests/tree10r.txt: PASS
# tree_tests/tree11r.txt: PASS
# tree_tests/tree12r.txt: PASS
# tree_tests/tree13r.txt: PASS
# tree_tests/tree14r.txt: PASS
# tree_tests/tree15r.txt: PASS
# tree_tests/tree16r.txt: PASS
# tree_tests/tree17r.txt: PASS
# tree_tests/tree18r.txt: PASS
# tree_tests/tree19r.txt: PASS
# tree_tests/tree1r.txt: PASS
# tree_tests/tree20r.txt: PASS
# tree_tests/tree21r.txt: PASS
# tree_tests/tree22r.txt: PASS
# tree_tests/tree23r.txt: PASS
# tree_tests/tree24r.txt: PASS
# tree_tests/tree25r.txt: PASS
# tree_tests/tree26r.txt: PASS
# tree_tests/tree27r.txt: PASS
# tree_tests/tree28r.txt: PASS
# tree_tests/tree29r.txt: PASS
# tree_tests/tree2r.txt: PASS
# tree_tests/tree30r.txt: PASS
# tree_tests/tree31r.txt: PASS
# tree_tests/tree32r.txt: PASS
# tree_tests/tree33r.txt: PASS
# tree_tests/tree34r.txt: PASS
# tree_tests/tree35r.txt: PASS
# tree_tests/tree36r.txt: PASS
# tree_tests/tree37r.txt: PASS
# tree_tests/tree38r.txt: PASS
# tree_tests/tree39r.txt: PASS
# tree_tests/tree3r.txt: PASS
# tree_tests/tree40r.txt: PASS
# tree_tests/tree41r.txt: PASS
# tree_tests/tree42r.txt: PASS
# tree_tests/tree43r.txt: PASS
# tree_tests/tree44r.txt: PASS
# tree_tests/tree45r.txt: PASS
# tree_tests/tree46r.txt: PASS
# tree_tests/tree47r.txt: PASS
# tree_tests/tree48r.txt: PASS
# tree_tests/tree49r.txt: PASS
# tree_tests/tree4r.txt: PASS
# tree_tests/tree5r.txt: PASS
# tree_tests/tree6r.txt: PASS
# tree_tests/tree7r.txt: PASS
# tree_tests/tree8r.txt: PASS
# tree_tests/tree9r.txt: PASS

# %% [markdown]
# ## Mutation
# Using your parse tree genotype, implement mutation in `TreeGenotype.mutate` and test your implementation by executing the next cell. You can use the grow method that you implemented in the previous assignment to grow a new subtree, replacing an existing randomly-selected subtree. This is called *subtree mutation* in GP literature. Note that you should make sure you don't select the root, which would cause you to grow an entirely new tree. And don't forget to enforce max tree depth like in recombination!
#
# You can also implement mutation in a number of other ways. Particularly, *point mutation* is also common in GP literature and is typically regarded as a performant GP mutation method. In context of the trees we're using here, this would be comparable to a random reset for a small number of the primitives in the tree without modifying the tree structure. That is, you could pick some (preferably small) subset of the nodes in a tree, then randomly select a new primitive for each of the selected nodes (but make sure that terminal nodes stay terminal nodes, and nonterminal nodes stay nonterminal nodes).

# %%
config = read_config('configs/2b_green_config.txt', globals(), locals())

# Initialize a population of 50 individuals.
population = TreeGenotype.initialization(50, **config['problem'])

# Perform mutation to make 50 children.
children = list()
for idx in range(len(population)):
    child = population[idx].mutate(**config['problem'])
    children.append(child)

# Save the child trees to files.
os.makedirs('tree_tests/', exist_ok=True)
for idx, individual in enumerate(children):
    with open(f'tree_tests/tree{idx}m.txt', 'w') as f:
        f.write(individual.to_string())

# !python tree_check.py tree_tests/tree*m.txt

del config, population, children
# Out:
# tree_tests/tree0m.txt: PASS
# tree_tests/tree10m.txt: PASS
# tree_tests/tree11m.txt: PASS
# tree_tests/tree12m.txt: PASS
# tree_tests/tree13m.txt: PASS
# tree_tests/tree14m.txt: PASS
# tree_tests/tree15m.txt: PASS
# tree_tests/tree16m.txt: PASS
# tree_tests/tree17m.txt: PASS
# tree_tests/tree18m.txt: PASS
# tree_tests/tree19m.txt: PASS
# tree_tests/tree1m.txt: PASS
# tree_tests/tree20m.txt: PASS
# tree_tests/tree21m.txt: PASS
# tree_tests/tree22m.txt: PASS
# tree_tests/tree23m.txt: PASS
# tree_tests/tree24m.txt: PASS
# tree_tests/tree25m.txt: PASS
# tree_tests/tree26m.txt: PASS
# tree_tests/tree27m.txt: PASS
# tree_tests/tree28m.txt: PASS
# tree_tests/tree29m.txt: PASS
# tree_tests/tree2m.txt: PASS
# tree_tests/tree30m.txt: PASS
# tree_tests/tree31m.txt: PASS
# tree_tests/tree32m.txt: PASS
# tree_tests/tree33m.txt: PASS
# tree_tests/tree34m.txt: PASS
# tree_tests/tree35m.txt: PASS
# tree_tests/tree36m.txt: PASS
# tree_tests/tree37m.txt: PASS
# tree_tests/tree38m.txt: PASS
# tree_tests/tree39m.txt: PASS
# tree_tests/tree3m.txt: PASS
# tree_tests/tree40m.txt: PASS
# tree_tests/tree41m.txt: PASS
# tree_tests/tree42m.txt: PASS
# tree_tests/tree43m.txt: PASS
# tree_tests/tree44m.txt: PASS
# tree_tests/tree45m.txt: PASS
# tree_tests/tree46m.txt: PASS
# tree_tests/tree47m.txt: PASS
# tree_tests/tree48m.txt: PASS
# tree_tests/tree49m.txt: PASS
# tree_tests/tree4m.txt: PASS
# tree_tests/tree5m.txt: PASS
# tree_tests/tree6m.txt: PASS
# tree_tests/tree7m.txt: PASS
# tree_tests/tree8m.txt: PASS
# tree_tests/tree9m.txt: PASS

# %% [markdown]
# ## Implementing Genetic Programming
# By this point, you should have a complete implementation of your genotype and we can turn our attention to implementing the complete GP algorithm.
#
# ### Evaluation and Parsimony Pressure
# Recall from the lecture and videos by Dr. Koza that tree GP, using the recombination and mutation methods we have implemented here, tends to produce larger and larger trees. Therefore, most GP implementations provide some mechanism to discourage this "bloat".
#
# You will implement a parsimony penalty to discourage your GP from producing unnecessarily large trees (in addition to the depth limit you already have). This parsimony pressure mechanism penalizes the fitness of a solution based on its size. We will apply this using a very similar calculation to the penalty function in Assignment 1c, using the size of the tree rather than a number of constraint violations:
#
# `fitness = base_fitness - size * parsimony_coefficient`
#
# Where `base_fitness` is the solution's fitness according to the fitness function, `size` is some measure of the tree's size, `parsimony_coefficient` is from your config file, and `fitness` is the penalized fitness. The two most obvious metrics of tree size are max depth and node count, but you are encouraged to experiment with different metrics.
#
# Just like Assignment 1c, **it is not meaningful to compare penalized fitness with unpenalized fitness**. We require that you use base fitness for your analysis, and penalized fitness for evolution (which will happen automatically if you store this in the `fitness` member variable, just like in Assignment 1c).
#
# In the file `gpac_population_evaluation.py`, implement the `base_population_evaluation` function that performs fitness evaluations on an input population and assigns the `base_fitness`, parsimony-penalized `fitness`, and `log` members to each individual. Then, test your implementation by executing the following cell.

# %%
config = read_config('configs/2b_green_config.txt', globals(), locals())

# Initialize a population.
population = TreeGenotype.initialization(100, **config['problem'])

# Note explicitly initializing to None is unnecessary in general.
# We only do it here to test that you've actually set these values.
for individual in population:
    individual.fitness = None
    individual.base_fitness = None
    individual.log = None
    individual.size = None

# Calling your function to test things out.
base_population_evaluation(population, **config['fitness_kwargs'], **config['game'])

missing = len([True for individual in population if individual.fitness is None])
base_missing = len([True for individual in population if individual.base_fitness is None])
log_missing = len([True for individual in population if individual.log is None])

if missing or base_missing or log_missing:
    print('Some individuals had some members left unassigned.')
    print('Make sure you assign all required members to all individuals, then run this cell again.')
    print('Individuals with unassigned (penalized) fitness:', missing)
    print('Individuals with unassigned base fitness:', base_missing)
    print('Individuals with unassigned log:', log_missing)

else:
    fitnesses = [individual.fitness for individual in population]
    print('Average fitness of population:', statistics.mean(fitnesses))
    print('Best fitness in population:', max(fitnesses))
    base_fitnesses = [individual.base_fitness for individual in population]
    print('Average unpenalized (base) fitness of population:', statistics.mean(base_fitnesses))
    print('Best unpenalized (base) fitness in population:', max(base_fitnesses))

    best_log = max(population, key=lambda ind:ind.base_fitness).log
    game_log_path = 'example_game.txt'
    with open(game_log_path, 'w') as f:
        [f.write(f'{line}\n') for line in best_log]
    print('The log of the most fit individual was written to', game_log_path)
    
    import numpy as np

    # Extract size and fitness into separate lists
    sizes = [individual.size for individual in population]
    fitnesses = [individual.fitness for individual in population]

    # Calculate the Pearson correlation coefficient
    correlation = np.corrcoef(sizes, fitnesses)[0, 1]
    del fitnesses, base_fitnesses, best_log, sizes

# Print the result
print(f"Correlation between size and fitness: {correlation}")

del config, population, missing, base_missing, log_missing, correlation
# Out:
# Some individuals had some members left unassigned.
# Make sure you assign all required members to all individuals, then run this cell again.
# Individuals with unassigned (penalized) fitness: 100
# Individuals with unassigned base fitness: 100
# Individuals with unassigned log: 100
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 53
#      50     del fitnesses, base_fitnesses, best_log, sizes
#      52 # Print the result
# ---> 53 print(f"Correlation between size and fitness: {correlation}")
#      55 del config, population, missing, base_missing, log_missing, correlation
#
# NameError: name 'correlation' is not defined

# %% [markdown]
# ### Child Generation
# With fitness evaluation implemented, you can now implement child generation within the `GeneticProgrammingPopulation` class. This class inherits from the `BaseEvolutionPopulation` class you used in Assignment Series 1, and will use the inherited initialization and survival selection methods without modification. The only method that you need to implement, then, is `generate_children`. This will override the same method in the base class.
#
# Recall that, typically, mutation in GP is mutually exclusive with recombination. That is, mutation in GP is usually used to directly produce children by mutating a copy of the parent. Therefore, you need to implement a GP-specific version of `generate_children` in the `GeneticProgrammingPopulation` class, which will override the version you previously implemented. The implementation should be broadly similar, except that you need to decide whether or not an individual should be mutated (rather than recombined) before recombination occurs, and either do one or the other (but not both).
#
# Once complete, test your implementation using the following cell, which will initialize your EA, as well as making one generation of children.

# %%
config = read_config('configs/2b_green_config.txt', globals(), locals())

# Full initialization of your GP population.
example_ea = GeneticProgrammingPopulation(**config['ea'], **config)

# Evaluate the initial population.
base_population_evaluation(example_ea.population, **config['fitness_kwargs'], **config['game'])
example_ea.evaluations = len(example_ea.population)

# Print statements for tutorialization.
print('Number of fitness evaluations:', example_ea.evaluations)
fitnesses = [individual.fitness for individual in example_ea.population]
print('Average fitness of population:', statistics.mean(fitnesses))
print('Best fitness in population:', max(fitnesses))
base_fitnesses = [individual.base_fitness for individual in example_ea.population]
print('Average unpenalized (base) fitness of population:', statistics.mean(base_fitnesses))
print('Best unpenalized (base) fitness in population:', max(base_fitnesses))

# Make a generation of children.
children = example_ea.generate_children()

# Evaluate the children.
base_population_evaluation(children, **config['fitness_kwargs'], **config['game'])
example_ea.evaluations += len(children)

# Print statements for tutorialization.
print('Number of fitness evaluations:', example_ea.evaluations)
child_fitnesses = [individual.fitness for individual in children]
print('Average fitness of children:', statistics.mean(child_fitnesses))
print('Best fitness in children:', max(child_fitnesses))
base_child_fitnesses = [individual.base_fitness for individual in children]
print('Average unpenalized (base) fitness of children:', statistics.mean(base_child_fitnesses))
print('Best unpenalized (base) fitness in children:', max(base_child_fitnesses))

# Print children trees to files.
os.makedirs('tree_tests/', exist_ok=True)
for idx, individual in enumerate(children):
    with open(f'tree_tests/tree{idx}c.txt', 'w') as f:
        f.write(individual.to_string())

# !python tree_check.py tree_tests/tree*c.txt

del config, example_ea, children, fitnesses, base_fitnesses
# Out:
# Number of fitness evaluations: 400
# Average fitness of population: -40.2408215393134
# Best fitness in population: 40.22421926910299
# Average unpenalized (base) fitness of population: -29.5438715393134
# Best unpenalized (base) fitness in population: 58.06201550387597
# Number of fitness evaluations: 500
# Average fitness of children: -26.317382059800664
# Best fitness in children: 60.98565891472868
# Average unpenalized (base) fitness of children: -20.245382059800665
# Best unpenalized (base) fitness in children: 62.63565891472868
# tree_tests/tree0c.txt: PASS
# tree_tests/tree10c.txt: PASS
# tree_tests/tree11c.txt: PASS
# tree_tests/tree12c.txt: PASS
# tree_tests/tree13c.txt: PASS
# tree_tests/tree14c.txt: PASS
# tree_tests/tree15c.txt: PASS
# tree_tests/tree16c.txt: PASS
# tree_tests/tree17c.txt: PASS
# tree_tests/tree18c.txt: PASS
# tree_tests/tree19c.txt: PASS
# tree_tests/tree1c.txt: PASS
# tree_tests/tree20c.txt: PASS
# tree_tests/tree21c.txt: PASS
# tree_tests/tree22c.txt: PASS
# tree_tests/tree23c.txt: PASS
# tree_tests/tree24c.txt: PASS
# tree_tests/tree25c.txt: PASS
# tree_tests/tree26c.txt: PASS
# tree_tests/tree27c.txt: PASS
# tree_tests/tree28c.txt: PASS
# tree_tests/tree29c.txt: PASS
# tree_tests/tree2c.txt: PASS
# tree_tests/tree30c.txt: PASS
# tree_tests/tree31c.txt: PASS
# tree_tests/tree32c.txt: PASS
# tree_tests/tree33c.txt: PASS
# tree_tests/tree34c.txt: PASS
# tree_tests/tree35c.txt: PASS
# tree_tests/tree36c.txt: PASS
# tree_tests/tree37c.txt: PASS
# tree_tests/tree38c.txt: PASS
# tree_tests/tree39c.txt: PASS
# tree_tests/tree3c.txt: PASS
# tree_tests/tree40c.txt: PASS
# tree_tests/tree41c.txt: PASS
# tree_tests/tree42c.txt: PASS
# tree_tests/tree43c.txt: PASS
# tree_tests/tree44c.txt: PASS
# tree_tests/tree45c.txt: PASS
# tree_tests/tree46c.txt: PASS
# tree_tests/tree47c.txt: PASS
# tree_tests/tree48c.txt: PASS
# tree_tests/tree49c.txt: PASS
# tree_tests/tree4c.txt: PASS
# tree_tests/tree50c.txt: PASS
# tree_tests/tree51c.txt: PASS
# tree_tests/tree52c.txt: PASS
# tree_tests/tree53c.txt: PASS
# tree_tests/tree54c.txt: PASS
# tree_tests/tree55c.txt: PASS
# tree_tests/tree56c.txt: PASS
# tree_tests/tree57c.txt: PASS
# tree_tests/tree58c.txt: PASS
# tree_tests/tree59c.txt: PASS
# tree_tests/tree5c.txt: PASS
# tree_tests/tree60c.txt: PASS
# tree_tests/tree61c.txt: PASS
# tree_tests/tree62c.txt: PASS
# tree_tests/tree63c.txt: PASS
# tree_tests/tree64c.txt: PASS
# tree_tests/tree65c.txt: PASS
# tree_tests/tree66c.txt: PASS
# tree_tests/tree67c.txt: PASS
# tree_tests/tree68c.txt: PASS
# tree_tests/tree69c.txt: PASS
# tree_tests/tree6c.txt: PASS
# tree_tests/tree70c.txt: PASS
# tree_tests/tree71c.txt: PASS
# tree_tests/tree72c.txt: PASS
# tree_tests/tree73c.txt: PASS
# tree_tests/tree74c.txt: PASS
# tree_tests/tree75c.txt: PASS
# tree_tests/tree76c.txt: PASS
# tree_tests/tree77c.txt: PASS
# tree_tests/tree78c.txt: PASS
# tree_tests/tree79c.txt: PASS
# tree_tests/tree7c.txt: PASS
# tree_tests/tree80c.txt: PASS
# tree_tests/tree81c.txt: PASS
# tree_tests/tree82c.txt: PASS
# tree_tests/tree83c.txt: PASS
# tree_tests/tree84c.txt: PASS
# tree_tests/tree85c.txt: PASS
# tree_tests/tree86c.txt: PASS
# tree_tests/tree87c.txt: PASS
# tree_tests/tree88c.txt: PASS
# tree_tests/tree89c.txt: PASS
# tree_tests/tree8c.txt: PASS
# tree_tests/tree90c.txt: PASS
# tree_tests/tree91c.txt: PASS
# tree_tests/tree92c.txt: PASS
# tree_tests/tree93c.txt: PASS
# tree_tests/tree94c.txt: PASS
# tree_tests/tree95c.txt: PASS
# tree_tests/tree96c.txt: PASS
# tree_tests/tree97c.txt: PASS
# tree_tests/tree98c.txt: PASS
# tree_tests/tree99c.txt: PASS
# tree_tests/tree9c.txt: PASS

# %% [markdown]
# ## Single Run Experiment
# At this point, you should have everything you need to implement a full GP search to evolve GPac controllers! Now put all the components together and implement a function to conduct a single full run in the next cell.
#
# **Note**: Just like in Assignment 2a, you should consider that the game logs (now stored in the `TreeGenotype.log` member variable) can consume a large amount of memory. As a result, it may be a good idea to manually remove logs from individuals that you know will not be necessary for analysis (i.e., anyone except the global-best individual). The following code should suffice for the GREEN and YELLOW deliverables, but may not be applicable for some of the RED deliverables:
#
# ```py
# best_individual = None
# for individual in population:
#     if best_individual is None:
#         best_individual = individual
#     elif individual.base_fitness > best_individual.base_fitness:
#         del best_individual.log
#         best_individual = individual
#     elif individual.base_fitness < best_individual.base_fitness:
#         del individual.log
# ```

# %%
def genetic_programming_search(number_evaluations, config_filename):
    # Parse the config and implement your GP search here.
    # Feel free to focus on implementation first and then return for data collection.
    config = read_config(config_filename, globals(), locals())
    print(config)
    ea = GeneticProgrammingPopulation(**config["ea"], **config)
    score_progression = []
    
    # Evaluate the initial population.
    base_population_evaluation(ea.population, **config["fitness_kwargs"], **config["game"])

    ea.evaluations = len(ea.population)

    best_individual = None
    for individual in ea.population:
        if best_individual is None:
            best_individual = individual
        elif individual.base_fitness > best_individual.base_fitness:
            del best_individual.log
            best_individual = individual
        elif individual.base_fitness < best_individual.base_fitness:
            del individual.log
    
    score_progression.append({
        "best_fitness": best_individual.fitness,
        "mean_fitness": statistics.mean(map(lambda x:x.fitness, ea.population)),
        "best_base_fitness": best_individual.base_fitness,
        "mean_base_fitness": statistics.mean(map(lambda x:x.base_fitness, ea.population)),
        "current_eval_count": ea.evaluations
    })

    ea.log.append("Best fitness: " +  str(best_individual.fitness))
    ea.log.append("Best base fitness: " + str(best_individual.base_fitness))
    ea.log.append("Mean fitness: " + str(statistics.mean(map(lambda x:x.fitness, ea.population))))
    ea.log.append("Mean base fitness: " + str(statistics.mean(map(lambda x:x.base_fitness, ea.population))))
    
    ea.survival()
    
    # GENERATIONS
    while ea.evaluations < number_evaluations:
        print(ea.evaluations)
        children = ea.generate_children()
        base_population_evaluation(children, **config["fitness_kwargs"], **config["game"])
        ea.evaluations += len(children)
        ea.population += children
        
        ea.survival()
        
        for individual in children:
            if individual.base_fitness > best_individual.base_fitness:
                del best_individual.log
                best_individual = individual
            elif individual.base_fitness < best_individual.base_fitness:
                del individual.log
        
        score_progression.append({
            "best_fitness": best_individual.fitness,
            "mean_fitness": statistics.mean(map(lambda x:x.fitness, ea.population)),
            "best_base_fitness": best_individual.base_fitness,
            "mean_base_fitness": statistics.mean(map(lambda x:x.base_fitness, ea.population)),
            "current_eval_count": ea.evaluations
        })
        print(score_progression[-1])
        
        ea.log.append("Best fitness: " + str(best_individual.fitness))
        ea.log.append("Best base fitness: " + str(best_individual.base_fitness))
        ea.log.append("Mean fitness: " + str(statistics.mean(map(lambda x:x.fitness, ea.population))))
        ea.log.append("Mean base fitness: " + str(statistics.mean(map(lambda x:x.base_fitness, ea.population))))

    # Return whatever data you wish!
    return {
        "best_individual": best_individual,
        "score_progression": score_progression,
        "log": ea.log
    }

# Calling your function to test things out.
# print(genetic_programming_search(50, "configs/2b_green_config.txt"))

# %% [markdown]
# ## Tuning
# As is the case with all EAs, tuning your GP algorithm is very important for good performance! In this case, it's also a graded component of the Algorithmic section of this assignment. Like Assignment 1b, you are expected to tune your algorithm parameters such that your full GP search outperforms the random search used in Assignment 2a (note that the default parameters are intentionally bad). As was the case with Assignment 1b, hand-tuning your parameters using a couple runs at a time is good enough for this class. While tuning, it can be helpful to ask yourself the following:
#  * How many generations of evolution will occur based on $\mu$ and $\lambda$? Is this enough generations for evolution to find good solutions?
#  * Is premature convergence occuring (e.g., max fitness stops increasing at a mediocre value)?
#  * Is a loss of diversity preventing improvement (e.g., mean and best fitness converge to very similar values)?
#  * Have the problem instance or search space parameters been manipulated in a way that invalidates a comparison with ramped half-and-half (i.e., avoid manipulating the game parameters and tree depth limits)?
#  * Is the parsimony coefficient tuned well? (Note: you'll need to consider this explicitly if attempting the YELLOW deliverable)
#
# Use the following cell to tune your parameters. Make sure to include the changes to your config in your final submission!

# %%
# Feel free to change these values and re-run this cell as much as you'd like
import os
from multiprocessing import Pool

number_runs = 5
number_evaluations = 1000
config_filename = 'configs/2b_green_config.txt'
outputs = []
def parallel_run(i):
    return genetic_programming_search(number_evaluations, config_filename)

# Implement your 10-run experiment here
with Pool(processes = 5) as p:
    outputs = p.map(parallel_run, range(number_runs))
    
    
for (i, output) in enumerate(outputs):
    print('Fitness:', output['best_individual'].fitness)
    print('Base Fitness:', output['best_individual'].base_fitness)
    print('Genes:\n', output['best_individual'].genes)
# Out:
# {'DEFAULT': {}, 'ea': {'mu': 400, 'num_children': 100, 'mutation_rate': 0.2, 'parent_selection': <function fitness_proportionate_selection at 0x7f56481476a0>, 'survival_selection': <function fitness_proportionate_selection at 0x7f56481476a0>, 'individual_class': <class 'tree_genotype.TreeGenotype'>}, 'parent_selection_kwargs': {'k': 1}, 'survival_selection_kwargs': {'k': 1}, 'problem': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'recombination_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'mutation_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'fitness_kwargs': {'parsimony_coefficient': 0.33, 'experiment': 'green'}, 'game': {'game_map': 'map.txt', 'pill_spawn': 'waves', 'pill_density': 0.3333333333333333, 'fruit_prob': 0.013333333333333334, 'fruit_score': 10, 'fruit_spawn': 'corners_spawned', 'time_multiplier': 2.5, 'num_pacs': 1, 'num_ghosts': 3}}{'DEFAULT': {}, 'ea': {'mu': 400, 'num_children': 100, 'mutation_rate': 0.2, 'parent_selection': <function fitness_proportionate_selection at 0x7f56481476a0>, 'survival_selection': <function fitness_proportionate_selection at 0x7f56481476a0>, 'individual_class': <class 'tree_genotype.TreeGenotype'>}, 'parent_selection_kwargs': {'k': 1}, 'survival_selection_kwargs': {'k': 1}, 'problem': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'recombination_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'mutation_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'fitness_kwargs': {'parsimony_coefficient': 0.33, 'experiment': 'green'}, 'game': {'game_map': 'map.txt', 'pill_spawn': 'waves', 'pill_density': 0.3333333333333333, 'fruit_prob': 0.013333333333333334, 'fruit_score': 10, 'fruit_spawn': 'corners_spawned', 'time_multiplier': 2.5, 'num_pacs': 1, 'num_ghosts': 3}}{'DEFAULT': {}, 'ea': {'mu': 400, 'num_children': 100, 'mutation_rate': 0.2, 'parent_selection': <function fitness_proportionate_selection at 0x7f56481476a0>, 'survival_selection': <function fitness_proportionate_selection at 0x7f56481476a0>, 'individual_class': <class 'tree_genotype.TreeGenotype'>}, 'parent_selection_kwargs': {'k': 1}, 'survival_selection_kwargs': {'k': 1}, 'problem': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'recombination_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'mutation_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'fitness_kwargs': {'parsimony_coefficient': 0.33, 'experiment': 'green'}, 'game': {'game_map': 'map.txt', 'pill_spawn': 'waves', 'pill_density': 0.3333333333333333, 'fruit_prob': 0.013333333333333334, 'fruit_score': 10, 'fruit_spawn': 'corners_spawned', 'time_multiplier': 2.5, 'num_pacs': 1, 'num_ghosts': 3}}{'DEFAULT': {}, 'ea': {'mu': 400, 'num_children': 100, 'mutation_rate': 0.2, 'parent_selection': <function fitness_proportionate_selection at 0x7f56481476a0>, 'survival_selection': <function fitness_proportionate_selection at 0x7f56481476a0>, 'individual_class': <class 'tree_genotype.TreeGenotype'>}, 'parent_selection_kwargs': {'k': 1}, 'survival_selection_kwargs': {'k': 1}, 'problem': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'recombination_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'mutation_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'fitness_kwargs': {'parsimony_coefficient': 0.33, 'experiment': 'green ...
#
#
#
#
# 400
# 400
# 400
# 400
# 400
# {'best_fitness': 59.3975968992248, 'mean_fitness': -16.247321207087488, 'best_base_fitness': 60.3875968992248, 'mean_base_fitness': -10.275971207087487, 'current_eval_count': 500}
# 500
# {'best_fitness': 85.67015503875969, 'mean_fitness': -14.578060409745294, 'best_base_fitness': 90.62015503875969, 'mean_base_fitness': -9.580210409745293, 'current_eval_count': 500}
# 500
# {'best_fitness': 57.71682170542635, 'mean_fitness': -15.091653543743078, 'best_base_fitness': 67.28682170542635, 'mean_base_fitness': -9.453603543743078, 'current_eval_count': 500}
# 500
# {'best_fitness': 59.3975968992248, 'mean_fitness': -8.07955553709856, 'best_base_fitness': 60.3875968992248, 'mean_base_fitness': -3.77800553709856, 'current_eval_count': 600}
# 600
# {'best_fitness': 85.67015503875969, 'mean_fitness': -3.5272088593576965, 'best_base_fitness': 90.62015503875969, 'mean_base_fitness': 0.18199114064230343, 'current_eval_count': 600}
# 600
# {'best_fitness': 91.73263565891473, 'mean_fitness': -14.558091140642304, 'best_base_fitness': 110.54263565891473, 'mean_base_fitness': -7.406991140642304, 'current_eval_count': 500}
# 500
# {'best_fitness': 59.3975968992248, 'mean_fitness': -3.924571926910299, 'best_base_fitness': 60.3875968992248, 'mean_base_fitness': -0.24342192691029896, 'current_eval_count': 700}
# 700
# {'best_fitness': 57.71682170542635, 'mean_fitness': -5.358198394241418, 'best_base_fitness': 67.28682170542635, 'mean_base_fitness': -0.017148394241417727, 'current_eval_count': 600}
# 600
# {'best_fitness': 58.599413067552604, 'mean_fitness': -17.79795957918051, 'best_base_fitness': 60.909413067552606, 'mean_base_fitness': -10.29045957918051, 'current_eval_count': 500}
# 500
# {'best_fitness': 85.67015503875969, 'mean_fitness': 6.088749833887043, 'best_base_fitness': 90.62015503875969, 'mean_base_fitness': 9.161049833887043, 'current_eval_count': 700}
# 700
# {'best_fitness': 61.446434108527136, 'mean_fitness': 0.5548706533776302, 'best_base_fitness': 65.73643410852713, 'mean_base_fitness': 4.19147065337763, 'current_eval_count': 800}
# 800
# {'best_fitness': 85.67015503875969, 'mean_fitness': 11.336541472868216, 'best_base_fitness': 90.62015503875969, 'mean_base_fitness': 14.370891472868218, 'current_eval_count': 800}
# 800
# {'best_fitness': 91.73263565891473, 'mean_fitness': -3.88796234772979, 'best_base_fitness': 110.54263565891473, 'mean_base_fitness': 2.21703765227021, 'current_eval_count': 600}
# 600
# {'best_fitness': 65.46875968992248, 'mean_fitness': -0.9734014396456258, 'best_base_fitness': 75.03875968992247, 'mean_base_fitness': 4.158098560354374, 'current_eval_count': 700}
# 700
# {'best_fitness': 85.67015503875969, 'mean_fitness': 15.761486101882614, 'best_base_fitness': 90.62015503875969, 'mean_base_fitness': 18.663836101882612, 'current_eval_count': 900}
# 900
# {'best_fitness': 78.71159468438537, 'mean_fitness': -8.424010409745295, 'best_base_fitness': 84.32159468438537, 'mean_base_fitness': -2.7612104097452934, 'current_eval_count': 600}
# 600
# {'best_fitness': 61.56162790697674, 'mean_fitness': 6.236743023255814, 'best_base_fitness': 66.51162790697674, 'mean_base_fitness': 9.568093023255814, 'current_eval_count': 900}
# 900
# {'best_fitness': 111.94922480620154, 'mean_fitness': 20.526069324473976, 'best_base_fitness': 116.89922480620154, 'mean_base_fitness': 23.317869324473975, 'current_eval_count': 1000}
# {'best_fitness': 65.46875968992248, 'mean_fitness': 4.8439857696567, 'best_base_fitness': 75.03875968992247, 'mean_base_fitness': 9.7329357696567, 'current_eval_count': 800}
# 800
# {'best_fitness': 91.73263565891473, 'mean_fitness': 4.218007530454042, 'best_base_fitness': 110.54263565891473, 'mean_base_fitness': 9.755407530454042, 'current_eval_count': 700}
# 700
# {'best_fitness': 61.56162790697674, 'mean_fitness': 9.713090310077519, 'best_base_fitness': 66.51162790697674, 'mean_base_fitness': 12.80024031007752, 'current_eval_count': 1000}
# {'best_fitness': 78.71159468438537, 'mean_fitness': 3.7883980620155038, 'best_base_fitness': 84.32159468438537, 'mean_base_fitness': 8.093248062015503, 'current_eval_count': 700}
# 700
# {'best_fitness': 65.46875968992248, 'mean_fitness': 8.695539258028793, 'best_base_fitness': 75.03875968992247, 'mean_base_fitness': 12.290889258028793, 'current_eval_count': 900}
# 900
# {'best_fitness': 91.73263565891473, 'mean_fitness': 17.55501683277962, 'best_base_fitness': 110.54263565891473, 'mean_base_fitness': 23.369616832779624, 'current_eval_count': 800}{'best_fitness': 78.71159468438537, 'mean_fitness': 11.742112513842747, 'best_base_fitness': 84.32159468438537, 'mean_base_fitness': 16.084912513842745, 'current_eval_count': 800}
# 800
# 800
# {'best_fitness': 65.46875968992248, 'mean_fitness': 13.452537209302326, 'best_base_fitness': 75.03875968992247, 'mean_base_fitness': 16.953837209302325, 'current_eval_count': 1000}
# {'best_fitness': 91.73263565891473, 'mean_fitness': 29.404772259136212, 'best_base_fitness': 110.54263565891473, 'mean_base_fitness': 35.62032225913621, 'current_eval_count': 900}
# 900
# {'best_fitness': 78.71159468438537, 'mean_fitness': 14.595354872646732, 'best_base_fitness': 84.32159468438537, 'mean_base_fitness': 18.999204872646732, 'current_eval_count': 900}
# 900
# {'best_fitness': 104.65806201550387, 'mean_fitness': 40.54508748615725, 'best_base_fitness': 112.24806201550388, 'mean_base_fitness': 46.41908748615725, 'current_eval_count': 1000}
# {'best_fitness': 78.71159468438537, 'mean_fitness': 19.80934772978959, 'best_base_fitness': 84.32159468438537, 'mean_base_fitness': 24.16534772978959, 'current_eval_count': 1000}
# Fitness: 104.65806201550387
# Base Fitness: 112.24806201550388
# Genes:
#  /
# |+
# ||RAND
# |||4.28
# |||RAND
# ||||W
# ||||RAND
# |||||G
# |||||G
# ||+
# |||P
# |||G
# |+
# ||*
# |||RAND
# ||||/
# |||||F
# |||||G
# ||||G
# |||P
# ||RAND
# |||-4.24
# |||F
#
# Fitness: 65.46875968992248
# Base Fitness: 75.03875968992247
# Genes:
#  +
# |W
# |+
# ||G
# ||*
# |||RAND
# ||||+
# |||||/
# ||||||F
# ||||||P
# |||||*
# ||||||F
# ||||||W
# ||||-
# |||||-
# ||||||P
# ||||||F
# |||||-
# ||||||W
# ||||||G
# |||RAND
# ||||-0.25
# ||||/
# |||||-
# ||||||4.45
# ||||||0.16
# |||||+
# ||||||W
# ||||||P
#
# Fitness: 61.56162790697674
# Base Fitness: 66.51162790697674
# Genes:
#  /
# |RAND
# ||-
# |||G
# |||W
# ||-
# |||W
# |||P
# |-
# ||RAND
# |||4.91
# |||F
# ||/
# |||-1.49
# |||G
#
# Fitness: 111.94922480620154
# Base Fitness: 116.89922480620154
# Genes:
#  -
# |-
# ||-
# |||G
# |||-0.75
# ||*
# |||P
# |||W
# |RAND
# ||/
# |||W
# |||W
# ||+
# |||P
# |||G
#
# Fitness: 78.71159468438537
# Base Fitness: 84.32159468438537
# Genes:
#  +
# |RAND
# ||/
# |||G
# |||P
# ||+
# |||-1.62
# |||/
# ||||G
# ||||3.38
# |-
# ||RAND
# |||W
# |||3.24
# ||-
# |||W
# |||-4.58

# %%
stats_data = []
for (i, output) in enumerate(outputs):
    stats_data.append(output['best_individual'].base_fitness)

print('2b data mean:', statistics.mean(stats_data))
print('2b data stdv:', statistics.stdev(stats_data))

# Reading the data from your 2a experiment
with open('data/2a/green/statistics.txt', 'r') as f:
    random_data = [float(line) for line in f.readlines()]

print('2a data mean:', statistics.mean(random_data))
print('2a data stdv:', statistics.stdev(random_data))

test_result = stats.ttest_ind(random_data, stats_data, equal_var=False)
print('p-value:', test_result.pvalue)
# Out:
# 2b data mean: 91.003853820598
# 2b data stdv: 22.479393721135096
# 2a data mean: 107.03915836101882
# 2a data stdv: 12.97632888106883
# p-value: 0.1957609337902419

# %%
best_individual = None
for output in outputs:
    individual = output['best_individual']
    if best_individual == None:
        best_individual = individual
    elif individual.base_fitness > best_individual.base_fitness:
        best_individual = individual
best_log = best_individual.log

game_log_path = 'data/2b/green/'
with open(game_log_path + 'best_individual_genes.txt', 'w') as f:
    f.write(best_individual.to_string())
    
with open(game_log_path + 'best_individual_log.txt', 'w') as f:
    [f.write(f'{line}\n') for line in best_log]

print('The log of the most fit individual was written to', game_log_path)
# Out:
# The log of the most fit individual was written to data/2b/green/

# %% [markdown]
# ## Multi-Run Experiments
# Implement a full 10-run experiment with 5,000 fitness evaluations per run. For each generation, including the initial population, log the average and best fitness and base fitness of the current population (so, 4 values in total) along with the evaluation count. For each run, log the global best base fitness encountered for statistical analysis. For the individual with the global best base fitness from each run, log the parse tree and game log for later analysis.

# %%
number_runs = 10
number_evaluations = 5000
config_filename = 'configs/2b_green_config.txt'

def parallel_run(i):
    return genetic_programming_search(number_evaluations, config_filename)

# Implement your 10-run experiment here
outputs = []
with Pool(processes = 10) as p:
    outputs = p.map(parallel_run, range(number_runs))

for (i, output) in enumerate(outputs):
    print('Fitness:', output['best_individual'].fitness)
    print('Base Fitness:', output['best_individual'].base_fitness)
    print('Genes:\n', output['best_individual'].genes)

# Assign your EA's log member variables here
# It should be a list containing the log from the EA in each run
run_logs = []
for (i, output) in enumerate(outputs):
    run_logs.append(output['log'])

# Writing the logs to files
os.makedirs('data/2b/green/logs/', exist_ok=True)
for i in range(len(run_logs)):
    with open('data/2b/green/logs/' + str(i+1) + '.txt', 'w') as f:
        f.write(''.join([entry + '\n' for entry in run_logs[i]]))
        
# Assign your data for statistical analysis to this variable
# It should be a list of the highest fitness values seen per run
stats_data = []
for (i, output) in enumerate(outputs):
    stats_data.append(output['best_individual'].base_fitness)

# Writing your statistical data to a file
with open('data/2b/green/statistics.txt', 'w') as f:
    for result in stats_data:
        f.write(str(result) + '\n')

with open('data/2b/green/stairstep_data.txt', 'w') as f:
    progressions = []
    for output in outputs:
        progressions.append(output['score_progression'])
    f.write(str(progressions))
    
best_individual = None
for output in outputs:
    individual = output['best_individual']
    if best_individual == None:
        best_individual = individual
    elif individual.base_fitness > best_individual.base_fitness:
        best_individual = individual
best_log = best_individual.log

game_log_path = 'data/2b/green/'
with open(game_log_path + 'best_individual_genes.txt', 'w') as f:
    f.write(best_individual.to_string())
    
with open(game_log_path + 'best_individual_log.txt', 'w') as f:
    [f.write(f'{line}\n') for line in best_log]

print('The log of the most fit individual was written to', game_log_path)
# Out:
# {'DEFAULT': {}, 'ea': {'mu': 400, 'num_children': 100, 'mutation_rate': 0.2, 'parent_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'survival_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'individual_class': <class 'tree_genotype.TreeGenotype'>}, 'parent_selection_kwargs': {'k': 1}, 'survival_selection_kwargs': {'k': 1}, 'problem': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'recombination_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'mutation_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'fitness_kwargs': {'parsimony_coefficient': 0.33, 'experiment': 'green'}, 'game': {'game_map': 'map.txt', 'pill_spawn': 'waves', 'pill_density': 0.3333333333333333, 'fruit_prob': 0.013333333333333334, 'fruit_score': 10, 'fruit_spawn': 'corners_spawned', 'time_multiplier': 2.5, 'num_pacs': 1, 'num_ghosts': 3}}{'DEFAULT': {}, 'ea': {'mu': 400, 'num_children': 100, 'mutation_rate': 0.2, 'parent_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'survival_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'individual_class': <class 'tree_genotype.TreeGenotype'>}, 'parent_selection_kwargs': {'k': 1}, 'survival_selection_kwargs': {'k': 1}, 'problem': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'recombination_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'mutation_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'fitness_kwargs': {'parsimony_coefficient': 0.33, 'experiment': 'green'}, 'game': {'game_map': 'map.txt', 'pill_spawn': 'waves', 'pill_density': 0.3333333333333333, 'fruit_prob': 0.013333333333333334, 'fruit_score': 10, 'fruit_spawn': 'corners_spawned', 'time_multiplier': 2.5, 'num_pacs': 1, 'num_ghosts': 3}}{'DEFAULT': {}, 'ea': {'mu': 400, 'num_children': 100, 'mutation_rate': 0.2, 'parent_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'survival_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'individual_class': <class 'tree_genotype.TreeGenotype'>}, 'parent_selection_kwargs': {'k': 1}, 'survival_selection_kwargs': {'k': 1}, 'problem': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'recombination_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'mutation_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'fitness_kwargs': {'parsimony_coefficient': 0.33, 'experiment': 'green'}, 'game': {'game_map': 'map.txt', 'pill_spawn': 'waves', 'pill_density': 0.3333333333333333, 'fruit_prob': 0.013333333333333334, 'fruit_score': 10, 'fruit_spawn': 'corners_spawned', 'time_multiplier': 2.5, 'num_pacs': 1, 'num_ghosts': 3}}{'DEFAULT': {}, 'ea': {'mu': 400, 'num_children': 100, 'mutation_rate': 0.2, 'parent_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'survival_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'individual_class': <class 'tree_genotype.TreeGenotype'>}, 'parent_selection_kwargs': {'k': 1}, 'survival_selection_kwargs': {'k': 1}, 'problem': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'recombination_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'mutation_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'fitness_kwargs': {'parsimony_coefficient': 0.33, 'experiment': 'green ...
# {'DEFAULT': {}, 'ea': {'mu': 400, 'num_children': 100, 'mutation_rate': 0.2, 'parent_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'survival_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'individual_class': <class 'tree_genotype.TreeGenotype'>}, 'parent_selection_kwargs': {'k': 1}, 'survival_selection_kwargs': {'k': 1}, 'problem': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'recombination_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'mutation_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'fitness_kwargs': {'parsimony_coefficient': 0.33, 'experiment': 'green'}, 'game': {'game_map': 'map.txt', 'pill_spawn': 'waves', 'pill_density': 0.3333333333333333, 'fruit_prob': 0.013333333333333334, 'fruit_score': 10, 'fruit_spawn': 'corners_spawned', 'time_multiplier': 2.5, 'num_pacs': 1, 'num_ghosts': 3}}
# {'DEFAULT': {}, 'ea': {'mu': 400, 'num_children': 100, 'mutation_rate': 0.2, 'parent_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'survival_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'individual_class': <class 'tree_genotype.TreeGenotype'>}, 'parent_selection_kwargs': {'k': 1}, 'survival_selection_kwargs': {'k': 1}, 'problem': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'recombination_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'mutation_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'fitness_kwargs': {'parsimony_coefficient': 0.33, 'experiment': 'green'}, 'game': {'game_map': 'map.txt', 'pill_spawn': 'waves', 'pill_density': 0.3333333333333333, 'fruit_prob': 0.013333333333333334, 'fruit_score': 10, 'fruit_spawn': 'corners_spawned', 'time_multiplier': 2.5, 'num_pacs': 1, 'num_ghosts': 3}}
#
#
#
#
#
#
#
# 400
# 400
# 400
# 400
# 400
# 400
# {'best_fitness': 73.18953488372092, 'mean_fitness': -13.662921096345515, 'best_base_fitness': 78.13953488372093, 'mean_base_fitness': -6.955671096345515, 'current_eval_count': 500}
# 500
# 400
# 400
# 400
# {'best_fitness': 46.097596899224804, 'mean_fitness': -19.748781949058692, 'best_base_fitness': 50.3875968992248, 'mean_base_fitness': -15.099081949058693, 'current_eval_count': 500}
# 500
# {'best_fitness': 62.491860465116275, 'mean_fitness': -10.61217015503876, 'best_base_fitness': 67.44186046511628, 'mean_base_fitness': -4.69362015503876, 'current_eval_count': 500}
# 500
# 400
# {'best_fitness': 58.27976744186046, 'mean_fitness': -15.131545902547066, 'best_base_fitness': 79.06976744186046, 'mean_base_fitness': -9.618895902547065, 'current_eval_count': 500}
# 500
# {'best_fitness': 20.80317829457364, 'mean_fitness': -21.38014485049834, 'best_base_fitness': 62.713178294573645, 'mean_base_fitness': -16.06054485049834, 'current_eval_count': 500}
# 500
# {'best_fitness': 56.72937984496123, 'mean_fitness': -19.312479512735326, 'best_base_fitness': 77.51937984496124, 'mean_base_fitness': -12.151479512735326, 'current_eval_count': 500}
# 500
# {'best_fitness': 73.18953488372092, 'mean_fitness': -0.9874189368770768, 'best_base_fitness': 78.13953488372093, 'mean_base_fitness': 4.4806810631229235, 'current_eval_count': 600}
# 600
# {'best_fitness': 81.38054263565891, 'mean_fitness': -11.380929069767442, 'best_base_fitness': 102.17054263565892, 'mean_base_fitness': -6.7262790697674415, 'current_eval_count': 500}
# 500
# {'best_fitness': 83.2923477297896, 'mean_fitness': -11.537402436323367, 'best_base_fitness': 89.5623477297896, 'mean_base_fitness': -5.907602436323367, 'current_eval_count': 500}
# 500
# {'best_fitness': 69.92937984496123, 'mean_fitness': -17.358413178294573, 'best_base_fitness': 77.51937984496124, 'mean_base_fitness': -12.246713178294574, 'current_eval_count': 500}
# 500
# {'best_fitness': 20.80317829457364, 'mean_fitness': -10.066116777408638, 'best_base_fitness': 62.713178294573645, 'mean_base_fitness': -5.9889667774086375, 'current_eval_count': 600}
# 600
# {'best_fitness': 46.097596899224804, 'mean_fitness': -9.895970210409745, 'best_base_fitness': 50.3875968992248, 'mean_base_fitness': -6.500270210409745, 'current_eval_count': 600}
# 600
# {'best_fitness': 85.37132890365449, 'mean_fitness': 5.121442967884828, 'best_base_fitness': 95.60132890365449, 'mean_base_fitness': 10.698442967884828, 'current_eval_count': 700}
# 700
# {'best_fitness': 86.2853488372093, 'mean_fitness': -6.699091915836102, 'best_base_fitness': 88.5953488372093, 'mean_base_fitness': -0.9240919158361021, 'current_eval_count': 600}
# 600
# {'best_fitness': 62.491860465116275, 'mean_fitness': -1.3314710409745294, 'best_base_fitness': 67.44186046511628, 'mean_base_fitness': 3.771978959025471, 'current_eval_count': 600}
# 600
# {'best_fitness': 83.2923477297896, 'mean_fitness': 1.011373754152824, 'best_base_fitness': 89.5623477297896, 'mean_base_fitness': 5.449873754152824, 'current_eval_count': 600}
# 600
# {'best_fitness': 81.38054263565891, 'mean_fitness': -4.210220265780731, 'best_base_fitness': 102.17054263565892, 'mean_base_fitness': 0.3140797342192689, 'current_eval_count': 600}
# 600
# {'best_fitness': 72.23325581395348, 'mean_fitness': -2.9247061461794024, 'best_base_fitness': 93.02325581395348, 'mean_base_fitness': 2.432843853820598, 'current_eval_count': 600}
# 600
# {'best_fitness': 86.2853488372093, 'mean_fitness': 2.822474252491694, 'best_base_fitness': 88.5953488372093, 'mean_base_fitness': 7.483724252491694, 'current_eval_count': 700}
# 700
# {'best_fitness': 76.26109634551496, 'mean_fitness': -4.305179457364342, 'best_base_fitness': 81.87109634551496, 'mean_base_fitness': -1.1718294573643413, 'current_eval_count': 600}
# 600
# {'best_fitness': 20.80317829457364, 'mean_fitness': 0.5735452380952382, 'best_base_fitness': 62.713178294573645, 'mean_base_fitness': 3.819095238095238, 'current_eval_count': 700}
# 700
# {'best_fitness': 79.00782945736434, 'mean_fitness': -17.718526799557033, 'best_base_fitness': 81.31782945736434, 'mean_base_fitness': -9.524626799557032, 'current_eval_count': 500}
# 500
# {'best_fitness': 67.13434108527132, 'mean_fitness': -8.027359025470654, 'best_base_fitness': 77.36434108527132, 'mean_base_fitness': -3.5459590254706534, 'current_eval_count': 700}
# 700
# {'best_fitness': 62.491860465116275, 'mean_fitness': 5.504256533776301, 'best_base_fitness': 67.44186046511628, 'mean_base_fitness': 10.310706533776301, 'current_eval_count': 700}
# 700
# {'best_fitness': 85.37132890365449, 'mean_fitness': 8.38996068660022, 'best_base_fitness': 95.60132890365449, 'mean_base_fitness': 13.851460686600221, 'current_eval_count': 800}
# 800
# {'best_fitness': 83.2923477297896, 'mean_fitness': 5.582164008859358, 'best_base_fitness': 89.5623477297896, 'mean_base_fitness': 9.050464008859358, 'current_eval_count': 700}
# 700
# {'best_fitness': 81.38054263565891, 'mean_fitness': 3.0823169435215942, 'best_base_fitness': 102.17054263565892, 'mean_base_fitness': 6.883916943521594, 'current_eval_count': 700}
# 700
# {'best_fitness': 20.80317829457364, 'mean_fitness': 5.050190642303433, 'best_base_fitness': 62.713178294573645, 'mean_base_fitness': 8.322140642303433, 'current_eval_count': 800}
# 800
# {'best_fitness': 72.23325581395348, 'mean_fitness': 1.846362624584717, 'best_base_fitness': 93.02325581395348, 'mean_base_fitness': 6.844212624584717, 'current_eval_count': 700}
# 700
# {'best_fitness': 76.26109634551496, 'mean_fitness': 5.553864064230343, 'best_base_fitness': 81.87109634551496, 'mean_base_fitness': 7.971114064230343, 'current_eval_count': 700}
# 700
# {'best_fitness': 67.13434108527132, 'mean_fitness': 0.7958821151716499, 'best_base_fitness': 77.36434108527132, 'mean_base_fitness': 3.91603211517165, 'current_eval_count': 800}
# 800
# {'best_fitness': 95.98457364341085, 'mean_fitness': 10.636953156146179, 'best_base_fitness': 98.29457364341086, 'mean_base_fitness': 14.620053156146179, 'current_eval_count': 800}
# 800
# {'best_fitness': 62.491860465116275, 'mean_fitness': 7.452023864894795, 'best_base_fitness': 67.44186046511628, 'mean_base_fitness': 11.034173864894795, 'current_eval_count': 800}
# 800
# {'best_fitness': 85.37132890365449, 'mean_fitness': 10.015552214839424, 'best_base_fitness': 95.60132890365449, 'mean_base_fitness': 15.119002214839425, 'current_eval_count': 900}
# 900
# {'best_fitness': 83.2923477297896, 'mean_fitness': 12.302884053156147, 'best_base_fitness': 89.5623477297896, 'mean_base_fitness': 15.711784053156146, 'current_eval_count': 800}
# 800
# {'best_fitness': 79.00782945736434, 'mean_fitness': -5.981397009966777, 'best_base_fitness': 81.31782945736434, 'mean_base_fitness': -1.7738970099667772, 'current_eval_count': 600}
# 600
# {'best_fitness': 81.38054263565891, 'mean_fitness': 7.864291749723145, 'best_base_fitness': 102.17054263565892, 'mean_base_fitness': 11.806141749723144, 'current_eval_count': 800}
# 800
# {'best_fitness': 67.13434108527132, 'mean_fitness': 6.2662657807308975, 'best_base_fitness': 77.36434108527132, 'mean_base_fitness': 8.972265780730897, 'current_eval_count': 900}
# 900
# {'best_fitness': 20.80317829457364, 'mean_fitness': 7.681793244739756, 'best_base_fitness': 62.713178294573645, 'mean_base_fitness': 10.859693244739757, 'current_eval_count': 900}
# 900
# {'best_fitness': 81.23819490586934, 'mean_fitness': 11.993815946843853, 'best_base_fitness': 84.20819490586933, 'mean_base_fitness': 14.330215946843854, 'current_eval_count': 800}
# 800
# {'best_fitness': 89.90767441860464, 'mean_fitness': 10.313030509413068, 'best_base_fitness': 110.69767441860465, 'mean_base_fitness': 15.182180509413067, 'current_eval_count': 800}
# 800
# {'best_fitness': 92.79976744186047, 'mean_fitness': 19.37442131782946, 'best_base_fitness': 99.06976744186046, 'mean_base_fitness': 22.854271317829458, 'current_eval_count': 900}
# 900
# {'best_fitness': 95.98457364341085, 'mean_fitness': 16.084070099667773, 'best_base_fitness': 98.29457364341086, 'mean_base_fitness': 20.581970099667775, 'current_eval_count': 900}
# 900
# {'best_fitness': 79.00782945736434, 'mean_fitness': 2.8060513842746406, 'best_base_fitness': 81.31782945736434, 'mean_base_fitness': 5.92125138427464, 'current_eval_count': 700}
# 700
# {'best_fitness': 67.13434108527132, 'mean_fitness': 10.423945736434108, 'best_base_fitness': 77.36434108527132, 'mean_base_fitness': 13.129945736434108, 'current_eval_count': 1000}
# 1000
# {'best_fitness': 85.37132890365449, 'mean_fitness': 16.970863953488372, 'best_base_fitness': 95.60132890365449, 'mean_base_fitness': 22.45381395348837, 'current_eval_count': 1000}
# 1000
# {'best_fitness': 62.491860465116275, 'mean_fitness': 11.882736987818383, 'best_base_fitness': 67.44186046511628, 'mean_base_fitness': 15.298236987818383, 'current_eval_count': 900}
# 900
# {'best_fitness': 81.38054263565891, 'mean_fitness': 11.17053588039867, 'best_base_fitness': 102.17054263565892, 'mean_base_fitness': 15.32523588039867, 'current_eval_count': 900}
# 900
# {'best_fitness': 96.06209302325581, 'mean_fitness': 10.432858471760797, 'best_base_fitness': 98.37209302325581, 'mean_base_fitness': 13.574458471760797, 'current_eval_count': 1000}
# 1000
# {'best_fitness': 81.23819490586934, 'mean_fitness': 15.135597563676633, 'best_base_fitness': 84.20819490586933, 'mean_base_fitness': 17.498397563676633, 'current_eval_count': 900}
# 900
# {'best_fitness': 108.69341085271317, 'mean_fitness': 25.518558914728683, 'best_base_fitness': 113.64341085271317, 'mean_base_fitness': 29.105658914728682, 'current_eval_count': 1000}
# 1000
# {'best_fitness': 94.48131782945735, 'mean_fitness': 17.673547674418604, 'best_base_fitness': 115.27131782945736, 'mean_base_fitness': 24.192697674418604, 'current_eval_count': 900}
# 900
# {'best_fitness': 79.00782945736434, 'mean_fitness': 9.035158748615727, 'best_base_fitness': 81.31782945736434, 'mean_base_fitness': 11.884708748615726, 'current_eval_count': 800}
# 800
# {'best_fitness': 95.98457364341085, 'mean_fitness': 21.78544772978959, 'best_base_fitness': 98.29457364341086, 'mean_base_fitness': 26.44834772978959, 'current_eval_count': 1000}
# 1000
# {'best_fitness': 62.491860465116275, 'mean_fitness': 14.359282392026579, 'best_base_fitness': 67.44186046511628, 'mean_base_fitness': 17.395282392026576, 'current_eval_count': 1000}
# 1000
# {'best_fitness': 83.77418604651163, 'mean_fitness': 20.238676245847177, 'best_base_fitness': 86.74418604651163, 'mean_base_fitness': 22.372126245847177, 'current_eval_count': 1000}
# 1000
# {'best_fitness': 67.13434108527132, 'mean_fitness': 16.9233419158361, 'best_base_fitness': 77.36434108527132, 'mean_base_fitness': 19.5550919158361, 'current_eval_count': 1100}
# 1100
# {'best_fitness': 81.38054263565891, 'mean_fitness': 15.609578626799557, 'best_base_fitness': 102.17054263565892, 'mean_base_fitness': 20.081078626799556, 'current_eval_count': 1000}
# 1000
# {'best_fitness': 109.61496124031008, 'mean_fitness': 22.691009523809523, 'best_base_fitness': 119.84496124031008, 'mean_base_fitness': 27.891809523809524, 'current_eval_count': 1100}
# 1100
# {'best_fitness': 96.06209302325581, 'mean_fitness': 12.298389036544851, 'best_base_fitness': 98.37209302325581, 'mean_base_fitness': 15.27828903654485, 'current_eval_count': 1100}
# 1100
# {'best_fitness': 109.77651162790698, 'mean_fitness': 28.686129401993355, 'best_base_fitness': 116.04651162790698, 'mean_base_fitness': 32.54217940199336, 'current_eval_count': 1100}
# 1100
# {'best_fitness': 79.00782945736434, 'mean_fitness': 12.467688815060908, 'best_base_fitness': 81.31782945736434, 'mean_base_fitness': 15.800688815060909, 'current_eval_count': 900}
# 900
# {'best_fitness': 104.54937984496124, 'mean_fitness': 23.82150581395349, 'best_base_fitness': 107.51937984496124, 'mean_base_fitness': 25.826255813953487, 'current_eval_count': 1100}
# 1100
# {'best_fitness': 95.98457364341085, 'mean_fitness': 23.639793964562568, 'best_base_fitness': 98.29457364341086, 'mean_base_fitness': 29.08314396456257, 'current_eval_count': 1100}
# 1100
# {'best_fitness': 67.13434108527132, 'mean_fitness': 20.94473864894795, 'best_base_fitness': 77.36434108527132, 'mean_base_fitness': 23.88173864894795, 'current_eval_count': 1200}
# 1200
# {'best_fitness': 62.491860465116275, 'mean_fitness': 18.24748676633444, 'best_base_fitness': 67.44186046511628, 'mean_base_fitness': 20.93863676633444, 'current_eval_count': 1100}
# 1100
# {'best_fitness': 96.06209302325581, 'mean_fitness': 15.789886600221484, 'best_base_fitness': 98.37209302325581, 'mean_base_fitness': 18.548686600221483, 'current_eval_count': 1200}
# 1200
# {'best_fitness': 81.38054263565891, 'mean_fitness': 17.97823765227021, 'best_base_fitness': 102.17054263565892, 'mean_base_fitness': 22.81603765227021, 'current_eval_count': 1100}
# 1100
# {'best_fitness': 94.48131782945735, 'mean_fitness': 23.796096788482835, 'best_base_fitness': 115.27131782945736, 'mean_base_fitness': 32.323296788482835, 'current_eval_count': 1000}
# 1000
# {'best_fitness': 104.54937984496124, 'mean_fitness': 24.28828815060908, 'best_base_fitness': 107.51937984496124, 'mean_base_fitness': 26.30788815060908, 'current_eval_count': 1200}
# 1200
# {'best_fitness': 79.00782945736434, 'mean_fitness': 13.941682668881507, 'best_base_fitness': 81.31782945736434, 'mean_base_fitness': 17.025532668881507, 'current_eval_count': 1000}
# 1000
# {'best_fitness': 109.61496124031008, 'mean_fitness': 27.906187320044296, 'best_base_fitness': 119.84496124031008, 'mean_base_fitness': 33.9171373200443, 'current_eval_count': 1200}
# 1200
# {'best_fitness': 109.77651162790698, 'mean_fitness': 32.528693244739756, 'best_base_fitness': 116.04651162790698, 'mean_base_fitness': 36.38969324473976, 'current_eval_count': 1200}
# 1200
# {'best_fitness': 82.45418604651162, 'mean_fitness': 21.479707253599116, 'best_base_fitness': 86.74418604651163, 'mean_base_fitness': 23.646157253599114, 'current_eval_count': 1200}
# 1200
# {'best_fitness': 67.13434108527132, 'mean_fitness': 21.099902823920267, 'best_base_fitness': 77.36434108527132, 'mean_base_fitness': 24.309152823920265, 'current_eval_count': 1300}
# 1300
# {'best_fitness': 81.38054263565891, 'mean_fitness': 24.113616168327795, 'best_base_fitness': 102.17054263565892, 'mean_base_fitness': 29.010816168327796, 'current_eval_count': 1200}
# 1200
# {'best_fitness': 96.06209302325581, 'mean_fitness': 19.369852048726468, 'best_base_fitness': 98.37209302325581, 'mean_base_fitness': 21.396052048726467, 'current_eval_count': 1300}
# 1300
# {'best_fitness': 104.54937984496124, 'mean_fitness': 31.599117165005538, 'best_base_fitness': 107.51937984496124, 'mean_base_fitness': 33.47351716500554, 'current_eval_count': 1300}
# 1300
# {'best_fitness': 95.98457364341085, 'mean_fitness': 25.995929235880396, 'best_base_fitness': 98.29457364341086, 'mean_base_fitness': 32.071229235880395, 'current_eval_count': 1200}
# 1200
# {'best_fitness': 82.45418604651162, 'mean_fitness': 22.5902853820598, 'best_base_fitness': 86.74418604651163, 'mean_base_fitness': 24.5933853820598, 'current_eval_count': 1300}
# 1300
# {'best_fitness': 79.00782945736434, 'mean_fitness': 18.43399523809524, 'best_base_fitness': 81.31782945736434, 'mean_base_fitness': 21.75709523809524, 'current_eval_count': 1100}
# 1100
# {'best_fitness': 109.77651162790698, 'mean_fitness': 36.30041090808417, 'best_base_fitness': 116.04651162790698, 'mean_base_fitness': 40.52606090808416, 'current_eval_count': 1300}
# 1300
# {'best_fitness': 67.13434108527132, 'mean_fitness': 24.752458028792912, 'best_base_fitness': 77.36434108527132, 'mean_base_fitness': 28.468258028792913, 'current_eval_count': 1400}
# 1400
# {'best_fitness': 81.38054263565891, 'mean_fitness': 26.857822369878182, 'best_base_fitness': 102.17054263565892, 'mean_base_fitness': 32.09162236987818, 'current_eval_count': 1300}
# 1300
# {'best_fitness': 96.06209302325581, 'mean_fitness': 18.726409413067554, 'best_base_fitness': 98.37209302325581, 'mean_base_fitness': 21.092509413067553, 'current_eval_count': 1400}
# 1400
# {'best_fitness': 109.61496124031008, 'mean_fitness': 30.952667441860463, 'best_base_fitness': 119.84496124031008, 'mean_base_fitness': 36.35476744186047, 'current_eval_count': 1300}
# 1300
# {'best_fitness': 94.48131782945735, 'mean_fitness': 29.796744241417496, 'best_base_fitness': 115.27131782945736, 'mean_base_fitness': 39.467394241417495, 'current_eval_count': 1100}
# 1100
# {'best_fitness': 104.54937984496124, 'mean_fitness': 32.864410797342195, 'best_base_fitness': 107.51937984496124, 'mean_base_fitness': 34.80976079734219, 'current_eval_count': 1400}
# 1400
# {'best_fitness': 82.45418604651162, 'mean_fitness': 23.336554872646733, 'best_base_fitness': 86.74418604651163, 'mean_base_fitness': 25.351204872646733, 'current_eval_count': 1400}
# 1400
# {'best_fitness': 79.00782945736434, 'mean_fitness': 18.100963565891472, 'best_base_fitness': 81.31782945736434, 'mean_base_fitness': 21.47026356589147, 'current_eval_count': 1200}
# 1200
# {'best_fitness': 95.98457364341085, 'mean_fitness': 27.031857973421925, 'best_base_fitness': 98.29457364341086, 'mean_base_fitness': 32.105607973421925, 'current_eval_count': 1300}
# 1300
# {'best_fitness': 96.06209302325581, 'mean_fitness': 21.258115337763012, 'best_base_fitness': 98.37209302325581, 'mean_base_fitness': 23.73806533776301, 'current_eval_count': 1500}
# 1500
# {'best_fitness': 81.38054263565891, 'mean_fitness': 28.729649058693244, 'best_base_fitness': 102.17054263565892, 'mean_base_fitness': 34.44194905869325, 'current_eval_count': 1400}
# 1400
# {'best_fitness': 104.54937984496124, 'mean_fitness': 38.986586932447395, 'best_base_fitness': 107.51937984496124, 'mean_base_fitness': 41.1315869324474, 'current_eval_count': 1500}
# 1500
# {'best_fitness': 67.13434108527132, 'mean_fitness': 27.321387984496123, 'best_base_fitness': 77.36434108527132, 'mean_base_fitness': 31.985937984496125, 'current_eval_count': 1500}
# 1500
# {'best_fitness': 88.27031007751938, 'mean_fitness': 24.285727962347732, 'best_base_fitness': 91.24031007751938, 'mean_base_fitness': 26.40927796234773, 'current_eval_count': 1500}
# 1500
# {'best_fitness': 109.77651162790698, 'mean_fitness': 39.560666334440754, 'best_base_fitness': 116.04651162790698, 'mean_base_fitness': 44.137766334440755, 'current_eval_count': 1400}
# 1400
# {'best_fitness': 109.61496124031008, 'mean_fitness': 37.32536057585825, 'best_base_fitness': 119.84496124031008, 'mean_base_fitness': 43.05416057585825, 'current_eval_count': 1400}
# 1400
# {'best_fitness': 95.98457364341085, 'mean_fitness': 34.86416029900332, 'best_base_fitness': 98.29457364341086, 'mean_base_fitness': 40.234910299003324, 'current_eval_count': 1400}
# 1400
# {'best_fitness': 96.06209302325581, 'mean_fitness': 21.779218604651163, 'best_base_fitness': 98.37209302325581, 'mean_base_fitness': 23.739418604651163, 'current_eval_count': 1600}
# 1600
# {'best_fitness': 79.00782945736434, 'mean_fitness': 20.435574750830565, 'best_base_fitness': 81.31782945736434, 'mean_base_fitness': 24.362574750830564, 'current_eval_count': 1300}
# 1300
# {'best_fitness': 99.13248062015504, 'mean_fitness': 30.83479335548173, 'best_base_fitness': 119.92248062015504, 'mean_base_fitness': 37.54699335548173, 'current_eval_count': 1500}
# 1500
# {'best_fitness': 88.27031007751938, 'mean_fitness': 24.401799114064232, 'best_base_fitness': 91.24031007751938, 'mean_base_fitness': 26.59959911406423, 'current_eval_count': 1600}
# 1600
# {'best_fitness': 104.54937984496124, 'mean_fitness': 43.518499058693244, 'best_base_fitness': 107.51937984496124, 'mean_base_fitness': 45.88294905869324, 'current_eval_count': 1600}
# 1600
# {'best_fitness': 67.13434108527132, 'mean_fitness': 25.97396838316722, 'best_base_fitness': 77.36434108527132, 'mean_base_fitness': 30.27881838316722, 'current_eval_count': 1600}
# 1600
# {'best_fitness': 94.48131782945735, 'mean_fitness': 39.751830786267995, 'best_base_fitness': 115.27131782945736, 'mean_base_fitness': 52.232430786268, 'current_eval_count': 1200}
# 1200
# {'best_fitness': 109.77651162790698, 'mean_fitness': 45.47024856035438, 'best_base_fitness': 116.04651162790698, 'mean_base_fitness': 50.204098560354375, 'current_eval_count': 1500}
# 1500
# {'best_fitness': 96.06209302325581, 'mean_fitness': 23.47366827242525, 'best_base_fitness': 98.37209302325581, 'mean_base_fitness': 25.501518272425248, 'current_eval_count': 1700}
# 1700
# {'best_fitness': 88.27031007751938, 'mean_fitness': 24.362418715393133, 'best_base_fitness': 91.24031007751938, 'mean_base_fitness': 26.642718715393134, 'current_eval_count': 1700}
# 1700
# {'best_fitness': 99.13248062015504, 'mean_fitness': 32.7919592469546, 'best_base_fitness': 119.92248062015504, 'mean_base_fitness': 39.134559246954595, 'current_eval_count': 1600}
# 1600
# {'best_fitness': 95.98457364341085, 'mean_fitness': 35.781359302325576, 'best_base_fitness': 98.29457364341086, 'mean_base_fitness': 40.614209302325584, 'current_eval_count': 1500}
# 1500
# {'best_fitness': 79.00782945736434, 'mean_fitness': 21.43332857142857, 'best_base_fitness': 81.31782945736434, 'mean_base_fitness': 25.515428571428572, 'current_eval_count': 1400}
# 1400
# {'best_fitness': 117.72767441860465, 'mean_fitness': 49.45131411960133, 'best_base_fitness': 120.69767441860465, 'mean_base_fitness': 51.94776411960133, 'current_eval_count': 1700}
# 1700
# {'best_fitness': 109.61496124031008, 'mean_fitness': 39.88380249169435, 'best_base_fitness': 119.84496124031008, 'mean_base_fitness': 45.35025249169435, 'current_eval_count': 1500}
# 1500
# {'best_fitness': 67.13434108527132, 'mean_fitness': 27.457610741971205, 'best_base_fitness': 77.36434108527132, 'mean_base_fitness': 32.028110741971204, 'current_eval_count': 1700}
# 1700
# {'best_fitness': 107.31834994462902, 'mean_fitness': 25.111116722037654, 'best_base_fitness': 109.62834994462902, 'mean_base_fitness': 26.939316722037653, 'current_eval_count': 1800}
# 1800
# {'best_fitness': 88.27031007751938, 'mean_fitness': 26.668279069767443, 'best_base_fitness': 91.24031007751938, 'mean_base_fitness': 28.94527906976744, 'current_eval_count': 1800}
# 1800
# {'best_fitness': 109.77651162790698, 'mean_fitness': 50.15064186046512, 'best_base_fitness': 116.04651162790698, 'mean_base_fitness': 54.988441860465116, 'current_eval_count': 1600}
# 1600
# {'best_fitness': 99.13248062015504, 'mean_fitness': 36.93521926910299, 'best_base_fitness': 119.92248062015504, 'mean_base_fitness': 43.63421926910299, 'current_eval_count': 1700}
# 1700
# {'best_fitness': 95.98457364341085, 'mean_fitness': 38.15450465116279, 'best_base_fitness': 98.29457364341086, 'mean_base_fitness': 42.40160465116279, 'current_eval_count': 1600}
# 1600
# {'best_fitness': 79.00782945736434, 'mean_fitness': 24.141170985603544, 'best_base_fitness': 81.31782945736434, 'mean_base_fitness': 28.246370985603544, 'current_eval_count': 1500}
# 1500
# {'best_fitness': 107.31834994462902, 'mean_fitness': 26.09795531561462, 'best_base_fitness': 109.62834994462902, 'mean_base_fitness': 27.93440531561462, 'current_eval_count': 1900}
# 1900
# {'best_fitness': 117.72767441860465, 'mean_fitness': 52.824323864894794, 'best_base_fitness': 120.69767441860465, 'mean_base_fitness': 55.446173864894796, 'current_eval_count': 1800}
# 1800
# {'best_fitness': 67.13434108527132, 'mean_fitness': 26.783513455149503, 'best_base_fitness': 77.36434108527132, 'mean_base_fitness': 31.6889634551495, 'current_eval_count': 1800}
# 1800
# {'best_fitness': 88.27031007751938, 'mean_fitness': 27.442455592469546, 'best_base_fitness': 91.24031007751938, 'mean_base_fitness': 29.600655592469547, 'current_eval_count': 1900}
# 1900
# {'best_fitness': 109.61496124031008, 'mean_fitness': 41.94329617940199, 'best_base_fitness': 119.84496124031008, 'mean_base_fitness': 47.40314617940199, 'current_eval_count': 1600}
# 1600
# {'best_fitness': 94.48131782945735, 'mean_fitness': 45.165048781838316, 'best_base_fitness': 115.27131782945736, 'mean_base_fitness': 58.894698781838315, 'current_eval_count': 1300}
# 1300
# {'best_fitness': 107.31834994462902, 'mean_fitness': 27.839321207087487, 'best_base_fitness': 109.62834994462902, 'mean_base_fitness': 29.754971207087486, 'current_eval_count': 2000}
# 2000
# {'best_fitness': 95.98457364341085, 'mean_fitness': 41.28317469545958, 'best_base_fitness': 98.29457364341086, 'mean_base_fitness': 45.36692469545958, 'current_eval_count': 1700}
# 1700
# {'best_fitness': 99.13248062015504, 'mean_fitness': 36.519846511627904, 'best_base_fitness': 119.92248062015504, 'mean_base_fitness': 43.52904651162791, 'current_eval_count': 1800}
# 1800
# {'best_fitness': 109.77651162790698, 'mean_fitness': 53.702843964562575, 'best_base_fitness': 116.04651162790698, 'mean_base_fitness': 58.95314396456257, 'current_eval_count': 1700}
# 1700
# {'best_fitness': 79.00782945736434, 'mean_fitness': 24.529804429678848, 'best_base_fitness': 81.31782945736434, 'mean_base_fitness': 28.33800442967885, 'current_eval_count': 1600}
# 1600
# {'best_fitness': 117.72767441860465, 'mean_fitness': 59.1288357696567, 'best_base_fitness': 120.69767441860465, 'mean_base_fitness': 61.8579357696567, 'current_eval_count': 1900}
# 1900
# {'best_fitness': 88.27031007751938, 'mean_fitness': 29.32503831672204, 'best_base_fitness': 91.24031007751938, 'mean_base_fitness': 31.423838316722037, 'current_eval_count': 2000}
# 2000
# {'best_fitness': 77.28937984496123, 'mean_fitness': 30.210824141749722, 'best_base_fitness': 87.51937984496124, 'mean_base_fitness': 35.95942414174972, 'current_eval_count': 1900}
# 1900
# {'best_fitness': 119.27806201550388, 'mean_fitness': 31.54073726467331, 'best_base_fitness': 122.24806201550388, 'mean_base_fitness': 33.64448726467331, 'current_eval_count': 2100}
# 2100
# {'best_fitness': 88.27031007751938, 'mean_fitness': 31.66084911406423, 'best_base_fitness': 91.24031007751938, 'mean_base_fitness': 34.02859911406423, 'current_eval_count': 2100}
# 2100
# {'best_fitness': 99.13248062015504, 'mean_fitness': 38.270795404208194, 'best_base_fitness': 119.92248062015504, 'mean_base_fitness': 45.4070454042082, 'current_eval_count': 1900}
# 1900
# {'best_fitness': 95.98457364341085, 'mean_fitness': 40.24098233665559, 'best_base_fitness': 98.29457364341086, 'mean_base_fitness': 44.862632336655594, 'current_eval_count': 1800}
# 1800
# {'best_fitness': 119.27806201550388, 'mean_fitness': 64.04185675526024, 'best_base_fitness': 122.24806201550388, 'mean_base_fitness': 66.90130675526024, 'current_eval_count': 2000}
# 2000
# {'best_fitness': 113.92054263565892, 'mean_fitness': 45.44682779623477, 'best_base_fitness': 122.17054263565892, 'mean_base_fitness': 50.51232779623477, 'current_eval_count': 1700}
# 1700
# {'best_fitness': 79.00782945736434, 'mean_fitness': 26.98059684385382, 'best_base_fitness': 81.31782945736434, 'mean_base_fitness': 31.20294684385382, 'current_eval_count': 1700}
# 1700
# {'best_fitness': 109.77651162790698, 'mean_fitness': 56.40137187153932, 'best_base_fitness': 116.04651162790698, 'mean_base_fitness': 61.60877187153931, 'current_eval_count': 1800}
# 1800
# {'best_fitness': 119.27806201550388, 'mean_fitness': 30.53492242524917, 'best_base_fitness': 122.24806201550388, 'mean_base_fitness': 32.71127242524917, 'current_eval_count': 2200}
# 2200
# {'best_fitness': 77.28937984496123, 'mean_fitness': 33.539067275747506, 'best_base_fitness': 87.51937984496124, 'mean_base_fitness': 40.03181727574751, 'current_eval_count': 2000}
# 2000
# {'best_fitness': 88.27031007751938, 'mean_fitness': 33.66068715393134, 'best_base_fitness': 91.24031007751938, 'mean_base_fitness': 36.21818715393134, 'current_eval_count': 2200}
# 2200
# {'best_fitness': 105.33403100775193, 'mean_fitness': 49.02281328903654, 'best_base_fitness': 126.12403100775194, 'mean_base_fitness': 64.08401328903655, 'current_eval_count': 1400}
# 1400
# {'best_fitness': 119.27806201550388, 'mean_fitness': 67.40250703211517, 'best_base_fitness': 122.24806201550388, 'mean_base_fitness': 70.23555703211517, 'current_eval_count': 2100}
# 2100
# {'best_fitness': 119.27806201550388, 'mean_fitness': 31.790786378737543, 'best_base_fitness': 122.24806201550388, 'mean_base_fitness': 34.170086378737544, 'current_eval_count': 2300}
# 2300
# {'best_fitness': 95.98457364341085, 'mean_fitness': 43.05560160575858, 'best_base_fitness': 98.29457364341086, 'mean_base_fitness': 47.68385160575858, 'current_eval_count': 1900}
# 1900
# {'best_fitness': 114.55883720930233, 'mean_fitness': 40.43105603543743, 'best_base_fitness': 135.34883720930233, 'mean_base_fitness': 49.16285603543743, 'current_eval_count': 2000}
# 2000
# {'best_fitness': 79.00782945736434, 'mean_fitness': 27.878686323366555, 'best_base_fitness': 81.31782945736434, 'mean_base_fitness': 31.995436323366558, 'current_eval_count': 1800}
# 1800
# {'best_fitness': 109.77651162790698, 'mean_fitness': 61.94020819490587, 'best_base_fitness': 116.04651162790698, 'mean_base_fitness': 67.38520819490587, 'current_eval_count': 1900}
# 1900
# {'best_fitness': 88.27031007751938, 'mean_fitness': 32.48090620155039, 'best_base_fitness': 91.24031007751938, 'mean_base_fitness': 35.06480620155039, 'current_eval_count': 2300}
# 2300
# {'best_fitness': 127.68131782945736, 'mean_fitness': 50.90701279069767, 'best_base_fitness': 135.27131782945736, 'mean_base_fitness': 56.337162790697676, 'current_eval_count': 1800}
# 1800
# {'best_fitness': 119.27806201550388, 'mean_fitness': 32.152288704318934, 'best_base_fitness': 122.24806201550388, 'mean_base_fitness': 34.35338870431894, 'current_eval_count': 2400}
# 2400
# {'best_fitness': 119.27806201550388, 'mean_fitness': 69.1274865448505, 'best_base_fitness': 122.24806201550388, 'mean_base_fitness': 72.0100365448505, 'current_eval_count': 2200}
# 2200
# {'best_fitness': 77.28937984496123, 'mean_fitness': 35.09426240310077, 'best_base_fitness': 87.51937984496124, 'mean_base_fitness': 41.79161240310078, 'current_eval_count': 2100}
# 2100
# {'best_fitness': 95.98457364341085, 'mean_fitness': 43.365354928017716, 'best_base_fitness': 98.29457364341086, 'mean_base_fitness': 48.26585492801772, 'current_eval_count': 2000}
# 2000
# {'best_fitness': 114.55883720930233, 'mean_fitness': 42.811694961240306, 'best_base_fitness': 135.34883720930233, 'mean_base_fitness': 51.73984496124031, 'current_eval_count': 2100}
# 2100
# {'best_fitness': 88.27031007751938, 'mean_fitness': 32.981676744186046, 'best_base_fitness': 91.24031007751938, 'mean_base_fitness': 35.492976744186045, 'current_eval_count': 2400}
# 2400
# {'best_fitness': 79.00782945736434, 'mean_fitness': 29.37620603543743, 'best_base_fitness': 81.31782945736434, 'mean_base_fitness': 33.43685603543743, 'current_eval_count': 1900}
# 1900
# {'best_fitness': 109.77651162790698, 'mean_fitness': 63.91431943521595, 'best_base_fitness': 116.04651162790698, 'mean_base_fitness': 69.50616943521595, 'current_eval_count': 2000}
# 2000
# {'best_fitness': 119.27806201550388, 'mean_fitness': 35.026403322259135, 'best_base_fitness': 122.24806201550388, 'mean_base_fitness': 37.112003322259135, 'current_eval_count': 2500}
# 2500
# {'best_fitness': 114.55883720930233, 'mean_fitness': 43.01393161683278, 'best_base_fitness': 135.34883720930233, 'mean_base_fitness': 51.37118161683278, 'current_eval_count': 2200}
# 2200
# {'best_fitness': 119.27806201550388, 'mean_fitness': 71.53008947951274, 'best_base_fitness': 122.24806201550388, 'mean_base_fitness': 74.42748947951273, 'current_eval_count': 2300}
# 2300
# {'best_fitness': 77.28937984496123, 'mean_fitness': 35.13549750830565, 'best_base_fitness': 87.51937984496124, 'mean_base_fitness': 42.106747508305645, 'current_eval_count': 2200}
# 2200
# {'best_fitness': 88.27031007751938, 'mean_fitness': 35.17261334440753, 'best_base_fitness': 91.24031007751938, 'mean_base_fitness': 37.51066334440753, 'current_eval_count': 2500}
# 2500
# {'best_fitness': 127.68131782945736, 'mean_fitness': 53.269749169435215, 'best_base_fitness': 135.27131782945736, 'mean_base_fitness': 58.99524916943521, 'current_eval_count': 1900}
# 1900
# {'best_fitness': 79.62798449612403, 'mean_fitness': 28.169479125138427, 'best_base_fitness': 81.93798449612403, 'mean_base_fitness': 32.513929125138425, 'current_eval_count': 2000}
# 2000
# {'best_fitness': 102.8837984496124, 'mean_fitness': 43.84661782945736, 'best_base_fitness': 105.1937984496124, 'mean_base_fitness': 49.42031782945736, 'current_eval_count': 2100}
# 2100
# {'best_fitness': 117.71183831672204, 'mean_fitness': 64.02980586932448, 'best_base_fitness': 123.98183831672203, 'mean_base_fitness': 69.62990586932447, 'current_eval_count': 2100}
# 2100
# {'best_fitness': 105.33403100775193, 'mean_fitness': 56.97445769656699, 'best_base_fitness': 126.12403100775194, 'mean_base_fitness': 74.144357696567, 'current_eval_count': 1500}
# 1500
# {'best_fitness': 119.27806201550388, 'mean_fitness': 38.012052325581394, 'best_base_fitness': 122.24806201550388, 'mean_base_fitness': 40.2643023255814, 'current_eval_count': 2600}
# 2600
# {'best_fitness': 114.55883720930233, 'mean_fitness': 42.927911351052046, 'best_base_fitness': 135.34883720930233, 'mean_base_fitness': 52.76026135105205, 'current_eval_count': 2300}
# 2300
# {'best_fitness': 88.27031007751938, 'mean_fitness': 33.48924091915836, 'best_base_fitness': 91.24031007751938, 'mean_base_fitness': 35.78439091915836, 'current_eval_count': 2600}
# 2600
# {'best_fitness': 119.27806201550388, 'mean_fitness': 73.11583621262459, 'best_base_fitness': 122.24806201550388, 'mean_base_fitness': 76.02313621262458, 'current_eval_count': 2400}
# 2400
# {'best_fitness': 85.55496124031008, 'mean_fitness': 36.65800359911406, 'best_base_fitness': 89.84496124031008, 'mean_base_fitness': 43.89325359911406, 'current_eval_count': 2300}
# 2300
# {'best_fitness': 119.27806201550388, 'mean_fitness': 40.98995011074197, 'best_base_fitness': 122.24806201550388, 'mean_base_fitness': 43.16630011074197, 'current_eval_count': 2700}
# 2700
# {'best_fitness': 73.38328903654485, 'mean_fitness': 28.31565503875969, 'best_base_fitness': 83.61328903654486, 'mean_base_fitness': 32.78715503875969, 'current_eval_count': 2100}
# 2100
# {'best_fitness': 117.71183831672204, 'mean_fitness': 70.23757635658914, 'best_base_fitness': 123.98183831672203, 'mean_base_fitness': 75.86242635658915, 'current_eval_count': 2200}
# 2200
# {'best_fitness': 102.8837984496124, 'mean_fitness': 45.97260033222591, 'best_base_fitness': 105.1937984496124, 'mean_base_fitness': 51.486900332225915, 'current_eval_count': 2200}
# 2200
# {'best_fitness': 127.68131782945736, 'mean_fitness': 56.296723421926906, 'best_base_fitness': 135.27131782945736, 'mean_base_fitness': 62.07997342192691, 'current_eval_count': 2000}
# 2000
# {'best_fitness': 114.55883720930233, 'mean_fitness': 47.80571854928017, 'best_base_fitness': 135.34883720930233, 'mean_base_fitness': 58.591768549280175, 'current_eval_count': 2400}
# 2400
# {'best_fitness': 94.39434108527132, 'mean_fitness': 33.68055919158361, 'best_base_fitness': 97.36434108527132, 'mean_base_fitness': 36.02190919158361, 'current_eval_count': 2700}
# 2700
# {'best_fitness': 119.27806201550388, 'mean_fitness': 47.36816085271318, 'best_base_fitness': 122.24806201550388, 'mean_base_fitness': 49.52141085271318, 'current_eval_count': 2800}
# 2800
# {'best_fitness': 119.27806201550388, 'mean_fitness': 76.05615121816169, 'best_base_fitness': 122.24806201550388, 'mean_base_fitness': 78.97830121816169, 'current_eval_count': 2500}
# 2500
# {'best_fitness': 73.38328903654485, 'mean_fitness': 29.682942746400887, 'best_base_fitness': 83.61328903654486, 'mean_base_fitness': 34.180842746400884, 'current_eval_count': 2200}
# 2200
# {'best_fitness': 117.71183831672204, 'mean_fitness': 68.83602115171651, 'best_base_fitness': 123.98183831672203, 'mean_base_fitness': 74.7133211517165, 'current_eval_count': 2300}
# 2300
# {'best_fitness': 85.55496124031008, 'mean_fitness': 37.43612358803986, 'best_base_fitness': 89.84496124031008, 'mean_base_fitness': 45.04592358803987, 'current_eval_count': 2400}
# 2400
# {'best_fitness': 94.39434108527132, 'mean_fitness': 34.008724141749724, 'best_base_fitness': 97.36434108527132, 'mean_base_fitness': 36.381424141749726, 'current_eval_count': 2800}
# 2800
# {'best_fitness': 119.27806201550388, 'mean_fitness': 46.665690863787376, 'best_base_fitness': 122.24806201550388, 'mean_base_fitness': 48.904740863787374, 'current_eval_count': 2900}
# 2900
# {'best_fitness': 114.55883720930233, 'mean_fitness': 50.57416738648948, 'best_base_fitness': 135.34883720930233, 'mean_base_fitness': 61.99711738648948, 'current_eval_count': 2500}
# 2500
# {'best_fitness': 102.8837984496124, 'mean_fitness': 45.15623599114064, 'best_base_fitness': 105.1937984496124, 'mean_base_fitness': 50.01053599114064, 'current_eval_count': 2300}
# 2300
# {'best_fitness': 119.27806201550388, 'mean_fitness': 76.5725022702104, 'best_base_fitness': 122.24806201550388, 'mean_base_fitness': 79.52765227021041, 'current_eval_count': 2600}
# 2600
# {'best_fitness': 106.10922480620154, 'mean_fitness': 57.10222115171649, 'best_base_fitness': 126.89922480620154, 'mean_base_fitness': 75.5393211517165, 'current_eval_count': 1600}
# 1600
# {'best_fitness': 127.68131782945736, 'mean_fitness': 61.77343028792912, 'best_base_fitness': 135.27131782945736, 'mean_base_fitness': 67.53358028792913, 'current_eval_count': 2100}
# 2100
# {'best_fitness': 94.39434108527132, 'mean_fitness': 35.500532281284606, 'best_base_fitness': 97.36434108527132, 'mean_base_fitness': 37.83198228128461, 'current_eval_count': 2900}
# 2900
# {'best_fitness': 73.38328903654485, 'mean_fitness': 29.531099944629016, 'best_base_fitness': 83.61328903654486, 'mean_base_fitness': 33.96134994462901, 'current_eval_count': 2300}
# 2300
# {'best_fitness': 117.71183831672204, 'mean_fitness': 71.7828831118494, 'best_base_fitness': 123.98183831672203, 'mean_base_fitness': 77.7707331118494, 'current_eval_count': 2400}
# 2400
# {'best_fitness': 119.27806201550388, 'mean_fitness': 50.3964326688815, 'best_base_fitness': 122.24806201550388, 'mean_base_fitness': 52.729532668881504, 'current_eval_count': 3000}
# 3000
# {'best_fitness': 114.55883720930233, 'mean_fitness': 53.23842868217054, 'best_base_fitness': 135.34883720930233, 'mean_base_fitness': 65.41872868217054, 'current_eval_count': 2600}
# 2600
# {'best_fitness': 126.83728682170542, 'mean_fitness': 78.38034047619048, 'best_base_fitness': 129.14728682170542, 'mean_base_fitness': 81.36519047619048, 'current_eval_count': 2700}
# 2700
# {'best_fitness': 102.8837984496124, 'mean_fitness': 49.71448172757475, 'best_base_fitness': 105.1937984496124, 'mean_base_fitness': 54.49948172757475, 'current_eval_count': 2400}
# 2400
# {'best_fitness': 85.55496124031008, 'mean_fitness': 40.21835830564784, 'best_base_fitness': 89.84496124031008, 'mean_base_fitness': 47.92550830564784, 'current_eval_count': 2500}
# 2500
# {'best_fitness': 94.39434108527132, 'mean_fitness': 37.76159014396456, 'best_base_fitness': 97.36434108527132, 'mean_base_fitness': 40.26629014396456, 'current_eval_count': 3000}
# 3000
# {'best_fitness': 119.27806201550388, 'mean_fitness': 56.4205415282392, 'best_base_fitness': 122.24806201550388, 'mean_base_fitness': 58.829541528239204, 'current_eval_count': 3100}
# 3100
# {'best_fitness': 73.38328903654485, 'mean_fitness': 30.62233565891473, 'best_base_fitness': 83.61328903654486, 'mean_base_fitness': 35.11363565891473, 'current_eval_count': 2400}
# 2400
# {'best_fitness': 117.71183831672204, 'mean_fitness': 73.48402441860465, 'best_base_fitness': 123.98183831672203, 'mean_base_fitness': 79.45867441860466, 'current_eval_count': 2500}
# 2500
# {'best_fitness': 114.55883720930233, 'mean_fitness': 56.320046788482834, 'best_base_fitness': 135.34883720930233, 'mean_base_fitness': 69.85829678848283, 'current_eval_count': 2700}
# 2700
# {'best_fitness': 127.68131782945736, 'mean_fitness': 60.1749465116279, 'best_base_fitness': 135.27131782945736, 'mean_base_fitness': 66.33604651162791, 'current_eval_count': 2200}
# 2200
# {'best_fitness': 102.8837984496124, 'mean_fitness': 50.69079983388704, 'best_base_fitness': 105.1937984496124, 'mean_base_fitness': 55.02204983388704, 'current_eval_count': 2500}
# 2500
# {'best_fitness': 126.83728682170542, 'mean_fitness': 80.20203139534884, 'best_base_fitness': 129.14728682170542, 'mean_base_fitness': 83.28258139534884, 'current_eval_count': 2800}
# 2800
# {'best_fitness': 119.27806201550388, 'mean_fitness': 59.763169545957915, 'best_base_fitness': 122.24806201550388, 'mean_base_fitness': 62.20846954595792, 'current_eval_count': 3200}
# 3200
# {'best_fitness': 94.39434108527132, 'mean_fitness': 37.987425858250276, 'best_base_fitness': 97.36434108527132, 'mean_base_fitness': 40.77757585825027, 'current_eval_count': 3100}
# 3100
# {'best_fitness': 73.38328903654485, 'mean_fitness': 29.86526096345515, 'best_base_fitness': 83.61328903654486, 'mean_base_fitness': 34.47371096345515, 'current_eval_count': 2500}
# 2500
# {'best_fitness': 85.55496124031008, 'mean_fitness': 39.482701052048725, 'best_base_fitness': 89.84496124031008, 'mean_base_fitness': 47.70135105204873, 'current_eval_count': 2600}
# 2600
# {'best_fitness': 117.71183831672204, 'mean_fitness': 73.86560919158362, 'best_base_fitness': 123.98183831672203, 'mean_base_fitness': 79.84190919158361, 'current_eval_count': 2600}
# 2600
# {'best_fitness': 106.10922480620154, 'mean_fitness': 61.06054867109634, 'best_base_fitness': 126.89922480620154, 'mean_base_fitness': 80.18239867109635, 'current_eval_count': 1700}
# 1700
# {'best_fitness': 114.55883720930233, 'mean_fitness': 60.834853211517164, 'best_base_fitness': 135.34883720930233, 'mean_base_fitness': 75.63370321151717, 'current_eval_count': 2800}
# 2800
# {'best_fitness': 102.8837984496124, 'mean_fitness': 55.3445822812846, 'best_base_fitness': 105.1937984496124, 'mean_base_fitness': 59.891982281284605, 'current_eval_count': 2600}
# 2600
# {'best_fitness': 119.27806201550388, 'mean_fitness': 61.240793244739756, 'best_base_fitness': 122.24806201550388, 'mean_base_fitness': 63.626693244739755, 'current_eval_count': 3300}
# 3300
# {'best_fitness': 94.39434108527132, 'mean_fitness': 36.98219573643411, 'best_base_fitness': 97.36434108527132, 'mean_base_fitness': 39.81194573643411, 'current_eval_count': 3200}
# 3200
# {'best_fitness': 126.83728682170542, 'mean_fitness': 79.49954745293466, 'best_base_fitness': 129.14728682170542, 'mean_base_fitness': 82.54709745293466, 'current_eval_count': 2900}
# 2900
# {'best_fitness': 82.52302325581394, 'mean_fitness': 28.743003211517166, 'best_base_fitness': 92.09302325581395, 'mean_base_fitness': 33.755703211517165, 'current_eval_count': 2600}
# 2600
# ...
# 4600
# {'best_fitness': 99.54612403100775, 'mean_fitness': 52.991020708748614, 'best_base_fitness': 104.49612403100775, 'mean_base_fitness': 56.94112070874861, 'current_eval_count': 5000}
# {'best_fitness': 106.10922480620154, 'mean_fitness': 66.237211517165, 'best_base_fitness': 126.89922480620154, 'mean_base_fitness': 86.433211517165, 'current_eval_count': 2400}
# 2400
# {'best_fitness': 124.97248062015505, 'mean_fitness': 79.51545016611296, 'best_base_fitness': 129.92248062015506, 'mean_base_fitness': 82.46895016611296, 'current_eval_count': 4700}
# 4700
# {'best_fitness': 114.55883720930233, 'mean_fitness': 80.33924424141749, 'best_base_fitness': 135.34883720930233, 'mean_base_fitness': 101.0813942414175, 'current_eval_count': 4700}
# 4700
# {'best_fitness': 139.30922480620154, 'mean_fitness': 87.6850253599114, 'best_base_fitness': 146.89922480620154, 'mean_base_fitness': 94.41372535991141, 'current_eval_count': 3300}
# 3300
# {'best_fitness': 137.22054263565894, 'mean_fitness': 103.8372373754153, 'best_base_fitness': 142.17054263565893, 'mean_base_fitness': 109.12878737541529, 'current_eval_count': 4700}
# 4700
# {'best_fitness': 98.23263565891473, 'mean_fitness': 49.78495481727575, 'best_base_fitness': 100.54263565891473, 'mean_base_fitness': 55.89655481727575, 'current_eval_count': 4600}
# 4600
# {'best_fitness': 90.31263565891473, 'mean_fitness': 47.409960354374306, 'best_base_fitness': 100.54263565891473, 'mean_base_fitness': 57.31656035437431, 'current_eval_count': 4000}
# 4000
# {'best_fitness': 124.97248062015505, 'mean_fitness': 81.18997879291251, 'best_base_fitness': 129.92248062015506, 'mean_base_fitness': 84.15502879291252, 'current_eval_count': 4800}
# 4800
# {'best_fitness': 137.22054263565894, 'mean_fitness': 102.84432469545959, 'best_base_fitness': 142.17054263565893, 'mean_base_fitness': 108.13092469545958, 'current_eval_count': 4800}
# 4800
# {'best_fitness': 98.23263565891473, 'mean_fitness': 50.49916356589147, 'best_base_fitness': 100.54263565891473, 'mean_base_fitness': 56.627263565891475, 'current_eval_count': 4700}
# 4700
# {'best_fitness': 114.55883720930233, 'mean_fitness': 80.85579634551495, 'best_base_fitness': 135.34883720930233, 'mean_base_fitness': 101.55009634551496, 'current_eval_count': 4800}
# 4800
# {'best_fitness': 137.22054263565894, 'mean_fitness': 101.70690038759692, 'best_base_fitness': 142.17054263565893, 'mean_base_fitness': 106.9885503875969, 'current_eval_count': 4900}
# 4900
# {'best_fitness': 146.9836434108527, 'mean_fitness': 86.61713277962347, 'best_base_fitness': 154.5736434108527, 'mean_base_fitness': 93.31283277962348, 'current_eval_count': 3400}
# 3400
# {'best_fitness': 124.97248062015505, 'mean_fitness': 84.20953527131783, 'best_base_fitness': 129.92248062015506, 'mean_base_fitness': 87.15808527131783, 'current_eval_count': 4900}
# 4900
# {'best_fitness': 98.23263565891473, 'mean_fitness': 49.323443964562564, 'best_base_fitness': 100.54263565891473, 'mean_base_fitness': 55.68914396456257, 'current_eval_count': 4800}
# 4800
# {'best_fitness': 90.31263565891473, 'mean_fitness': 48.489461074197116, 'best_base_fitness': 100.54263565891473, 'mean_base_fitness': 58.53301107419712, 'current_eval_count': 4100}
# 4100
# {'best_fitness': 114.55883720930233, 'mean_fitness': 82.24658471760797, 'best_base_fitness': 135.34883720930233, 'mean_base_fitness': 103.03658471760798, 'current_eval_count': 4900}
# 4900
# {'best_fitness': 106.10922480620154, 'mean_fitness': 64.6320119047619, 'best_base_fitness': 126.89922480620154, 'mean_base_fitness': 84.8527619047619, 'current_eval_count': 2500}
# 2500
# {'best_fitness': 141.09651162790698, 'mean_fitness': 101.21290177187154, 'best_base_fitness': 146.04651162790697, 'mean_base_fitness': 106.46980177187154, 'current_eval_count': 5000}
# {'best_fitness': 98.23263565891473, 'mean_fitness': 54.17381262458471, 'best_base_fitness': 100.54263565891473, 'mean_base_fitness': 60.206212624584715, 'current_eval_count': 4900}
# 4900
# {'best_fitness': 124.97248062015505, 'mean_fitness': 81.95790559246954, 'best_base_fitness': 129.92248062015506, 'mean_base_fitness': 84.82065559246955, 'current_eval_count': 5000}
# {'best_fitness': 114.55883720930233, 'mean_fitness': 83.18315171650055, 'best_base_fitness': 135.34883720930233, 'mean_base_fitness': 103.97315171650055, 'current_eval_count': 5000}
# {'best_fitness': 90.31263565891473, 'mean_fitness': 47.725306866002214, 'best_base_fitness': 100.54263565891473, 'mean_base_fitness': 57.826606866002216, 'current_eval_count': 4200}
# 4200
# {'best_fitness': 146.9836434108527, 'mean_fitness': 89.51732596899224, 'best_base_fitness': 154.5736434108527, 'mean_base_fitness': 96.35987596899224, 'current_eval_count': 3500}
# 3500
# {'best_fitness': 98.23263565891473, 'mean_fitness': 53.127550609080835, 'best_base_fitness': 100.54263565891473, 'mean_base_fitness': 59.43715060908084, 'current_eval_count': 5000}
# {'best_fitness': 90.31263565891473, 'mean_fitness': 49.74664407530454, 'best_base_fitness': 100.54263565891473, 'mean_base_fitness': 59.89744407530454, 'current_eval_count': 4300}
# 4300
# {'best_fitness': 106.10922480620154, 'mean_fitness': 64.95330476190476, 'best_base_fitness': 126.89922480620154, 'mean_base_fitness': 85.22190476190477, 'current_eval_count': 2600}
# 2600
# {'best_fitness': 146.9836434108527, 'mean_fitness': 90.45903571428572, 'best_base_fitness': 154.5736434108527, 'mean_base_fitness': 97.33128571428571, 'current_eval_count': 3600}
# 3600
# {'best_fitness': 91.35806201550388, 'mean_fitness': 50.4408419158361, 'best_base_fitness': 102.24806201550388, 'mean_base_fitness': 60.5800919158361, 'current_eval_count': 4400}
# 4400
# {'best_fitness': 91.35806201550388, 'mean_fitness': 50.00924750830565, 'best_base_fitness': 102.24806201550388, 'mean_base_fitness': 60.15674750830565, 'current_eval_count': 4500}
# 4500
# {'best_fitness': 146.9836434108527, 'mean_fitness': 96.69505155038759, 'best_base_fitness': 154.5736434108527, 'mean_base_fitness': 103.74220155038759, 'current_eval_count': 3700}
# 3700
# {'best_fitness': 106.10922480620154, 'mean_fitness': 66.87892990033222, 'best_base_fitness': 126.89922480620154, 'mean_base_fitness': 87.09802990033222, 'current_eval_count': 2700}
# 2700
# {'best_fitness': 91.35806201550388, 'mean_fitness': 47.13973377630122, 'best_base_fitness': 102.24806201550388, 'mean_base_fitness': 57.29053377630122, 'current_eval_count': 4600}
# 4600
# {'best_fitness': 147.09883720930233, 'mean_fitness': 93.92834706533776, 'best_base_fitness': 155.34883720930233, 'mean_base_fitness': 101.03654706533776, 'current_eval_count': 3800}
# 3800
# {'best_fitness': 91.35806201550388, 'mean_fitness': 50.70662912513843, 'best_base_fitness': 102.24806201550388, 'mean_base_fitness': 60.84092912513843, 'current_eval_count': 4700}
# 4700
# {'best_fitness': 106.10922480620154, 'mean_fitness': 65.80388466223698, 'best_base_fitness': 126.89922480620154, 'mean_base_fitness': 86.09393466223699, 'current_eval_count': 2800}
# 2800
# {'best_fitness': 147.09883720930233, 'mean_fitness': 96.0774411406423, 'best_base_fitness': 155.34883720930233, 'mean_base_fitness': 103.3159911406423, 'current_eval_count': 3900}
# 3900
# {'best_fitness': 91.35806201550388, 'mean_fitness': 51.97016727574751, 'best_base_fitness': 102.24806201550388, 'mean_base_fitness': 62.06981727574751, 'current_eval_count': 4800}
# 4800
# {'best_fitness': 91.35806201550388, 'mean_fitness': 53.60153300110742, 'best_base_fitness': 102.24806201550388, 'mean_base_fitness': 63.70943300110742, 'current_eval_count': 4900}
# 4900
# {'best_fitness': 106.10922480620154, 'mean_fitness': 66.3524876522702, 'best_base_fitness': 126.89922480620154, 'mean_base_fitness': 86.65903765227021, 'current_eval_count': 2900}
# 2900
# {'best_fitness': 151.6348062015504, 'mean_fitness': 94.70212425249169, 'best_base_fitness': 159.2248062015504, 'mean_base_fitness': 101.8697242524917, 'current_eval_count': 4000}
# 4000
# {'best_fitness': 91.35806201550388, 'mean_fitness': 50.743830011074195, 'best_base_fitness': 102.24806201550388, 'mean_base_fitness': 60.891330011074196, 'current_eval_count': 5000}
# {'best_fitness': 151.6348062015504, 'mean_fitness': 96.97730232558139, 'best_base_fitness': 159.2248062015504, 'mean_base_fitness': 104.2043023255814, 'current_eval_count': 4100}
# 4100
# {'best_fitness': 106.10922480620154, 'mean_fitness': 66.10100476190476, 'best_base_fitness': 126.89922480620154, 'mean_base_fitness': 86.33990476190476, 'current_eval_count': 3000}
# 3000
# {'best_fitness': 151.6348062015504, 'mean_fitness': 99.3115245847176, 'best_base_fitness': 159.2248062015504, 'mean_base_fitness': 106.59462458471761, 'current_eval_count': 4200}
# 4200
# {'best_fitness': 106.10922480620154, 'mean_fitness': 67.55819274640088, 'best_base_fitness': 126.89922480620154, 'mean_base_fitness': 88.05284274640088, 'current_eval_count': 3100}
# 3100
# {'best_fitness': 151.6348062015504, 'mean_fitness': 98.83150553709855, 'best_base_fitness': 159.2248062015504, 'mean_base_fitness': 106.10800553709856, 'current_eval_count': 4300}
# 4300
# {'best_fitness': 106.10922480620154, 'mean_fitness': 66.4975311184939, 'best_base_fitness': 126.89922480620154, 'mean_base_fitness': 87.04333111849391, 'current_eval_count': 3200}
# 3200
# {'best_fitness': 151.6348062015504, 'mean_fitness': 101.77359302325581, 'best_base_fitness': 159.2248062015504, 'mean_base_fitness': 109.11609302325581, 'current_eval_count': 4400}
# 4400
# {'best_fitness': 151.6348062015504, 'mean_fitness': 101.05936461794019, 'best_base_fitness': 159.2248062015504, 'mean_base_fitness': 108.52561461794019, 'current_eval_count': 4500}
# 4500
# {'best_fitness': 106.10922480620154, 'mean_fitness': 65.7663410852713, 'best_base_fitness': 126.89922480620154, 'mean_base_fitness': 86.35834108527132, 'current_eval_count': 3300}
# 3300
# {'best_fitness': 151.6348062015504, 'mean_fitness': 100.07395985603543, 'best_base_fitness': 159.2248062015504, 'mean_base_fitness': 107.49070985603544, 'current_eval_count': 4600}
# 4600
# {'best_fitness': 106.10922480620154, 'mean_fitness': 66.56946356589147, 'best_base_fitness': 126.89922480620154, 'mean_base_fitness': 87.21426356589147, 'current_eval_count': 3400}
# 3400
# {'best_fitness': 151.6348062015504, 'mean_fitness': 99.8341096345515, 'best_base_fitness': 159.2248062015504, 'mean_base_fitness': 107.25910963455149, 'current_eval_count': 4700}
# 4700
# {'best_fitness': 106.10922480620154, 'mean_fitness': 65.98115603543742, 'best_base_fitness': 126.89922480620154, 'mean_base_fitness': 86.66885603543743, 'current_eval_count': 3500}
# 3500
# {'best_fitness': 151.6348062015504, 'mean_fitness': 98.85569435215946, 'best_base_fitness': 159.2248062015504, 'mean_base_fitness': 106.28069435215947, 'current_eval_count': 4800}
# 4800
# {'best_fitness': 151.6348062015504, 'mean_fitness': 101.31848787375415, 'best_base_fitness': 159.2248062015504, 'mean_base_fitness': 108.82763787375416, 'current_eval_count': 4900}
# 4900
# {'best_fitness': 106.10922480620154, 'mean_fitness': 64.11316467331118, 'best_base_fitness': 126.89922480620154, 'mean_base_fitness': 84.79426467331119, 'current_eval_count': 3600}
# 3600
# {'best_fitness': 151.6348062015504, 'mean_fitness': 103.59242713178294, 'best_base_fitness': 159.2248062015504, 'mean_base_fitness': 111.07352713178294, 'current_eval_count': 5000}
# {'best_fitness': 106.10922480620154, 'mean_fitness': 65.78128754152823, 'best_base_fitness': 126.89922480620154, 'mean_base_fitness': 86.46073754152823, 'current_eval_count': 3700}
# 3700
# {'best_fitness': 106.10922480620154, 'mean_fitness': 65.62689850498339, 'best_base_fitness': 126.89922480620154, 'mean_base_fitness': 86.29644850498339, 'current_eval_count': 3800}
# 3800
# {'best_fitness': 125.0957142857143, 'mean_fitness': 66.71065481727574, 'best_base_fitness': 145.8857142857143, 'mean_base_fitness': 87.41155481727574, 'current_eval_count': 3900}
# 3900
# {'best_fitness': 125.0957142857143, 'mean_fitness': 66.30540747508304, 'best_base_fitness': 145.8857142857143, 'mean_base_fitness': 87.02775747508305, 'current_eval_count': 4000}
# 4000
# {'best_fitness': 125.0957142857143, 'mean_fitness': 64.53495276854927, 'best_base_fitness': 145.8857142857143, 'mean_base_fitness': 85.27050276854928, 'current_eval_count': 4100}
# 4100
# {'best_fitness': 125.0957142857143, 'mean_fitness': 64.79353632336655, 'best_base_fitness': 145.8857142857143, 'mean_base_fitness': 85.52743632336656, 'current_eval_count': 4200}
# 4200
# {'best_fitness': 125.0957142857143, 'mean_fitness': 65.37700586932446, 'best_base_fitness': 145.8857142857143, 'mean_base_fitness': 86.11090586932447, 'current_eval_count': 4300}
# 4300
# {'best_fitness': 125.0957142857143, 'mean_fitness': 63.521622037652264, 'best_base_fitness': 145.8857142857143, 'mean_base_fitness': 84.26872203765227, 'current_eval_count': 4400}
# 4400
# {'best_fitness': 125.0957142857143, 'mean_fitness': 65.5233318936877, 'best_base_fitness': 145.8857142857143, 'mean_base_fitness': 86.27043189368771, 'current_eval_count': 4500}
# 4500
# {'best_fitness': 125.0957142857143, 'mean_fitness': 64.85746744186046, 'best_base_fitness': 145.8857142857143, 'mean_base_fitness': 85.61776744186047, 'current_eval_count': 4600}
# 4600
# {'best_fitness': 125.0957142857143, 'mean_fitness': 64.028453820598, 'best_base_fitness': 145.8857142857143, 'mean_base_fitness': 84.811853820598, 'current_eval_count': 4700}
# 4700
# {'best_fitness': 125.0957142857143, 'mean_fitness': 67.01876949058693, 'best_base_fitness': 145.8857142857143, 'mean_base_fitness': 87.80381949058693, 'current_eval_count': 4800}
# 4800
# {'best_fitness': 125.0957142857143, 'mean_fitness': 66.3272945736434, 'best_base_fitness': 145.8857142857143, 'mean_base_fitness': 87.1172945736434, 'current_eval_count': 4900}
# 4900
# {'best_fitness': 125.0957142857143, 'mean_fitness': 66.36476965669988, 'best_base_fitness': 145.8857142857143, 'mean_base_fitness': 87.15476965669988, 'current_eval_count': 5000}
# Fitness: 91.35806201550388
# Base Fitness: 102.24806201550388
# Genes:
#  RAND
# |-
# ||*
# |||/
# ||||G
# ||||G
# |||RAND
# ||||-4.75
# ||||G
# ||/
# |||-
# ||||P
# ||||/
# |||||G
# |||||P
# |||/
# ||||G
# ||||F
# |+
# ||RAND
# |||+
# ||||4.04
# ||||P
# |||-
# ||||-4.75
# ||||P
# ||/
# |||/
# ||||P
# ||||-4.83
# |||+
# ||||-0.76
# ||||G
#
# Fitness: 114.51170542635658
# Base Fitness: 116.82170542635659
# Genes:
#  *
# |RAND
# ||-1.68
# ||P
# |*
# ||-0.6
# ||G
#
# Fitness: 124.97248062015505
# Base Fitness: 129.92248062015506
# Genes:
#  /
# |RAND
# ||G
# ||G
# |RAND
# ||+
# |||P
# |||P
# ||RAND
# |||RAND
# ||||+
# |||||G
# |||||G
# ||||P
# |||F
#
# Fitness: 125.0957142857143
# Base Fitness: 145.8857142857143
# Genes:
#  *
# |/
# ||-
# |||/
# ||||*
# |||||W
# |||||W
# ||||-
# |||||0.26
# |||||G
# |||/
# ||||-
# |||||G
# |||||W
# ||||RAND
# |||||G
# |||||P
# ||/
# |||/
# ||||-
# |||||P
# |||||-0.74
# ||||/
# |||||G
# |||||-3.28
# |||-
# ||||/
# |||||1.8
# |||||P
# ||||/
# |||||-1.66
# |||||W
# |/
# ||-
# |||+
# ||||-
# |||||3.66
# |||||G
# ||||RAND
# |||||F
# |||||4.62
# |||+
# ||||-
# |||||0.55
# |||||G
# ||||/
# |||||F
# |||||G
# ||/
# |||/
# ||||-
# |||||G
# |||||G
# ||||*
# |||||G
# |||||W
# |||*
# ||||/
# |||||G
# |||||-2.31
# ||||RAND
# |||||G
# |||||P
#
# Fitness: 114.55883720930233
# Base Fitness: 135.34883720930233
# Genes:
#  /
# |/
# ||*
# |||*
# ||||*
# |||||F
# |||||G
# ||||/
# |||||P
# |||||G
# |||+
# ||||*
# |||||F
# |||||F
# ||||*
# |||||W
# |||||G
# ||/
# |||*
# ||||*
# |||||0.75
# |||||F
# ||||+
# |||||G
# |||||W
# |||*
# ||||+
# |||||P
# |||||W
# ||||-
# |||||W
# |||||W
# |/
# ||RAND
# |||RAND
# ||||/
# |||||G
# |||||P
# ||||-
# |||||F
# |||||1.05
# |||/
# ||||RAND
# |||||W
# |||||F
# ||||+
# |||||W
# |||||1.31
# ||-
# |||/
# ||||-
# |||||P
# |||||W
# ||||-
# |||||F
# |||||-1.42
# |||+
# ||||+
# |||||G
# |||||W
# ||||/
# |||||-4.43
# |||||-2.54
#
# Fitness: 119.27806201550388
# Base Fitness: 122.24806201550388
# Genes:
#  /
# |+
# ||RAND
# |||G
# |||G
# ||G
# |RAND
# ||2.13
# ||P
#
# Fitness: 98.23263565891473
# Base Fitness: 100.54263565891473
# Genes:
#  -
# |G
# |RAND
# ||G
# ||+
# |||P
# |||-1.14
#
# Fitness: 141.09651162790698
# Base Fitness: 146.04651162790697
# Genes:
#  /
# |RAND
# ||*
# |||W
# |||2.26
# ||+
# |||-0.89
# |||G
# |-
# ||+
# |||F
# |||W
# ||/
# |||F
# |||P
#
# Fitness: 151.6348062015504
# Base Fitness: 159.2248062015504
# Genes:
#  *
# |/
# ||G
# ||+
# |||RAND
# ||||RAND
# |||||+
# ||||||F
# ||||||2.88
# |||||-
# ||||||P
# ||||||P
# ||||P
# |||/
# ||||F
# ||||/
# |||||2.52
# |||||*
# ||||||G
# ||||||P
# |RAND
# ||G
# ||P
#
# Fitness: 99.54612403100775
# Base Fitness: 104.49612403100775
# Genes:
#  RAND
# |/
# ||G
# ||+
# |||G
# |||P
# |-
# ||/
# |||-0.92
# |||-0.76
# ||*
# |||-
# ||||G
# ||||P
# |||-1.59
#
# The log of the most fit individual was written to data/2b/green/

# %% [markdown]
# ## Report
# Now you should have the data required to complete the report described in the assignment document. There are components of the report you need to complete independently, but this notebook will walk you through plotting and statistical analysis.
#
# ### Statistical Analysis
# Statistical analysis should consist of a comparison between global best per-run **base** fitness values of your GP searches with the data you generated during your experiment in Assignment 2a. That data should have been saved in your Assignment 2a repository under `data/2a/green/statistics.txt`. If you have not already done so, copy that file to this assignment's `data` subdirectory. Then you can run the below cell and interpret the results. Recall that we specify $\alpha = 0.05$ for these tests.

# %%
with open('data/2b/green/statistics.txt', 'r') as f:
    gp_data = [float(line) for line in f.readlines()]

print('2b data mean:', statistics.mean(gp_data))
print('2b data stdv:', statistics.stdev(gp_data))

# Reading the data from your 2a experiment
with open('data/2a/green/statistics.txt', 'r') as f:
    random_data = [float(line) for line in f.readlines()]

print('2a data mean:', statistics.mean(random_data))
print('2a data stdv:', statistics.stdev(random_data))

test_result = stats.ttest_ind(random_data, gp_data, equal_var=False)
print('p-value:', test_result.pvalue)
# Out:
# 2b data mean: 126.27849390919158
# 2b data stdv: 20.483515865371682
# 2a data mean: 107.03915836101882
# 2a data stdv: 12.97632888106883
# p-value: 0.023876795879310294

# %% [markdown]
# ### Evals-vs-fitness Plot
# Using the data you've collected from your 10 run experiment, analyze your fitness values to find the mean and maximum fitness and base fitness at each generation averaged over your 10 runs, as you should have done several times now.
#
# Using this data, plot the number of evaluations (not generations) versus the mean and maximum fitness and base fitness averaged over 10 runs. The following cell has code to generate the plot, but you need to calculate and set the x and y values appropriately.

# %%
import json
import re
'''
Store the y-values for mean fitness in average_penalized_means,
and the y-values for best fitness in average_penalized_maxes.
Do similar for average_base_means and average_base_maxes.
x-values should represent the number of **evaluations**, NOT **generations**.
Store the evaluation counts in the evals variable.
'''
def get_means_list(identifier):
    experiments_list_lists = []
    with open(f'data/2b/green/stairstep_data.txt', 'r') as f:
        content = f.readlines()[0]
        content = re.sub(r"(?<!\\)'", '"', content)
        content = json.loads(content)
        for i in range(len(content)):
            current_experiment_list = []
            for n in range(len(content[i])):
                current_experiment_list.append(content[i][n][identifier])
            experiments_list_lists.append(current_experiment_list)
            
        final_list = [0] * len(experiments_list_lists[0])
        for i in range(len(experiments_list_lists[0])):
            for n in range(0, len(content)):
                final_list[i] += experiments_list_lists[n][i]
            final_list[i] = final_list[i] / len(content)

    return final_list
    
average_penalized_means = get_means_list('mean_fitness')
average_penalized_maxes = get_means_list('best_fitness')
average_base_means = get_means_list('mean_base_fitness')
average_base_maxes = get_means_list('best_base_fitness')
evals = [eval['current_eval_count'] for eval in outputs[0]['score_progression']]

fig, ax = plt.subplots()
ax.plot(evals, average_penalized_maxes, 'g-')
ax.plot(evals, average_penalized_means, 'g--')
ax.plot(evals, average_base_maxes, 'b-')
ax.plot(evals, average_base_means, 'b--')
ax.set(xlabel = 'Evaluations', ylabel = 'Fitness',\
       title = '2b Green Experiment: Evaluations vs Population Fitness Averaged Across 10 Runs')
ax.legend(['Max Penalized Fitness', 'Mean Penalized Fitness', 'Max Base Fitness', 'Mean Base Fitness'])
plt.show()

# %% [markdown]
# # YELLOW Deliverable
# Now that you've completed the GREEN deliverable and conducted an experiment with one choice of parsimony metric (most likely max depth or node count), experiment with a different metric and re-tune the parsimony coefficient. You are welcome to reuse the other parameters you used in your GREEN configuration, but some attempt at tuning the parsimony coefficient to account for the new parsimony metric is required. Implement your new parsimony calculation in the `base_population_evaluation` function under the `yellow` section.
#
# Use the following 2 cells to tune and conduct a 10-run experiment, respectively. Add more cells below these for your analysis, if necessary.

# %%
def genetic_programming_search(number_evaluations, config_filename):
    # Parse the config and implement your GP search here.
    # Feel free to focus on implementation first and then return for data collection.
    config = read_config(config_filename, globals(), locals())
    print(config)
    ea = GeneticProgrammingPopulation(**config["ea"], **config)
    score_progression = []
    
    # Evaluate the initial population.
    base_population_evaluation(ea.population, **config["fitness_kwargs"], **config["game"])

    ea.evaluations = len(ea.population)

    best_individual = None
    for individual in ea.population:
        if best_individual is None:
            best_individual = individual
        elif individual.base_fitness > best_individual.base_fitness:
            del best_individual.log
            best_individual = individual
        elif individual.base_fitness < best_individual.base_fitness:
            del individual.log
    
    score_progression.append({
        "best_fitness": best_individual.fitness,
        "mean_fitness": statistics.mean(map(lambda x:x.fitness, ea.population)),
        "best_base_fitness": best_individual.base_fitness,
        "mean_base_fitness": statistics.mean(map(lambda x:x.base_fitness, ea.population)),
        "minimum_size": min(ea.population, key=lambda x: x.size).size,
        "maximum_size": max(ea.population, key=lambda x: x.size).size,
        "mean_size": statistics.mean(map(lambda x:x.size, ea.population)),
        "current_eval_count": ea.evaluations
    })

    ea.log.append("Best fitness: " +  str(best_individual.fitness))
    ea.log.append("Best base fitness: " + str(best_individual.base_fitness))
    ea.log.append("Mean fitness: " + str(statistics.mean(map(lambda x:x.fitness, ea.population))))
    ea.log.append("Mean base fitness: " + str(statistics.mean(map(lambda x:x.base_fitness, ea.population))))
    ea.log.append("Minimum Size: " + str(min(ea.population, key=lambda x: x.size).size))
    ea.log.append("Maximum Size: " + str(max(ea.population, key=lambda x: x.size).size))
    ea.log.append("Mean Size: " + str(statistics.mean(map(lambda x:x.size, ea.population))))
    ea.survival()
    
    # GENERATIONS
    while ea.evaluations < number_evaluations:
        print(ea.evaluations)
        children = ea.generate_children()
        base_population_evaluation(children, **config["fitness_kwargs"], **config["game"])
        ea.evaluations += len(children)
        ea.population += children
        
        ea.survival()
        
        for individual in children:
            if individual.base_fitness > best_individual.base_fitness:
                del best_individual.log
                best_individual = individual
            elif individual.base_fitness < best_individual.base_fitness:
                del individual.log
        
        score_progression.append({
            "best_fitness": best_individual.fitness,
            "mean_fitness": statistics.mean(map(lambda x:x.fitness, ea.population)),
            "best_base_fitness": best_individual.base_fitness,
            "mean_base_fitness": statistics.mean(map(lambda x:x.base_fitness, ea.population)),
            "minimum_size": min(ea.population, key=lambda x: x.size).size,
            "maximum_size": max(ea.population, key=lambda x: x.size).size,
            "mean_size": statistics.mean(map(lambda x:x.size, ea.population)),
            "current_eval_count": ea.evaluations
        })
        print(score_progression[-1])
        
        ea.log.append("Best fitness: " + str(best_individual.fitness))
        ea.log.append("Best base fitness: " + str(best_individual.base_fitness))
        ea.log.append("Mean fitness: " + str(statistics.mean(map(lambda x:x.fitness, ea.population))))
        ea.log.append("Mean base fitness: " + str(statistics.mean(map(lambda x:x.base_fitness, ea.population))))
        ea.log.append("Minimum Size: " + str(min(ea.population, key=lambda x: x.size).size))
        ea.log.append("Maximum Size: " + str(max(ea.population, key=lambda x: x.size).size))
        ea.log.append("Mean Size: " + str(statistics.mean(map(lambda x:x.size, ea.population))))

    # Return whatever data you wish!
    return {
        "best_individual": best_individual,
        "score_progression": score_progression,
        "log": ea.log
    }

# Calling your function to test things out.
# print(genetic_programming_search(50, "configs/2b_green_config.txt"))

# %%
import os
from multiprocessing import Pool

number_runs = 5
number_evaluations = 5000
config_filename = 'configs/2b_yellow_config.txt'
outputs = []
def parallel_run(i):
    return genetic_programming_search(number_evaluations, config_filename)

# Implement your 10-run experiment here
with Pool(processes = 5) as p:
    outputs = p.map(parallel_run, range(number_runs))
    
    
for (i, output) in enumerate(outputs):
    print('Fitness:', output['best_individual'].fitness)
    print('Base Fitness:', output['best_individual'].base_fitness)
    print('Genes:\n', output['best_individual'].genes)
    
stats_data = []
for (i, output) in enumerate(outputs):
    stats_data.append(output['best_individual'].base_fitness)

print('2b data mean:', statistics.mean(stats_data))
print('2b data stdv:', statistics.stdev(stats_data))

# Reading the data from your 2a experiment
with open('data/2a/green/statistics.txt', 'r') as f:
    random_data = [float(line) for line in f.readlines()]

print('2a data mean:', statistics.mean(random_data))
print('2a data stdv:', statistics.stdev(random_data))

test_result = stats.ttest_ind(random_data, stats_data, equal_var=False)
print('p-value:', test_result.pvalue)
# Out:
# {'DEFAULT': {}, 'ea': {'mu': 400, 'num_children': 100, 'mutation_rate': 0.2, 'parent_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'survival_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'individual_class': <class 'tree_genotype.TreeGenotype'>}, 'parent_selection_kwargs': {'k': 1}, 'survival_selection_kwargs': {'k': 1}, 'problem': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'recombination_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'mutation_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'fitness_kwargs': {'parsimony_coefficient': 0.5, 'experiment': 'yellow'}, 'game': {'game_map': 'map.txt', 'pill_spawn': 'waves', 'pill_density': 0.3333333333333333, 'fruit_prob': 0.013333333333333334, 'fruit_score': 10, 'fruit_spawn': 'corners_spawned', 'time_multiplier': 2.5, 'num_pacs': 1, 'num_ghosts': 3}}{'DEFAULT': {}, 'ea': {'mu': 400, 'num_children': 100, 'mutation_rate': 0.2, 'parent_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'survival_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'individual_class': <class 'tree_genotype.TreeGenotype'>}, 'parent_selection_kwargs': {'k': 1}, 'survival_selection_kwargs': {'k': 1}, 'problem': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'recombination_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'mutation_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'fitness_kwargs': {'parsimony_coefficient': 0.5, 'experiment': 'yellow'}, 'game': {'game_map': 'map.txt', 'pill_spawn': 'waves', 'pill_density': 0.3333333333333333, 'fruit_prob': 0.013333333333333334, 'fruit_score': 10, 'fruit_spawn': 'corners_spawned', 'time_multiplier': 2.5, 'num_pacs': 1, 'num_ghosts': 3}}{'DEFAULT': {}, 'ea': {'mu': 400, 'num_children': 100, 'mutation_rate': 0.2, 'parent_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'survival_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'individual_class': <class 'tree_genotype.TreeGenotype'>}, 'parent_selection_kwargs': {'k': 1}, 'survival_selection_kwargs': {'k': 1}, 'problem': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'recombination_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'mutation_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'fitness_kwargs': {'parsimony_coefficient': 0.5, 'experiment': 'yellow'}, 'game': {'game_map': 'map.txt', 'pill_spawn': 'waves', 'pill_density': 0.3333333333333333, 'fruit_prob': 0.013333333333333334, 'fruit_score': 10, 'fruit_spawn': 'corners_spawned', 'time_multiplier': 2.5, 'num_pacs': 1, 'num_ghosts': 3}}{'DEFAULT': {}, 'ea': {'mu': 400, 'num_children': 100, 'mutation_rate': 0.2, 'parent_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'survival_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'individual_class': <class 'tree_genotype.TreeGenotype'>}, 'parent_selection_kwargs': {'k': 1}, 'survival_selection_kwargs': {'k': 1}, 'problem': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'recombination_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'mutation_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'fitness_kwargs': {'parsimony_coefficient': 0.5, 'experiment': 'yellow ...
#
#
#
# {'DEFAULT': {}, 'ea': {'mu': 400, 'num_children': 100, 'mutation_rate': 0.2, 'parent_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'survival_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'individual_class': <class 'tree_genotype.TreeGenotype'>}, 'parent_selection_kwargs': {'k': 1}, 'survival_selection_kwargs': {'k': 1}, 'problem': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'recombination_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'mutation_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'fitness_kwargs': {'parsimony_coefficient': 0.5, 'experiment': 'yellow'}, 'game': {'game_map': 'map.txt', 'pill_spawn': 'waves', 'pill_density': 0.3333333333333333, 'fruit_prob': 0.013333333333333334, 'fruit_score': 10, 'fruit_spawn': 'corners_spawned', 'time_multiplier': 2.5, 'num_pacs': 1, 'num_ghosts': 3}}
# 400
# 400
# 400
# 400
# {'best_fitness': 102.11627906976744, 'mean_fitness': -11.216767441860465, 'best_base_fitness': 105.11627906976744, 'mean_base_fitness': -7.186767441860465, 'current_eval_count': 500}
# 500
# 400
# {'best_fitness': 57.01616832779623, 'mean_fitness': -20.81812956810631, 'best_base_fitness': 59.01616832779623, 'mean_base_fitness': -16.028129568106312, 'current_eval_count': 500}
# 500
# {'best_fitness': -3.3100775193798455, 'mean_fitness': -20.18281007751938, 'best_base_fitness': 59.689922480620154, 'mean_base_fitness': -14.630310077519379, 'current_eval_count': 500}
# 500
# {'best_fitness': 74.34108527131782, 'mean_fitness': -8.3971284606866, 'best_base_fitness': 74.34108527131782, 'mean_base_fitness': -3.8321284606866004, 'current_eval_count': 500}
# 500
# {'best_fitness': 57.01616832779623, 'mean_fitness': -6.98709080841639, 'best_base_fitness': 59.01616832779623, 'mean_base_fitness': -4.53209080841639, 'current_eval_count': 600}
# 600
# {'best_fitness': 102.11627906976744, 'mean_fitness': -1.540580287929125, 'best_base_fitness': 105.11627906976744, 'mean_base_fitness': 1.409419712070875, 'current_eval_count': 600}
# 600
# {'best_fitness': 93.19756367663345, 'mean_fitness': -24.473112403100775, 'best_base_fitness': 98.19756367663345, 'mean_base_fitness': -16.150612403100777, 'current_eval_count': 500}
# 500
# {'best_fitness': 84.49612403100775, 'mean_fitness': 1.4291633444075302, 'best_base_fitness': 84.49612403100775, 'mean_base_fitness': 4.49666334440753, 'current_eval_count': 600}
# 600
# {'best_fitness': 57.01616832779623, 'mean_fitness': 3.0621838316722036, 'best_base_fitness': 59.01616832779623, 'mean_base_fitness': 4.977183831672203, 'current_eval_count': 700}
# 700
# {'best_fitness': 102.11627906976744, 'mean_fitness': 8.525924141749723, 'best_base_fitness': 105.11627906976744, 'mean_base_fitness': 11.098424141749723, 'current_eval_count': 700}
# 700
# {'best_fitness': 57.16279069767441, 'mean_fitness': -8.704225359911407, 'best_base_fitness': 71.16279069767441, 'mean_base_fitness': -5.791725359911406, 'current_eval_count': 600}
# 600
# {'best_fitness': 57.01616832779623, 'mean_fitness': 8.8262065337763, 'best_base_fitness': 59.01616832779623, 'mean_base_fitness': 10.733706533776301, 'current_eval_count': 800}
# 800
# {'best_fitness': 105.13953488372093, 'mean_fitness': 19.513985049833888, 'best_base_fitness': 108.13953488372093, 'mean_base_fitness': 21.721485049833888, 'current_eval_count': 800}
# 800
# {'best_fitness': 91.29457364341086, 'mean_fitness': 10.61324861572536, 'best_base_fitness': 98.29457364341086, 'mean_base_fitness': 13.80574861572536, 'current_eval_count': 700}
# 700
# {'best_fitness': 95.56589147286822, 'mean_fitness': 1.411563676633444, 'best_base_fitness': 103.56589147286822, 'mean_base_fitness': 4.436563676633444, 'current_eval_count': 700}
# 700
# {'best_fitness': 93.19756367663345, 'mean_fitness': -15.252646733111849, 'best_base_fitness': 98.19756367663345, 'mean_base_fitness': -9.22764673311185, 'current_eval_count': 600}
# 600
# {'best_fitness': 61.16279069767442, 'mean_fitness': 17.36752657807309, 'best_base_fitness': 61.16279069767442, 'mean_base_fitness': 18.82502657807309, 'current_eval_count': 900}
# 900
# {'best_fitness': 105.13953488372093, 'mean_fitness': 26.667353820598006, 'best_base_fitness': 108.13953488372093, 'mean_base_fitness': 29.144853820598005, 'current_eval_count': 900}
# 900
# {'best_fitness': 95.56589147286822, 'mean_fitness': 6.048921373200443, 'best_base_fitness': 103.56589147286822, 'mean_base_fitness': 8.543921373200442, 'current_eval_count': 800}
# 800
# {'best_fitness': 91.29457364341086, 'mean_fitness': 15.12189091915836, 'best_base_fitness': 98.29457364341086, 'mean_base_fitness': 17.499390919158362, 'current_eval_count': 800}
# 800
# {'best_fitness': 64.96124031007753, 'mean_fitness': 21.570662790697675, 'best_base_fitness': 64.96124031007753, 'mean_base_fitness': 22.763162790697674, 'current_eval_count': 1000}
# 1000
# {'best_fitness': 93.19756367663345, 'mean_fitness': -10.899196566998892, 'best_base_fitness': 98.19756367663345, 'mean_base_fitness': -7.126696566998893, 'current_eval_count': 700}
# 700
# {'best_fitness': 105.13953488372093, 'mean_fitness': 30.85805426356589, 'best_base_fitness': 108.13953488372093, 'mean_base_fitness': 33.76305426356589, 'current_eval_count': 1000}
# 1000
# {'best_fitness': 53.83720930232559, 'mean_fitness': 21.93798726467331, 'best_base_fitness': 68.83720930232559, 'mean_base_fitness': 23.095487264673313, 'current_eval_count': 1100}
# 1100
# {'best_fitness': 96.06976744186046, 'mean_fitness': 19.268939645625693, 'best_base_fitness': 99.06976744186046, 'mean_base_fitness': 21.406439645625692, 'current_eval_count': 900}
# 900
# {'best_fitness': 106.47286821705427, 'mean_fitness': 14.232766888150609, 'best_base_fitness': 121.47286821705427, 'mean_base_fitness': 17.26026688815061, 'current_eval_count': 900}
# 900
# {'best_fitness': 53.83720930232559, 'mean_fitness': 23.338, 'best_base_fitness': 68.83720930232559, 'mean_base_fitness': 24.493, 'current_eval_count': 1200}
# 1200
# {'best_fitness': 93.19756367663345, 'mean_fitness': -3.972821151716501, 'best_base_fitness': 98.19756367663345, 'mean_base_fitness': -1.3603211517165008, 'current_eval_count': 800}
# 800
# {'best_fitness': 127.44961240310079, 'mean_fitness': 38.43543244739757, 'best_base_fitness': 128.4496124031008, 'mean_base_fitness': 41.312932447397564, 'current_eval_count': 1100}
# 1100
# {'best_fitness': 114.74418604651163, 'mean_fitness': 24.975392580287927, 'best_base_fitness': 116.74418604651163, 'mean_base_fitness': 26.99289258028793, 'current_eval_count': 1000}
# 1000
# {'best_fitness': 53.83720930232559, 'mean_fitness': 25.063921373200444, 'best_base_fitness': 68.83720930232559, 'mean_base_fitness': 26.333921373200443, 'current_eval_count': 1300}
# 1300
# {'best_fitness': 93.19756367663345, 'mean_fitness': 5.0911810631229235, 'best_base_fitness': 98.19756367663345, 'mean_base_fitness': 6.933681063122924, 'current_eval_count': 900}
# 900
# {'best_fitness': 127.44961240310079, 'mean_fitness': 43.804965669988924, 'best_base_fitness': 128.4496124031008, 'mean_base_fitness': 47.444965669988925, 'current_eval_count': 1200}
# 1200
# {'best_fitness': 53.83720930232559, 'mean_fitness': 26.43323588039867, 'best_base_fitness': 68.83720930232559, 'mean_base_fitness': 27.88823588039867, 'current_eval_count': 1400}
# 1400
# {'best_fitness': 114.74418604651163, 'mean_fitness': 32.02175747508306, 'best_base_fitness': 116.74418604651163, 'mean_base_fitness': 33.81675747508306, 'current_eval_count': 1100}
# 1100
# {'best_fitness': 106.47286821705427, 'mean_fitness': 20.62553599114064, 'best_base_fitness': 121.47286821705427, 'mean_base_fitness': 23.94553599114064, 'current_eval_count': 1000}
# 1000
# {'best_fitness': 53.83720930232559, 'mean_fitness': 28.71996068660022, 'best_base_fitness': 68.83720930232559, 'mean_base_fitness': 30.167460686600222, 'current_eval_count': 1500}
# 1500
# {'best_fitness': 108.24806201550388, 'mean_fitness': 10.46739091915836, 'best_base_fitness': 112.24806201550388, 'mean_base_fitness': 12.26739091915836, 'current_eval_count': 1000}
# 1000
# {'best_fitness': 127.44961240310079, 'mean_fitness': 51.14017663344408, 'best_base_fitness': 128.4496124031008, 'mean_base_fitness': 54.30267663344407, 'current_eval_count': 1300}
# 1300
# {'best_fitness': 53.83720930232559, 'mean_fitness': 28.620271317829456, 'best_base_fitness': 68.83720930232559, 'mean_base_fitness': 30.045271317829457, 'current_eval_count': 1600}
# 1600
# {'best_fitness': 114.74418604651163, 'mean_fitness': 38.40111406423034, 'best_base_fitness': 116.74418604651163, 'mean_base_fitness': 40.68111406423034, 'current_eval_count': 1200}
# 1200
# {'best_fitness': 108.24806201550388, 'mean_fitness': 9.541064784053155, 'best_base_fitness': 112.24806201550388, 'mean_base_fitness': 11.183564784053155, 'current_eval_count': 1100}
# 1100
# {'best_fitness': 53.83720930232559, 'mean_fitness': 30.708782945736434, 'best_base_fitness': 68.83720930232559, 'mean_base_fitness': 32.233782945736436, 'current_eval_count': 1700}
# 1700
# {'best_fitness': 106.47286821705427, 'mean_fitness': 24.473299003322257, 'best_base_fitness': 121.47286821705427, 'mean_base_fitness': 28.13829900332226, 'current_eval_count': 1100}
# 1100
# {'best_fitness': 127.44961240310079, 'mean_fitness': 60.208569213732005, 'best_base_fitness': 128.4496124031008, 'mean_base_fitness': 63.123569213732004, 'current_eval_count': 1400}
# 1400
# {'best_fitness': 114.74418604651163, 'mean_fitness': 40.82501937984496, 'best_base_fitness': 116.74418604651163, 'mean_base_fitness': 43.19751937984496, 'current_eval_count': 1300}
# 1300
# {'best_fitness': 108.24806201550388, 'mean_fitness': 12.70647342192691, 'best_base_fitness': 112.24806201550388, 'mean_base_fitness': 14.25397342192691, 'current_eval_count': 1200}
# 1200
# {'best_fitness': 53.83720930232559, 'mean_fitness': 31.659856589147285, 'best_base_fitness': 68.83720930232559, 'mean_base_fitness': 32.93235658914729, 'current_eval_count': 1800}
# 1800
# {'best_fitness': 53.83720930232559, 'mean_fitness': 31.45623311184939, 'best_base_fitness': 68.83720930232559, 'mean_base_fitness': 32.71873311184939, 'current_eval_count': 1900}
# 1900
# {'best_fitness': 120.82170542635659, 'mean_fitness': 17.72068992248062, 'best_base_fitness': 126.82170542635659, 'mean_base_fitness': 19.32068992248062, 'current_eval_count': 1300}
# 1300
# {'best_fitness': 127.44961240310079, 'mean_fitness': 66.5947895902547, 'best_base_fitness': 128.4496124031008, 'mean_base_fitness': 69.07478959025471, 'current_eval_count': 1500}
# 1500
# {'best_fitness': 114.74418604651163, 'mean_fitness': 48.014903654485046, 'best_base_fitness': 116.74418604651163, 'mean_base_fitness': 50.57490365448505, 'current_eval_count': 1400}
# 1400
# {'best_fitness': 53.83720930232559, 'mean_fitness': 31.95887320044297, 'best_base_fitness': 68.83720930232559, 'mean_base_fitness': 33.131373200442965, 'current_eval_count': 2000}
# 2000
# {'best_fitness': 106.47286821705427, 'mean_fitness': 28.727599667774086, 'best_base_fitness': 121.47286821705427, 'mean_base_fitness': 33.160099667774084, 'current_eval_count': 1200}
# 1200
# {'best_fitness': 120.82170542635659, 'mean_fitness': 22.327043743078626, 'best_base_fitness': 126.82170542635659, 'mean_base_fitness': 24.039543743078628, 'current_eval_count': 1400}
# 1400
# {'best_fitness': 53.83720930232559, 'mean_fitness': 31.77285215946844, 'best_base_fitness': 68.83720930232559, 'mean_base_fitness': 32.87535215946844, 'current_eval_count': 2100}
# 2100
# {'best_fitness': 120.72093023255815, 'mean_fitness': 49.569244739756364, 'best_base_fitness': 123.72093023255815, 'mean_base_fitness': 51.934244739756366, 'current_eval_count': 1500}
# 1500
# {'best_fitness': 127.44961240310079, 'mean_fitness': 70.79098062015504, 'best_base_fitness': 128.4496124031008, 'mean_base_fitness': 73.30848062015504, 'current_eval_count': 1600}
# 1600
# {'best_fitness': 77.28682170542635, 'mean_fitness': 31.30086323366556, 'best_base_fitness': 77.28682170542635, 'mean_base_fitness': 32.40336323366556, 'current_eval_count': 2200}
# 2200
# {'best_fitness': 120.82170542635659, 'mean_fitness': 28.14244019933555, 'best_base_fitness': 126.82170542635659, 'mean_base_fitness': 30.159940199335548, 'current_eval_count': 1500}
# 1500
# {'best_fitness': 77.28682170542635, 'mean_fitness': 29.732511627906977, 'best_base_fitness': 77.28682170542635, 'mean_base_fitness': 30.552511627906977, 'current_eval_count': 2300}
# 2300
# {'best_fitness': 120.72093023255815, 'mean_fitness': 54.226964008859355, 'best_base_fitness': 123.72093023255815, 'mean_base_fitness': 56.57446400885936, 'current_eval_count': 1600}
# 1600
# {'best_fitness': 127.44961240310079, 'mean_fitness': 72.613496124031, 'best_base_fitness': 128.4496124031008, 'mean_base_fitness': 75.28849612403101, 'current_eval_count': 1700}
# 1700
# {'best_fitness': 77.28682170542635, 'mean_fitness': 30.91299723145072, 'best_base_fitness': 77.28682170542635, 'mean_base_fitness': 31.65049723145072, 'current_eval_count': 2400}
# 2400
# {'best_fitness': 106.47286821705427, 'mean_fitness': 31.01140753045404, 'best_base_fitness': 121.47286821705427, 'mean_base_fitness': 35.73140753045404, 'current_eval_count': 1300}
# 1300
# {'best_fitness': 120.82170542635659, 'mean_fitness': 35.51744130675526, 'best_base_fitness': 126.82170542635659, 'mean_base_fitness': 38.01994130675526, 'current_eval_count': 1600}
# 1600
# {'best_fitness': 77.28682170542635, 'mean_fitness': 32.48271151716501, 'best_base_fitness': 77.28682170542635, 'mean_base_fitness': 33.445211517165006, 'current_eval_count': 2500}
# 2500
# {'best_fitness': 127.59689922480621, 'mean_fitness': 63.12935049833887, 'best_base_fitness': 127.59689922480621, 'mean_base_fitness': 65.11685049833888, 'current_eval_count': 1700}
# 1700
# {'best_fitness': 77.28682170542635, 'mean_fitness': 34.375134551495016, 'best_base_fitness': 77.28682170542635, 'mean_base_fitness': 35.29263455149502, 'current_eval_count': 2600}
# 2600
# {'best_fitness': 120.82170542635659, 'mean_fitness': 39.913809523809526, 'best_base_fitness': 126.82170542635659, 'mean_base_fitness': 42.38880952380952, 'current_eval_count': 1700}
# 1700
# {'best_fitness': 127.44961240310079, 'mean_fitness': 75.15152380952381, 'best_base_fitness': 128.4496124031008, 'mean_base_fitness': 77.55652380952381, 'current_eval_count': 1800}
# 1800
# {'best_fitness': 77.28682170542635, 'mean_fitness': 35.929461240310076, 'best_base_fitness': 77.28682170542635, 'mean_base_fitness': 36.796961240310075, 'current_eval_count': 2700}
# 2700
# {'best_fitness': 144.49612403100775, 'mean_fitness': 68.99661351052049, 'best_base_fitness': 144.49612403100775, 'mean_base_fitness': 70.71661351052049, 'current_eval_count': 1800}
# 1800
# {'best_fitness': 120.82170542635659, 'mean_fitness': 46.690073643410855, 'best_base_fitness': 126.82170542635659, 'mean_base_fitness': 48.95757364341085, 'current_eval_count': 1800}
# 1800
# {'best_fitness': 77.28682170542635, 'mean_fitness': 34.5464861572536, 'best_base_fitness': 77.28682170542635, 'mean_base_fitness': 35.4514861572536, 'current_eval_count': 2800}
# 2800
# {'best_fitness': 127.44961240310079, 'mean_fitness': 78.56418936877077, 'best_base_fitness': 128.4496124031008, 'mean_base_fitness': 80.73918936877077, 'current_eval_count': 1900}
# 1900
# {'best_fitness': 106.47286821705427, 'mean_fitness': 37.02896843853821, 'best_base_fitness': 121.47286821705427, 'mean_base_fitness': 41.961468438538205, 'current_eval_count': 1400}
# 1400
# {'best_fitness': 77.28682170542635, 'mean_fitness': 33.46386877076412, 'best_base_fitness': 77.28682170542635, 'mean_base_fitness': 34.43636877076412, 'current_eval_count': 2900}
# 2900
# {'best_fitness': 120.82170542635659, 'mean_fitness': 52.21316445182724, 'best_base_fitness': 126.82170542635659, 'mean_base_fitness': 54.840664451827244, 'current_eval_count': 1900}
# 1900
# {'best_fitness': 144.49612403100775, 'mean_fitness': 72.91804928017719, 'best_base_fitness': 144.49612403100775, 'mean_base_fitness': 74.6905492801772, 'current_eval_count': 1900}
# 1900
# {'best_fitness': 77.28682170542635, 'mean_fitness': 35.09764894795127, 'best_base_fitness': 77.28682170542635, 'mean_base_fitness': 36.05764894795127, 'current_eval_count': 3000}
# 3000
# {'best_fitness': 127.44961240310079, 'mean_fitness': 81.41996677740863, 'best_base_fitness': 128.4496124031008, 'mean_base_fitness': 83.26996677740864, 'current_eval_count': 2000}
# 2000
# {'best_fitness': 77.28682170542635, 'mean_fitness': 35.59131284606866, 'best_base_fitness': 77.28682170542635, 'mean_base_fitness': 36.55881284606866, 'current_eval_count': 3100}
# 3100
# {'best_fitness': 136.04651162790697, 'mean_fitness': 56.6279496124031, 'best_base_fitness': 136.04651162790697, 'mean_base_fitness': 59.2204496124031, 'current_eval_count': 2000}
# 2000
# {'best_fitness': 144.49612403100775, 'mean_fitness': 76.49596622369879, 'best_base_fitness': 144.49612403100775, 'mean_base_fitness': 78.49846622369878, 'current_eval_count': 2000}
# 2000
# {'best_fitness': 77.28682170542635, 'mean_fitness': 36.063750830564786, 'best_base_fitness': 77.28682170542635, 'mean_base_fitness': 36.91375083056479, 'current_eval_count': 3200}
# 3200
# {'best_fitness': 138.4496124031008, 'mean_fitness': 78.91492469545958, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 80.45992469545958, 'current_eval_count': 2100}
# 2100
# {'best_fitness': 77.28682170542635, 'mean_fitness': 35.84117718715393, 'best_base_fitness': 77.28682170542635, 'mean_base_fitness': 36.74617718715393, 'current_eval_count': 3300}
# 3300
# {'best_fitness': 106.47286821705427, 'mean_fitness': 36.853792358803986, 'best_base_fitness': 121.47286821705427, 'mean_base_fitness': 41.776292358803985, 'current_eval_count': 1500}
# 1500
# {'best_fitness': 77.28682170542635, 'mean_fitness': 35.383614617940204, 'best_base_fitness': 77.28682170542635, 'mean_base_fitness': 36.3736146179402, 'current_eval_count': 3400}
# 3400
# {'best_fitness': 136.04651162790697, 'mean_fitness': 61.92737818383167, 'best_base_fitness': 136.04651162790697, 'mean_base_fitness': 64.41487818383168, 'current_eval_count': 2100}
# 2100
# {'best_fitness': 144.49612403100775, 'mean_fitness': 80.5516600221484, 'best_base_fitness': 144.49612403100775, 'mean_base_fitness': 82.6116600221484, 'current_eval_count': 2100}
# 2100
# {'best_fitness': 77.28682170542635, 'mean_fitness': 36.41346511627907, 'best_base_fitness': 77.28682170542635, 'mean_base_fitness': 37.52346511627907, 'current_eval_count': 3500}
# 3500
# {'best_fitness': 138.4496124031008, 'mean_fitness': 79.30610631229236, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 80.80110631229236, 'current_eval_count': 2200}
# 2200
# {'best_fitness': 77.28682170542635, 'mean_fitness': 35.63714507198228, 'best_base_fitness': 77.28682170542635, 'mean_base_fitness': 36.81214507198228, 'current_eval_count': 3600}
# 3600
# {'best_fitness': 136.04651162790697, 'mean_fitness': 67.81701328903654, 'best_base_fitness': 136.04651162790697, 'mean_base_fitness': 70.17701328903654, 'current_eval_count': 2200}
# 2200
# {'best_fitness': 144.49612403100775, 'mean_fitness': 82.83068604651163, 'best_base_fitness': 144.49612403100775, 'mean_base_fitness': 84.81318604651163, 'current_eval_count': 2200}
# 2200
# {'best_fitness': 77.28682170542635, 'mean_fitness': 36.78177408637874, 'best_base_fitness': 77.28682170542635, 'mean_base_fitness': 37.941774086378736, 'current_eval_count': 3700}
# 3700
# {'best_fitness': 138.4496124031008, 'mean_fitness': 76.44748394241418, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 77.64748394241417, 'current_eval_count': 2300}
# 2300
# {'best_fitness': 77.28682170542635, 'mean_fitness': 36.70012403100775, 'best_base_fitness': 77.28682170542635, 'mean_base_fitness': 37.910124031007754, 'current_eval_count': 3800}
# 3800
# {'best_fitness': 106.47286821705427, 'mean_fitness': 43.68164507198228, 'best_base_fitness': 121.47286821705427, 'mean_base_fitness': 49.28914507198228, 'current_eval_count': 1600}
# 1600
# {'best_fitness': 136.04651162790697, 'mean_fitness': 73.57025415282392, 'best_base_fitness': 136.04651162790697, 'mean_base_fitness': 75.91275415282392, 'current_eval_count': 2300}
# 2300
# {'best_fitness': 144.49612403100775, 'mean_fitness': 86.09546290143965, 'best_base_fitness': 144.49612403100775, 'mean_base_fitness': 87.90546290143965, 'current_eval_count': 2300}
# 2300
# {'best_fitness': 77.28682170542635, 'mean_fitness': 36.708306201550386, 'best_base_fitness': 77.28682170542635, 'mean_base_fitness': 37.83080620155039, 'current_eval_count': 3900}
# 3900
# {'best_fitness': 138.4496124031008, 'mean_fitness': 79.70991915836102, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 80.73991915836102, 'current_eval_count': 2400}
# 2400
# {'best_fitness': 77.28682170542635, 'mean_fitness': 35.87964451827243, 'best_base_fitness': 77.28682170542635, 'mean_base_fitness': 37.02964451827243, 'current_eval_count': 4000}
# 4000
# {'best_fitness': 77.28682170542635, 'mean_fitness': 35.68879900332226, 'best_base_fitness': 77.28682170542635, 'mean_base_fitness': 36.89629900332226, 'current_eval_count': 4100}
# 4100
# {'best_fitness': 136.04651162790697, 'mean_fitness': 76.94994739756368, 'best_base_fitness': 136.04651162790697, 'mean_base_fitness': 79.19244739756368, 'current_eval_count': 2400}
# 2400
# {'best_fitness': 146.12403100775194, 'mean_fitness': 88.17816611295682, 'best_base_fitness': 146.12403100775194, 'mean_base_fitness': 89.90316611295681, 'current_eval_count': 2400}
# 2400
# {'best_fitness': 77.28682170542635, 'mean_fitness': 34.60954872646733, 'best_base_fitness': 77.28682170542635, 'mean_base_fitness': 35.692048726467334, 'current_eval_count': 4200}
# 4200
# {'best_fitness': 138.4496124031008, 'mean_fitness': 79.34581672203765, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 80.21331672203765, 'current_eval_count': 2500}
# 2500
# {'best_fitness': 77.28682170542635, 'mean_fitness': 35.364744186046515, 'best_base_fitness': 77.28682170542635, 'mean_base_fitness': 36.53974418604651, 'current_eval_count': 4300}
# 4300
# {'best_fitness': 136.04651162790697, 'mean_fitness': 81.08395736434109, 'best_base_fitness': 136.04651162790697, 'mean_base_fitness': 83.27645736434108, 'current_eval_count': 2500}
# 2500
# {'best_fitness': 146.12403100775194, 'mean_fitness': 90.10579401993355, 'best_base_fitness': 146.12403100775194, 'mean_base_fitness': 91.50579401993356, 'current_eval_count': 2500}
# 2500
# {'best_fitness': 106.47286821705427, 'mean_fitness': 51.38575359911406, 'best_base_fitness': 121.47286821705427, 'mean_base_fitness': 57.56325359911406, 'current_eval_count': 1700}
# 1700
# {'best_fitness': 77.28682170542635, 'mean_fitness': 33.24460299003322, 'best_base_fitness': 77.28682170542635, 'mean_base_fitness': 34.26710299003322, 'current_eval_count': 4400}
# 4400
# {'best_fitness': 138.4496124031008, 'mean_fitness': 78.82268826135105, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 79.61518826135105, 'current_eval_count': 2600}
# 2600
# {'best_fitness': 77.28682170542635, 'mean_fitness': 35.34506866002215, 'best_base_fitness': 77.28682170542635, 'mean_base_fitness': 36.34006866002215, 'current_eval_count': 4500}
# 4500
# {'best_fitness': 148.37209302325581, 'mean_fitness': 87.73606533776301, 'best_base_fitness': 148.37209302325581, 'mean_base_fitness': 89.16606533776302, 'current_eval_count': 2600}
# 2600
# {'best_fitness': 77.28682170542635, 'mean_fitness': 33.02977187153931, 'best_base_fitness': 77.28682170542635, 'mean_base_fitness': 34.00477187153931, 'current_eval_count': 4600}
# 4600
# {'best_fitness': 136.04651162790697, 'mean_fitness': 83.19428792912514, 'best_base_fitness': 136.04651162790697, 'mean_base_fitness': 85.20928792912514, 'current_eval_count': 2600}
# 2600
# {'best_fitness': 138.4496124031008, 'mean_fitness': 76.71814174972315, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 77.58814174972315, 'current_eval_count': 2700}
# 2700
# {'best_fitness': 77.28682170542635, 'mean_fitness': 34.588517165005534, 'best_base_fitness': 77.28682170542635, 'mean_base_fitness': 35.56851716500554, 'current_eval_count': 4700}
# 4700
# {'best_fitness': 85.11627906976744, 'mean_fitness': 34.461857696567, 'best_base_fitness': 85.11627906976744, 'mean_base_fitness': 35.404357696567, 'current_eval_count': 4800}
# 4800
# {'best_fitness': 148.37209302325581, 'mean_fitness': 88.58867220376523, 'best_base_fitness': 148.37209302325581, 'mean_base_fitness': 90.05867220376523, 'current_eval_count': 2700}
# 2700
# {'best_fitness': 135.82170542635657, 'mean_fitness': 86.34038593576966, 'best_base_fitness': 136.82170542635657, 'mean_base_fitness': 88.33288593576965, 'current_eval_count': 2700}
# 2700
# {'best_fitness': 138.4496124031008, 'mean_fitness': 82.4234772978959, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 83.3534772978959, 'current_eval_count': 2800}
# 2800
# {'best_fitness': 85.11627906976744, 'mean_fitness': 34.01070044296789, 'best_base_fitness': 85.11627906976744, 'mean_base_fitness': 34.958200442967886, 'current_eval_count': 4900}
# 4900
# {'best_fitness': 85.11627906976744, 'mean_fitness': 32.27798781838317, 'best_base_fitness': 85.11627906976744, 'mean_base_fitness': 33.26798781838317, 'current_eval_count': 5000}
# {'best_fitness': 106.47286821705427, 'mean_fitness': 54.05568161683278, 'best_base_fitness': 121.47286821705427, 'mean_base_fitness': 59.96818161683278, 'current_eval_count': 1800}
# 1800
# {'best_fitness': 148.37209302325581, 'mean_fitness': 88.38421317829457, 'best_base_fitness': 148.37209302325581, 'mean_base_fitness': 89.73171317829457, 'current_eval_count': 2800}
# 2800
# {'best_fitness': 135.82170542635657, 'mean_fitness': 85.08559800664452, 'best_base_fitness': 136.82170542635657, 'mean_base_fitness': 86.82559800664451, 'current_eval_count': 2800}
# 2800
# {'best_fitness': 138.4496124031008, 'mean_fitness': 81.90817829457364, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 82.64317829457364, 'current_eval_count': 2900}
# 2900
# {'best_fitness': 148.37209302325581, 'mean_fitness': 88.42689867109634, 'best_base_fitness': 148.37209302325581, 'mean_base_fitness': 89.72439867109635, 'current_eval_count': 2900}
# 2900
# {'best_fitness': 138.4496124031008, 'mean_fitness': 81.94642248062016, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 82.59392248062015, 'current_eval_count': 3000}
# 3000
# {'best_fitness': 135.82170542635657, 'mean_fitness': 85.88043798449613, 'best_base_fitness': 136.82170542635657, 'mean_base_fitness': 87.46293798449612, 'current_eval_count': 2900}
# 2900
# {'best_fitness': 148.37209302325581, 'mean_fitness': 87.28203211517165, 'best_base_fitness': 148.37209302325581, 'mean_base_fitness': 88.30703211517165, 'current_eval_count': 3000}
# 3000
# {'best_fitness': 138.4496124031008, 'mean_fitness': 82.85056533776302, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 83.45806533776302, 'current_eval_count': 3100}
# 3100
# {'best_fitness': 135.82170542635657, 'mean_fitness': 85.0013073089701, 'best_base_fitness': 136.82170542635657, 'mean_base_fitness': 86.7538073089701, 'current_eval_count': 3000}
# 3000
# {'best_fitness': 125.27131782945736, 'mean_fitness': 56.33234440753046, 'best_base_fitness': 125.27131782945736, 'mean_base_fitness': 62.11234440753045, 'current_eval_count': 1900}
# 1900
# {'best_fitness': 151.47286821705427, 'mean_fitness': 87.2731699889258, 'best_base_fitness': 151.47286821705427, 'mean_base_fitness': 88.2056699889258, 'current_eval_count': 3100}
# 3100
# {'best_fitness': 138.4496124031008, 'mean_fitness': 84.87293964562569, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 85.45043964562569, 'current_eval_count': 3200}
# 3200
# {'best_fitness': 135.82170542635657, 'mean_fitness': 84.76931284606866, 'best_base_fitness': 136.82170542635657, 'mean_base_fitness': 86.56181284606866, 'current_eval_count': 3100}
# 3100
# {'best_fitness': 138.4496124031008, 'mean_fitness': 83.43698062015504, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 83.91948062015504, 'current_eval_count': 3300}
# 3300
# {'best_fitness': 151.47286821705427, 'mean_fitness': 88.40306478405316, 'best_base_fitness': 151.47286821705427, 'mean_base_fitness': 89.44556478405316, 'current_eval_count': 3200}
# 3200
# {'best_fitness': 135.82170542635657, 'mean_fitness': 84.10759745293466, 'best_base_fitness': 136.82170542635657, 'mean_base_fitness': 86.05509745293466, 'current_eval_count': 3200}
# 3200
# {'best_fitness': 138.4496124031008, 'mean_fitness': 83.68309468438538, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 84.19059468438539, 'current_eval_count': 3400}
# 3400
# {'best_fitness': 155.34883720930233, 'mean_fitness': 88.46217718715393, 'best_base_fitness': 155.34883720930233, 'mean_base_fitness': 89.60717718715394, 'current_eval_count': 3300}
# 3300
# {'best_fitness': 125.27131782945736, 'mean_fitness': 57.60225249169435, 'best_base_fitness': 125.27131782945736, 'mean_base_fitness': 62.93225249169435, 'current_eval_count': 2000}
# 2000
# {'best_fitness': 135.82170542635657, 'mean_fitness': 87.39639258028792, 'best_base_fitness': 136.82170542635657, 'mean_base_fitness': 89.28889258028794, 'current_eval_count': 3300}
# 3300
# {'best_fitness': 138.4496124031008, 'mean_fitness': 85.97899723145072, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 86.44649723145072, 'current_eval_count': 3500}
# 3500
# {'best_fitness': 155.34883720930233, 'mean_fitness': 90.5749446290144, 'best_base_fitness': 155.34883720930233, 'mean_base_fitness': 91.6049446290144, 'current_eval_count': 3400}
# 3400
# {'best_fitness': 135.82170542635657, 'mean_fitness': 88.53125858250277, 'best_base_fitness': 136.82170542635657, 'mean_base_fitness': 90.47375858250277, 'current_eval_count': 3400}
# 3400
# {'best_fitness': 138.4496124031008, 'mean_fitness': 91.69005758582503, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 92.11505758582503, 'current_eval_count': 3600}
# 3600
# {'best_fitness': 155.34883720930233, 'mean_fitness': 92.01276633444076, 'best_base_fitness': 155.34883720930233, 'mean_base_fitness': 92.98276633444075, 'current_eval_count': 3500}
# 3500
# {'best_fitness': 138.4496124031008, 'mean_fitness': 91.79974086378738, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 93.76974086378738, 'current_eval_count': 3500}
# 3500
# {'best_fitness': 125.27131782945736, 'mean_fitness': 60.722013289036546, 'best_base_fitness': 125.27131782945736, 'mean_base_fitness': 65.18701328903654, 'current_eval_count': 2100}
# 2100
# {'best_fitness': 138.4496124031008, 'mean_fitness': 89.46169324473976, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 89.87169324473976, 'current_eval_count': 3700}
# 3700
# {'best_fitness': 155.34883720930233, 'mean_fitness': 93.01403156146179, 'best_base_fitness': 155.34883720930233, 'mean_base_fitness': 93.8315315614618, 'current_eval_count': 3600}
# 3600
# {'best_fitness': 138.4496124031008, 'mean_fitness': 94.31541971207088, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 96.17041971207087, 'current_eval_count': 3600}
# 3600
# {'best_fitness': 138.4496124031008, 'mean_fitness': 89.53411960132891, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 89.9791196013289, 'current_eval_count': 3800}
# 3800
# {'best_fitness': 155.34883720930233, 'mean_fitness': 93.9280354374308, 'best_base_fitness': 155.34883720930233, 'mean_base_fitness': 94.61803543743079, 'current_eval_count': 3700}
# 3700
# {'best_fitness': 138.4496124031008, 'mean_fitness': 95.7790138427464, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 97.6265138427464, 'current_eval_count': 3700}
# 3700
# {'best_fitness': 138.4496124031008, 'mean_fitness': 91.47287707641196, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 91.89787707641196, 'current_eval_count': 3900}
# 3900
# {'best_fitness': 138.4496124031008, 'mean_fitness': 93.73390033222591, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 95.46390033222592, 'current_eval_count': 3800}
# 3800
# {'best_fitness': 155.34883720930233, 'mean_fitness': 94.53391583610188, 'best_base_fitness': 155.34883720930233, 'mean_base_fitness': 95.24891583610189, 'current_eval_count': 3800}
# 3800
# {'best_fitness': 125.27131782945736, 'mean_fitness': 62.61127519379845, 'best_base_fitness': 125.27131782945736, 'mean_base_fitness': 66.61377519379845, 'current_eval_count': 2200}
# 2200
# {'best_fitness': 138.4496124031008, 'mean_fitness': 91.48710188261352, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 91.9671018826135, 'current_eval_count': 4000}
# 4000
# {'best_fitness': 155.34883720930233, 'mean_fitness': 90.45233610188261, 'best_base_fitness': 155.34883720930233, 'mean_base_fitness': 91.13983610188261, 'current_eval_count': 3900}
# 3900
# {'best_fitness': 143.02325581395348, 'mean_fitness': 97.62736157253599, 'best_base_fitness': 143.02325581395348, 'mean_base_fitness': 99.434861572536, 'current_eval_count': 3900}
# 3900
# {'best_fitness': 138.4496124031008, 'mean_fitness': 91.80421650055371, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 92.3067165005537, 'current_eval_count': 4100}
# 4100
# {'best_fitness': 155.34883720930233, 'mean_fitness': 91.19682059800664, 'best_base_fitness': 155.34883720930233, 'mean_base_fitness': 91.85682059800665, 'current_eval_count': 4000}
# 4000
# {'best_fitness': 143.02325581395348, 'mean_fitness': 98.70801328903654, 'best_base_fitness': 143.02325581395348, 'mean_base_fitness': 100.55801328903654, 'current_eval_count': 4000}
# 4000
# {'best_fitness': 138.4496124031008, 'mean_fitness': 92.27289977851606, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 92.79539977851606, 'current_eval_count': 4200}
# 4200
# {'best_fitness': 125.27131782945736, 'mean_fitness': 65.74136821705426, 'best_base_fitness': 125.27131782945736, 'mean_base_fitness': 69.54886821705426, 'current_eval_count': 2300}
# 2300
# {'best_fitness': 143.02325581395348, 'mean_fitness': 101.18738482834995, 'best_base_fitness': 143.02325581395348, 'mean_base_fitness': 103.17488482834995, 'current_eval_count': 4100}
# 4100
# {'best_fitness': 155.34883720930233, 'mean_fitness': 91.58889700996677, 'best_base_fitness': 155.34883720930233, 'mean_base_fitness': 92.21389700996677, 'current_eval_count': 4100}
# 4100
# {'best_fitness': 138.4496124031008, 'mean_fitness': 89.1710780730897, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 89.6885780730897, 'current_eval_count': 4300}
# 4300
# {'best_fitness': 143.02325581395348, 'mean_fitness': 101.50872369878184, 'best_base_fitness': 143.02325581395348, 'mean_base_fitness': 103.24122369878184, 'current_eval_count': 4200}
# 4200
# {'best_fitness': 155.34883720930233, 'mean_fitness': 94.04539147286822, 'best_base_fitness': 155.34883720930233, 'mean_base_fitness': 94.61789147286822, 'current_eval_count': 4200}
# 4200
# {'best_fitness': 138.4496124031008, 'mean_fitness': 91.14704429678848, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 91.58204429678848, 'current_eval_count': 4400}
# 4400
# {'best_fitness': 143.02325581395348, 'mean_fitness': 101.90954374307863, 'best_base_fitness': 143.02325581395348, 'mean_base_fitness': 103.43954374307863, 'current_eval_count': 4300}
# 4300
# {'best_fitness': 155.34883720930233, 'mean_fitness': 95.24283942414175, 'best_base_fitness': 155.34883720930233, 'mean_base_fitness': 95.83283942414175, 'current_eval_count': 4300}
# 4300
# {'best_fitness': 125.27131782945736, 'mean_fitness': 64.20669822812846, 'best_base_fitness': 125.27131782945736, 'mean_base_fitness': 68.09419822812846, 'current_eval_count': 2400}
# 2400
# {'best_fitness': 138.4496124031008, 'mean_fitness': 92.4954446290144, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 92.9329446290144, 'current_eval_count': 4500}
# 4500
# {'best_fitness': 143.02325581395348, 'mean_fitness': 103.24508416389811, 'best_base_fitness': 143.02325581395348, 'mean_base_fitness': 104.77508416389811, 'current_eval_count': 4400}
# 4400
# {'best_fitness': 155.34883720930233, 'mean_fitness': 94.68225083056478, 'best_base_fitness': 155.34883720930233, 'mean_base_fitness': 95.30975083056478, 'current_eval_count': 4400}
# 4400
# {'best_fitness': 138.4496124031008, 'mean_fitness': 92.84478571428572, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 93.27228571428572, 'current_eval_count': 4600}
# 4600
# {'best_fitness': 143.02325581395348, 'mean_fitness': 104.227496124031, 'best_base_fitness': 143.02325581395348, 'mean_base_fitness': 105.792496124031, 'current_eval_count': 4500}
# 4500
# {'best_fitness': 155.34883720930233, 'mean_fitness': 95.84793743078627, 'best_base_fitness': 155.34883720930233, 'mean_base_fitness': 96.38043743078627, 'current_eval_count': 4500}
# 4500
# {'best_fitness': 138.4496124031008, 'mean_fitness': 95.05310797342193, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 95.38060797342193, 'current_eval_count': 4700}
# 4700
# {'best_fitness': 143.02325581395348, 'mean_fitness': 102.2087253599114, 'best_base_fitness': 143.02325581395348, 'mean_base_fitness': 103.75872535991141, 'current_eval_count': 4600}
# 4600
# {'best_fitness': 155.34883720930233, 'mean_fitness': 96.2432065337763, 'best_base_fitness': 155.34883720930233, 'mean_base_fitness': 96.70570653377631, 'current_eval_count': 4600}
# 4600
# {'best_fitness': 125.27131782945736, 'mean_fitness': 70.01545348837209, 'best_base_fitness': 125.27131782945736, 'mean_base_fitness': 73.5529534883721, 'current_eval_count': 2500}
# 2500
# {'best_fitness': 138.4496124031008, 'mean_fitness': 95.81776024363234, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 96.10026024363233, 'current_eval_count': 4800}
# 4800
# {'best_fitness': 143.02325581395348, 'mean_fitness': 103.98118826135105, 'best_base_fitness': 143.02325581395348, 'mean_base_fitness': 105.51118826135105, 'current_eval_count': 4700}
# 4700
# {'best_fitness': 157.4496124031008, 'mean_fitness': 95.29566777408638, 'best_base_fitness': 158.4496124031008, 'mean_base_fitness': 95.70566777408638, 'current_eval_count': 4700}
# 4700
# {'best_fitness': 138.4496124031008, 'mean_fitness': 96.72880121816168, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 97.01630121816169, 'current_eval_count': 4900}
# 4900
# {'best_fitness': 143.02325581395348, 'mean_fitness': 107.91188261351051, 'best_base_fitness': 143.02325581395348, 'mean_base_fitness': 109.32688261351052, 'current_eval_count': 4800}
# 4800
# {'best_fitness': 157.4496124031008, 'mean_fitness': 93.09024916943521, 'best_base_fitness': 158.4496124031008, 'mean_base_fitness': 93.46024916943522, 'current_eval_count': 4800}
# 4800
# {'best_fitness': 138.4496124031008, 'mean_fitness': 97.37068050941306, 'best_base_fitness': 138.4496124031008, 'mean_base_fitness': 97.62818050941307, 'current_eval_count': 5000}
# {'best_fitness': 143.02325581395348, 'mean_fitness': 110.99082613510521, 'best_base_fitness': 143.02325581395348, 'mean_base_fitness': 112.3058261351052, 'current_eval_count': 4900}
# 4900
# {'best_fitness': 157.4496124031008, 'mean_fitness': 92.0651184939092, 'best_base_fitness': 158.4496124031008, 'mean_base_fitness': 92.4251184939092, 'current_eval_count': 4900}
# 4900
# {'best_fitness': 125.27131782945736, 'mean_fitness': 71.88977408637874, 'best_base_fitness': 125.27131782945736, 'mean_base_fitness': 75.15477408637874, 'current_eval_count': 2600}
# 2600
# {'best_fitness': 143.02325581395348, 'mean_fitness': 106.92152934662236, 'best_base_fitness': 143.02325581395348, 'mean_base_fitness': 108.13652934662237, 'current_eval_count': 5000}
# {'best_fitness': 157.4496124031008, 'mean_fitness': 95.6066057585825, 'best_base_fitness': 158.4496124031008, 'mean_base_fitness': 96.0116057585825, 'current_eval_count': 5000}
# {'best_fitness': 125.27131782945736, 'mean_fitness': 78.4275542635659, 'best_base_fitness': 125.27131782945736, 'mean_base_fitness': 81.40005426356589, 'current_eval_count': 2700}
# 2700
# {'best_fitness': 133.7984496124031, 'mean_fitness': 76.66601550387597, 'best_base_fitness': 133.7984496124031, 'mean_base_fitness': 78.92101550387596, 'current_eval_count': 2800}
# 2800
# {'best_fitness': 133.7984496124031, 'mean_fitness': 84.14873588039868, 'best_base_fitness': 133.7984496124031, 'mean_base_fitness': 86.04123588039867, 'current_eval_count': 2900}
# 2900
# {'best_fitness': 133.7984496124031, 'mean_fitness': 87.46724141749723, 'best_base_fitness': 133.7984496124031, 'mean_base_fitness': 88.87724141749723, 'current_eval_count': 3000}
# 3000
# {'best_fitness': 133.7984496124031, 'mean_fitness': 88.36593798449613, 'best_base_fitness': 133.7984496124031, 'mean_base_fitness': 89.59093798449612, 'current_eval_count': 3100}
# 3100
# {'best_fitness': 133.7984496124031, 'mean_fitness': 88.20418936877077, 'best_base_fitness': 133.7984496124031, 'mean_base_fitness': 89.31918936877076, 'current_eval_count': 3200}
# 3200
# {'best_fitness': 133.7984496124031, 'mean_fitness': 90.56648837209302, 'best_base_fitness': 133.7984496124031, 'mean_base_fitness': 91.71648837209302, 'current_eval_count': 3300}
# 3300
# {'best_fitness': 133.7984496124031, 'mean_fitness': 90.83734551495017, 'best_base_fitness': 133.7984496124031, 'mean_base_fitness': 91.95234551495017, 'current_eval_count': 3400}
# 3400
# {'best_fitness': 133.7984496124031, 'mean_fitness': 88.79740919158361, 'best_base_fitness': 133.7984496124031, 'mean_base_fitness': 89.7599091915836, 'current_eval_count': 3500}
# 3500
# {'best_fitness': 133.7984496124031, 'mean_fitness': 90.57032668881506, 'best_base_fitness': 133.7984496124031, 'mean_base_fitness': 91.49532668881506, 'current_eval_count': 3600}
# 3600
# {'best_fitness': 133.7984496124031, 'mean_fitness': 90.1202607973422, 'best_base_fitness': 133.7984496124031, 'mean_base_fitness': 90.96276079734218, 'current_eval_count': 3700}
# 3700
# {'best_fitness': 139.92248062015506, 'mean_fitness': 90.92264064230343, 'best_base_fitness': 139.92248062015506, 'mean_base_fitness': 91.79014064230343, 'current_eval_count': 3800}
# 3800
# {'best_fitness': 139.92248062015506, 'mean_fitness': 87.9687342192691, 'best_base_fitness': 139.92248062015506, 'mean_base_fitness': 89.0037342192691, 'current_eval_count': 3900}
# 3900
# {'best_fitness': 139.92248062015506, 'mean_fitness': 91.45496566998892, 'best_base_fitness': 139.92248062015506, 'mean_base_fitness': 92.30996566998893, 'current_eval_count': 4000}
# 4000
# {'best_fitness': 139.92248062015506, 'mean_fitness': 90.08678571428571, 'best_base_fitness': 139.92248062015506, 'mean_base_fitness': 90.89428571428572, 'current_eval_count': 4100}
# 4100
# {'best_fitness': 142.02325581395348, 'mean_fitness': 90.90599557032115, 'best_base_fitness': 143.02325581395348, 'mean_base_fitness': 91.55099557032115, 'current_eval_count': 4200}
# 4200
# {'best_fitness': 142.02325581395348, 'mean_fitness': 94.02274141749723, 'best_base_fitness': 143.02325581395348, 'mean_base_fitness': 94.54524141749722, 'current_eval_count': 4300}
# 4300
# {'best_fitness': 142.02325581395348, 'mean_fitness': 92.05008250276855, 'best_base_fitness': 143.02325581395348, 'mean_base_fitness': 92.49258250276854, 'current_eval_count': 4400}
# 4400
# {'best_fitness': 142.02325581395348, 'mean_fitness': 95.03650276854928, 'best_base_fitness': 143.02325581395348, 'mean_base_fitness': 95.54150276854928, 'current_eval_count': 4500}
# 4500
# {'best_fitness': 142.02325581395348, 'mean_fitness': 96.37800553709856, 'best_base_fitness': 143.02325581395348, 'mean_base_fitness': 96.86300553709856, 'current_eval_count': 4600}
# 4600
# {'best_fitness': 142.02325581395348, 'mean_fitness': 97.08604817275747, 'best_base_fitness': 143.02325581395348, 'mean_base_fitness': 97.50354817275748, 'current_eval_count': 4700}
# 4700
# {'best_fitness': 142.02325581395348, 'mean_fitness': 96.34178183831672, 'best_base_fitness': 143.02325581395348, 'mean_base_fitness': 96.77678183831672, 'current_eval_count': 4800}
# 4800
# {'best_fitness': 142.02325581395348, 'mean_fitness': 98.32431339977852, 'best_base_fitness': 143.02325581395348, 'mean_base_fitness': 98.77431339977852, 'current_eval_count': 4900}
# 4900
# {'best_fitness': 142.02325581395348, 'mean_fitness': 98.19048283499446, 'best_base_fitness': 143.02325581395348, 'mean_base_fitness': 98.70048283499446, 'current_eval_count': 5000}
# Fitness: 142.02325581395348
# Base Fitness: 143.02325581395348
# Genes:
#  *
# |*
# ||/
# |||-
# ||||-2.05
# ||||W
# |||*
# ||||G
# ||||G
# ||+
# |||RAND
# ||||P
# ||||P
# |||-
# ||||P
# ||||P
# |RAND
# ||/
# |||+
# ||||P
# ||||F
# |||*
# ||||F
# ||||*
# |||||G
# |||||G
# ||-
# |||RAND
# ||||P
# ||||F
# |||RAND
# ||||P
# ||||W
#
# Fitness: 85.11627906976744
# Base Fitness: 85.11627906976744
# Genes:
#  RAND
# |W
# |G
#
# Fitness: 143.02325581395348
# Base Fitness: 143.02325581395348
# Genes:
#  /
# |RAND
# ||-
# |||0.85
# |||P
# ||+
# |||P
# |||G
# |+
# ||*
# |||P
# |||F
# ||+
# |||2.25
# |||F
#
# Fitness: 138.4496124031008
# Base Fitness: 138.4496124031008
# Genes:
#  /
# |/
# ||G
# ||RAND
# |||F
# |||P
# |RAND
# ||P
# ||P
#
# Fitness: 157.4496124031008
# Base Fitness: 158.4496124031008
# Genes:
#  *
# |/
# ||G
# ||F
# |/
# ||*
# |||3.87
# |||RAND
# ||||0.85
# ||||3.87
# ||RAND
# |||0.85
# |||P
#
# 2b data mean: 133.6124031007752
# 2b data stdv: 28.148214434361517
# 2a data mean: 107.03915836101882
# 2a data stdv: 12.97632888106883
# p-value: 0.10253922918735528

# %%
# Implement your 10-run experiment here
number_runs = 10
number_evaluations = 5000
config_filename = 'configs/2b_yellow_config.txt'

def parallel_run(i):
    return genetic_programming_search(number_evaluations, config_filename)

# Implement your 10-run experiment here
outputs = []
with Pool(processes = 10) as p:
    outputs = p.map(parallel_run, range(number_runs))

for (i, output) in enumerate(outputs):
    print('Fitness:', output['best_individual'].fitness)
    print('Base Fitness:', output['best_individual'].base_fitness)
    print('Genes:\n', output['best_individual'].genes)

# Assign your EA's log member variables here
# It should be a list containing the log from the EA in each run
run_logs = []
for (i, output) in enumerate(outputs):
    run_logs.append(output['log'])

# Writing the logs to files
os.makedirs('data/2b/yellow/logs/', exist_ok=True)
for i in range(len(run_logs)):
    with open('data/2b/yellow/logs/' + str(i+1) + '.txt', 'w') as f:
        f.write(''.join([entry + '\n' for entry in run_logs[i]]))
        
# Assign your data for statistical analysis to this variable
# It should be a list of the highest fitness values seen per run
stats_data = []
for (i, output) in enumerate(outputs):
    stats_data.append(output['best_individual'].base_fitness)

# Writing your statistical data to a file
with open('data/2b/yellow/statistics.txt', 'w') as f:
    for result in stats_data:
        f.write(str(result) + '\n')

with open('data/2b/yellow/stairstep_data.txt', 'w') as f:
    progressions = []
    for output in outputs:
        progressions.append(output['score_progression'])
    f.write(str(progressions))
# Out:
# {'DEFAULT': {}, 'ea': {'mu': 400, 'num_children': 100, 'mutation_rate': 0.2, 'parent_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'survival_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'individual_class': <class 'tree_genotype.TreeGenotype'>}, 'parent_selection_kwargs': {'k': 1}, 'survival_selection_kwargs': {'k': 1}, 'problem': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'recombination_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'mutation_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'fitness_kwargs': {'parsimony_coefficient': 0.5, 'experiment': 'yellow'}, 'game': {'game_map': 'map.txt', 'pill_spawn': 'waves', 'pill_density': 0.3333333333333333, 'fruit_prob': 0.013333333333333334, 'fruit_score': 10, 'fruit_spawn': 'corners_spawned', 'time_multiplier': 2.5, 'num_pacs': 1, 'num_ghosts': 3}}{'DEFAULT': {}, 'ea': {'mu': 400, 'num_children': 100, 'mutation_rate': 0.2, 'parent_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'survival_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'individual_class': <class 'tree_genotype.TreeGenotype'>}, 'parent_selection_kwargs': {'k': 1}, 'survival_selection_kwargs': {'k': 1}, 'problem': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'recombination_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'mutation_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'fitness_kwargs': {'parsimony_coefficient': 0.5, 'experiment': 'yellow'}, 'game': {'game_map': 'map.txt', 'pill_spawn': 'waves', 'pill_density': 0.3333333333333333, 'fruit_prob': 0.013333333333333334, 'fruit_score': 10, 'fruit_spawn': 'corners_spawned', 'time_multiplier': 2.5, 'num_pacs': 1, 'num_ghosts': 3}}{'DEFAULT': {}, 'ea': {'mu': 400, 'num_children': 100, 'mutation_rate': 0.2, 'parent_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'survival_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'individual_class': <class 'tree_genotype.TreeGenotype'>}, 'parent_selection_kwargs': {'k': 1}, 'survival_selection_kwargs': {'k': 1}, 'problem': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'recombination_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'mutation_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'fitness_kwargs': {'parsimony_coefficient': 0.5, 'experiment': 'yellow'}, 'game': {'game_map': 'map.txt', 'pill_spawn': 'waves', 'pill_density': 0.3333333333333333, 'fruit_prob': 0.013333333333333334, 'fruit_score': 10, 'fruit_spawn': 'corners_spawned', 'time_multiplier': 2.5, 'num_pacs': 1, 'num_ghosts': 3}}{'DEFAULT': {}, 'ea': {'mu': 400, 'num_children': 100, 'mutation_rate': 0.2, 'parent_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'survival_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'individual_class': <class 'tree_genotype.TreeGenotype'>}, 'parent_selection_kwargs': {'k': 1}, 'survival_selection_kwargs': {'k': 1}, 'problem': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'recombination_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'mutation_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'fitness_kwargs': {'parsimony_coefficient': 0.5, 'experiment': 'yellow ...
# {'DEFAULT': {}, 'ea': {'mu': 400, 'num_children': 100, 'mutation_rate': 0.2, 'parent_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'survival_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'individual_class': <class 'tree_genotype.TreeGenotype'>}, 'parent_selection_kwargs': {'k': 1}, 'survival_selection_kwargs': {'k': 1}, 'problem': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'recombination_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'mutation_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'fitness_kwargs': {'parsimony_coefficient': 0.5, 'experiment': 'yellow'}, 'game': {'game_map': 'map.txt', 'pill_spawn': 'waves', 'pill_density': 0.3333333333333333, 'fruit_prob': 0.013333333333333334, 'fruit_score': 10, 'fruit_spawn': 'corners_spawned', 'time_multiplier': 2.5, 'num_pacs': 1, 'num_ghosts': 3}}{'DEFAULT': {}, 'ea': {'mu': 400, 'num_children': 100, 'mutation_rate': 0.2, 'parent_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'survival_selection': <function fitness_proportionate_selection at 0x7f8bac32d760>, 'individual_class': <class 'tree_genotype.TreeGenotype'>}, 'parent_selection_kwargs': {'k': 1}, 'survival_selection_kwargs': {'k': 1}, 'problem': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'recombination_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'mutation_kwargs': {'depth_limit': 7, 'terminals': ('G', 'P', 'F', 'W', 'C'), 'nonterminals': ('+', '-', '*', '/', 'RAND')}, 'fitness_kwargs': {'parsimony_coefficient': 0.5, 'experiment': 'yellow'}, 'game': {'game_map': 'map.txt', 'pill_spawn': 'waves', 'pill_density': 0.3333333333333333, 'fruit_prob': 0.013333333333333334, 'fruit_score': 10, 'fruit_spawn': 'corners_spawned', 'time_multiplier': 2.5, 'num_pacs': 1, 'num_ghosts': 3}}
#
#
#
#
#
#
#
#
#
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# {'best_fitness': 55.65891472868217, 'mean_fitness': -15.95723588039867, 'best_base_fitness': 55.65891472868217, 'mean_base_fitness': -11.78723588039867, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 13.615, 'current_eval_count': 500}
# 500
# 400
# {'best_fitness': 38.7906976744186, 'mean_fitness': -9.90909080841639, 'best_base_fitness': 62.7906976744186, 'mean_base_fitness': -6.79409080841639, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 13.73, 'current_eval_count': 500}
# 500
# 400
# {'best_fitness': 71.16279069767441, 'mean_fitness': -11.064323366555925, 'best_base_fitness': 71.16279069767441, 'mean_base_fitness': -6.474323366555925, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 18.71, 'current_eval_count': 500}
# 500
# {'best_fitness': 58.86046511627907, 'mean_fitness': -16.35535382059801, 'best_base_fitness': 61.86046511627907, 'mean_base_fitness': -12.667853820598006, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 14.665, 'current_eval_count': 500}
# 500
# {'best_fitness': 55.65891472868217, 'mean_fitness': -6.265064784053156, 'best_base_fitness': 55.65891472868217, 'mean_base_fitness': -3.422564784053156, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 9.785, 'current_eval_count': 600}
# 600
# {'best_fitness': 83.08925802879291, 'mean_fitness': -15.893281838316723, 'best_base_fitness': 99.08925802879291, 'mean_base_fitness': -10.880781838316722, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 22.15, 'current_eval_count': 500}
# 500
# {'best_fitness': 44.18604651162791, 'mean_fitness': -20.021616832779625, 'best_base_fitness': 54.18604651162791, 'mean_base_fitness': -15.691616832779623, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 14.92, 'current_eval_count': 500}
# 500
# {'best_fitness': 88.29457364341086, 'mean_fitness': -16.55225138427464, 'best_base_fitness': 88.29457364341086, 'mean_base_fitness': -11.29725138427464, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 18.81, 'current_eval_count': 500}
# 500
# {'best_fitness': 4.558139534883722, 'mean_fitness': -18.27281727574751, 'best_base_fitness': 52.55813953488372, 'mean_base_fitness': -13.39281727574751, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 18.495, 'current_eval_count': 500}
# 500
# {'best_fitness': 38.7906976744186, 'mean_fitness': -0.6057475083056479, 'best_base_fitness': 62.7906976744186, 'mean_base_fitness': 2.484252491694352, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 13.67, 'current_eval_count': 600}
# 600
# {'best_fitness': 49.06976744186046, 'mean_fitness': -20.331392026578072, 'best_base_fitness': 79.06976744186046, 'mean_base_fitness': -14.391392026578073, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 18.855, 'current_eval_count': 500}
# 500
# {'best_fitness': 57.2093023255814, 'mean_fitness': 0.49055980066445204, 'best_base_fitness': 57.2093023255814, 'mean_base_fitness': 2.853059800664452, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 8.485, 'current_eval_count': 700}
# 700
# {'best_fitness': 71.16279069767441, 'mean_fitness': -3.45131284606866, 'best_base_fitness': 71.16279069767441, 'mean_base_fitness': -0.5088128460686604, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 16.565, 'current_eval_count': 600}
# 600
# {'best_fitness': 52.6124031007752, 'mean_fitness': -24.427705980066445, 'best_base_fitness': 59.6124031007752, 'mean_base_fitness': -16.790205980066446, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 27.79, 'current_eval_count': 500}
# 500
# {'best_fitness': 53.89147286821705, 'mean_fitness': -6.151084717607973, 'best_base_fitness': 65.89147286821705, 'mean_base_fitness': -3.1235847176079736, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 12.68, 'current_eval_count': 600}
# 600
# {'best_fitness': 44.18604651162791, 'mean_fitness': -11.062475636766335, 'best_base_fitness': 54.18604651162791, 'mean_base_fitness': -7.549975636766335, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 13.505, 'current_eval_count': 600}
# 600
# {'best_fitness': 4.558139534883722, 'mean_fitness': -6.871523255813954, 'best_base_fitness': 52.55813953488372, 'mean_base_fitness': -3.3390232558139537, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 15.15, 'current_eval_count': 600}
# 600
# {'best_fitness': 83.08925802879291, 'mean_fitness': -6.868475083056478, 'best_base_fitness': 99.08925802879291, 'mean_base_fitness': -3.4634750830564784, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 16.305, 'current_eval_count': 600}
# 600
# {'best_fitness': 88.29457364341086, 'mean_fitness': -6.135703765227021, 'best_base_fitness': 88.29457364341086, 'mean_base_fitness': -3.768203765227021, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 11.61, 'current_eval_count': 600}
# 600
# {'best_fitness': 57.2093023255814, 'mean_fitness': 5.383513842746401, 'best_base_fitness': 57.2093023255814, 'mean_base_fitness': 7.503513842746401, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 8.41, 'current_eval_count': 800}
# 800
# {'best_fitness': 38.7906976744186, 'mean_fitness': 3.937206533776301, 'best_base_fitness': 62.7906976744186, 'mean_base_fitness': 6.724706533776302, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 13.225, 'current_eval_count': 700}
# 700
# {'best_fitness': 55.71317829457365, 'mean_fitness': 3.4353399778516054, 'best_base_fitness': 102.71317829457365, 'mean_base_fitness': 6.5753399778516055, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 16.705, 'current_eval_count': 700}
# 700
# {'best_fitness': 56.82170542635659, 'mean_fitness': -11.663877630121815, 'best_base_fitness': 86.82170542635659, 'mean_base_fitness': -6.366377630121816, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 17.68, 'current_eval_count': 600}
# 600
# {'best_fitness': 88.29457364341086, 'mean_fitness': 0.7545459579180511, 'best_base_fitness': 88.29457364341086, 'mean_base_fitness': 2.419545957918051, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 10.195, 'current_eval_count': 700}
# 700
# {'best_fitness': 76.66666666666667, 'mean_fitness': -15.073348283499447, 'best_base_fitness': 76.66666666666667, 'mean_base_fitness': -9.860848283499447, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 22.515, 'current_eval_count': 600}
# 600
# {'best_fitness': 57.2093023255814, 'mean_fitness': 9.143589700996678, 'best_base_fitness': 57.2093023255814, 'mean_base_fitness': 10.696089700996678, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 7.085, 'current_eval_count': 900}
# 900
# {'best_fitness': 67.44186046511628, 'mean_fitness': -1.204656699889258, 'best_base_fitness': 67.44186046511628, 'mean_base_fitness': 1.780343300110742, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 11.4, 'current_eval_count': 700}
# 700
# {'best_fitness': 83.08925802879291, 'mean_fitness': -2.4840448504983392, 'best_base_fitness': 99.08925802879291, 'mean_base_fitness': 0.27845514950166095, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 11.78, 'current_eval_count': 700}
# 700
# {'best_fitness': 61.16279069767442, 'mean_fitness': -1.112361018826135, 'best_base_fitness': 61.16279069767442, 'mean_base_fitness': 2.002638981173865, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 13.705, 'current_eval_count': 700}
# 700
# {'best_fitness': 4.558139534883722, 'mean_fitness': -2.2692408637873758, 'best_base_fitness': 52.55813953488372, 'mean_base_fitness': 1.4382591362126245, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 16.305, 'current_eval_count': 700}
# 700
# {'best_fitness': 88.29457364341086, 'mean_fitness': 4.928596899224806, 'best_base_fitness': 88.29457364341086, 'mean_base_fitness': 6.608596899224806, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 8.725, 'current_eval_count': 800}
# 800
# {'best_fitness': 55.71317829457365, 'mean_fitness': 6.697684939091916, 'best_base_fitness': 102.71317829457365, 'mean_base_fitness': 9.400184939091917, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 16.76, 'current_eval_count': 800}
# 800
# {'best_fitness': 38.7906976744186, 'mean_fitness': 10.499642303433001, 'best_base_fitness': 62.7906976744186, 'mean_base_fitness': 12.759642303433, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 13.23, 'current_eval_count': 800}
# 800
# {'best_fitness': 76.66666666666667, 'mean_fitness': -7.734405315614618, 'best_base_fitness': 76.66666666666667, 'mean_base_fitness': -3.724405315614618, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 17.08, 'current_eval_count': 700}
# 700
# {'best_fitness': 83.08925802879291, 'mean_fitness': 9.150045404208194, 'best_base_fitness': 99.08925802879291, 'mean_base_fitness': 10.830045404208194, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 8.515, 'current_eval_count': 800}
# 800
# {'best_fitness': 66.53488372093022, 'mean_fitness': 11.958689368770765, 'best_base_fitness': 69.53488372093022, 'mean_base_fitness': 13.331189368770763, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 7.28, 'current_eval_count': 1000}
# 1000
# {'best_fitness': 56.82170542635659, 'mean_fitness': -2.943420819490587, 'best_base_fitness': 86.82170542635659, 'mean_base_fitness': 0.921579180509413, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 14.735, 'current_eval_count': 700}
# 700
# {'best_fitness': 61.16279069767442, 'mean_fitness': 4.870161129568106, 'best_base_fitness': 61.16279069767442, 'mean_base_fitness': 8.102661129568107, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 13.765, 'current_eval_count': 800}
# 800
# {'best_fitness': 67.44186046511628, 'mean_fitness': 3.587673864894795, 'best_base_fitness': 67.44186046511628, 'mean_base_fitness': 6.745173864894795, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 11.93, 'current_eval_count': 800}
# 800
# {'best_fitness': 66.53488372093022, 'mean_fitness': 14.230119047619047, 'best_base_fitness': 69.53488372093022, 'mean_base_fitness': 15.427619047619048, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 5.91, 'current_eval_count': 1100}
# 1100
# {'best_fitness': 88.29457364341086, 'mean_fitness': 8.243861572535991, 'best_base_fitness': 88.29457364341086, 'mean_base_fitness': 10.023861572535992, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 9.16, 'current_eval_count': 900}
# 900
# {'best_fitness': 4.558139534883722, 'mean_fitness': 2.3410885935769654, 'best_base_fitness': 52.55813953488372, 'mean_base_fitness': 6.226088593576965, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 16.465, 'current_eval_count': 800}
# 800
# {'best_fitness': 83.08925802879291, 'mean_fitness': 17.564771871539314, 'best_base_fitness': 99.08925802879291, 'mean_base_fitness': 19.739771871539315, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 9.735, 'current_eval_count': 900}
# 900
# {'best_fitness': 55.71317829457365, 'mean_fitness': 7.6116511627906975, 'best_base_fitness': 102.71317829457365, 'mean_base_fitness': 10.521651162790697, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 16.225, 'current_eval_count': 900}
# 900
# {'best_fitness': 85.11627906976744, 'mean_fitness': 1.226108527131783, 'best_base_fitness': 85.11627906976744, 'mean_base_fitness': 4.031108527131783, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 12.46, 'current_eval_count': 800}
# 800
# {'best_fitness': 86.91472868217053, 'mean_fitness': 13.38007253599114, 'best_base_fitness': 88.91472868217053, 'mean_base_fitness': 16.06257253599114, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 12.655, 'current_eval_count': 900}
# 900
# {'best_fitness': 66.53488372093022, 'mean_fitness': 14.682041528239203, 'best_base_fitness': 69.53488372093022, 'mean_base_fitness': 15.529541528239202, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 4.795, 'current_eval_count': 1200}
# 1200
# {'best_fitness': 67.44186046511628, 'mean_fitness': 6.704016611295681, 'best_base_fitness': 67.44186046511628, 'mean_base_fitness': 9.50401661129568, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 11.325, 'current_eval_count': 900}
# 900
# {'best_fitness': 56.82170542635659, 'mean_fitness': 2.2606002214839425, 'best_base_fitness': 86.82170542635659, 'mean_base_fitness': 5.250600221483943, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 11.18, 'current_eval_count': 800}
# 800
# {'best_fitness': 61.16279069767442, 'mean_fitness': 4.122356589147287, 'best_base_fitness': 61.16279069767442, 'mean_base_fitness': 7.237356589147287, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 12.5, 'current_eval_count': 900}
# 900
# {'best_fitness': 83.08925802879291, 'mean_fitness': 21.499718715393133, 'best_base_fitness': 99.08925802879291, 'mean_base_fitness': 23.709718715393134, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 10.235, 'current_eval_count': 1000}
# 1000
# {'best_fitness': 66.53488372093022, 'mean_fitness': 16.516297895902547, 'best_base_fitness': 69.53488372093022, 'mean_base_fitness': 17.22129789590255, 'minimum_size': 1, 'maximum_size': 33, 'mean_size': 3.68, 'current_eval_count': 1300}
# 1300
# {'best_fitness': 88.29457364341086, 'mean_fitness': 12.22033388704319, 'best_base_fitness': 88.29457364341086, 'mean_base_fitness': 13.89283388704319, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 8.7, 'current_eval_count': 1000}
# 1000
# {'best_fitness': 85.11627906976744, 'mean_fitness': 13.434665559246955, 'best_base_fitness': 85.11627906976744, 'mean_base_fitness': 15.179665559246954, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 11.175, 'current_eval_count': 900}
# 900
# {'best_fitness': 71.06976744186046, 'mean_fitness': 3.4632779623477297, 'best_base_fitness': 79.06976744186046, 'mean_base_fitness': 8.07327796234773, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 17.39, 'current_eval_count': 900}
# 900
# {'best_fitness': 86.91472868217053, 'mean_fitness': 20.007153931339978, 'best_base_fitness': 88.91472868217053, 'mean_base_fitness': 22.552153931339976, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 13.77, 'current_eval_count': 1000}
# 1000
# {'best_fitness': 92.85249169435215, 'mean_fitness': 8.595734219269103, 'best_base_fitness': 95.85249169435215, 'mean_base_fitness': 10.970734219269103, 'minimum_size': 1, 'maximum_size': 125, 'mean_size': 10.73, 'current_eval_count': 900}
# 900
# {'best_fitness': 67.44186046511628, 'mean_fitness': 11.277670542635658, 'best_base_fitness': 67.44186046511628, 'mean_base_fitness': 14.27017054263566, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 13.11, 'current_eval_count': 1000}
# 1000
# {'best_fitness': 66.53488372093022, 'mean_fitness': 19.718151162790697, 'best_base_fitness': 69.53488372093022, 'mean_base_fitness': 20.385651162790698, 'minimum_size': 1, 'maximum_size': 29, 'mean_size': 3.445, 'current_eval_count': 1400}
# 1400
# {'best_fitness': 83.08925802879291, 'mean_fitness': 24.632885935769657, 'best_base_fitness': 99.08925802879291, 'mean_base_fitness': 26.987885935769658, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 10.11, 'current_eval_count': 1100}
# 1100
# {'best_fitness': 104.1937984496124, 'mean_fitness': 8.81611572535991, 'best_base_fitness': 115.1937984496124, 'mean_base_fitness': 11.758615725359912, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 15.43, 'current_eval_count': 1000}
# 1000
# {'best_fitness': 88.29457364341086, 'mean_fitness': 14.171483942414175, 'best_base_fitness': 88.29457364341086, 'mean_base_fitness': 15.576483942414175, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 7.77, 'current_eval_count': 1100}
# 1100
# {'best_fitness': 61.16279069767442, 'mean_fitness': 7.328045404208195, 'best_base_fitness': 61.16279069767442, 'mean_base_fitness': 10.518045404208195, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 13.315, 'current_eval_count': 1000}
# 1000
# {'best_fitness': 70.3875968992248, 'mean_fitness': 21.106819490586933, 'best_base_fitness': 70.3875968992248, 'mean_base_fitness': 21.821819490586932, 'minimum_size': 1, 'maximum_size': 15, 'mean_size': 3.6, 'current_eval_count': 1500}
# 1500
# {'best_fitness': 83.08925802879291, 'mean_fitness': 27.430019933554817, 'best_base_fitness': 99.08925802879291, 'mean_base_fitness': 30.020019933554817, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 10.78, 'current_eval_count': 1200}
# 1200
# {'best_fitness': 92.85249169435215, 'mean_fitness': 11.703250830564784, 'best_base_fitness': 95.85249169435215, 'mean_base_fitness': 14.185750830564784, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 10.79, 'current_eval_count': 1000}
# 1000
# {'best_fitness': 85.11627906976744, 'mean_fitness': 16.758330564784053, 'best_base_fitness': 85.11627906976744, 'mean_base_fitness': 18.015830564784054, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 10.81, 'current_eval_count': 1000}
# 1000
# {'best_fitness': 86.91472868217053, 'mean_fitness': 24.033292912513843, 'best_base_fitness': 88.91472868217053, 'mean_base_fitness': 26.850792912513842, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 14.49, 'current_eval_count': 1100}
# 1100
# {'best_fitness': 61.09302325581395, 'mean_fitness': 15.18693300110742, 'best_base_fitness': 72.09302325581395, 'mean_base_fitness': 18.42943300110742, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 13.505, 'current_eval_count': 1100}
# 1100
# {'best_fitness': 70.3875968992248, 'mean_fitness': 21.90616334440753, 'best_base_fitness': 70.3875968992248, 'mean_base_fitness': 22.59866334440753, 'minimum_size': 1, 'maximum_size': 13, 'mean_size': 3.605, 'current_eval_count': 1600}
# 1600
# {'best_fitness': 71.06976744186046, 'mean_fitness': 2.531880952380952, 'best_base_fitness': 79.06976744186046, 'mean_base_fitness': 6.709380952380952, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 15.605, 'current_eval_count': 1000}
# 1000
# {'best_fitness': 88.29457364341086, 'mean_fitness': 18.591762458471763, 'best_base_fitness': 88.29457364341086, 'mean_base_fitness': 19.87926245847176, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 8.11, 'current_eval_count': 1200}
# 1200
# {'best_fitness': 104.1937984496124, 'mean_fitness': 15.067312292358803, 'best_base_fitness': 115.1937984496124, 'mean_base_fitness': 17.857312292358802, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 13.93, 'current_eval_count': 1100}
# 1100
# {'best_fitness': 61.16279069767442, 'mean_fitness': 9.222867109634551, 'best_base_fitness': 61.16279069767442, 'mean_base_fitness': 12.562867109634551, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 13.41, 'current_eval_count': 1100}
# 1100
# {'best_fitness': 74.24872646733112, 'mean_fitness': 22.663117940199335, 'best_base_fitness': 75.24872646733112, 'mean_base_fitness': 23.410617940199337, 'minimum_size': 1, 'maximum_size': 13, 'mean_size': 3.69, 'current_eval_count': 1700}
# 1700
# {'best_fitness': 83.08925802879291, 'mean_fitness': 30.092563676633443, 'best_base_fitness': 99.08925802879291, 'mean_base_fitness': 33.727563676633444, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 13.315, 'current_eval_count': 1300}
# 1300
# {'best_fitness': 92.85249169435215, 'mean_fitness': 17.87103322259136, 'best_base_fitness': 95.85249169435215, 'mean_base_fitness': 20.76603322259136, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 11.945, 'current_eval_count': 1100}
# 1100
# {'best_fitness': 86.91472868217053, 'mean_fitness': 25.178661683277962, 'best_base_fitness': 88.91472868217053, 'mean_base_fitness': 27.826161683277963, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 14.65, 'current_eval_count': 1200}
# 1200
# {'best_fitness': 74.24872646733112, 'mean_fitness': 24.230240863787376, 'best_base_fitness': 75.24872646733112, 'mean_base_fitness': 24.957740863787375, 'minimum_size': 1, 'maximum_size': 13, 'mean_size': 3.53, 'current_eval_count': 1800}
# 1800
# {'best_fitness': 88.29457364341086, 'mean_fitness': 22.804020487264673, 'best_base_fitness': 88.29457364341086, 'mean_base_fitness': 24.146520487264674, 'minimum_size': 1, 'maximum_size': 31, 'mean_size': 8.93, 'current_eval_count': 1300}
# 1300
# {'best_fitness': 61.09302325581395, 'mean_fitness': 18.122674972314506, 'best_base_fitness': 72.09302325581395, 'mean_base_fitness': 21.195174972314508, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 12.12, 'current_eval_count': 1200}
# 1200
# {'best_fitness': 98.37209302325581, 'mean_fitness': 19.595732558139535, 'best_base_fitness': 98.37209302325581, 'mean_base_fitness': 21.038232558139534, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 11.755, 'current_eval_count': 1100}
# 1100
# {'best_fitness': 68.81395348837209, 'mean_fitness': 12.98305869324474, 'best_base_fitness': 75.81395348837209, 'mean_base_fitness': 15.37305869324474, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 11.575, 'current_eval_count': 1200}
# 1200
# {'best_fitness': 117.59689922480621, 'mean_fitness': 7.785734219269103, 'best_base_fitness': 117.59689922480621, 'mean_base_fitness': 11.860734219269103, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 15.22, 'current_eval_count': 1100}
# 1100
# {'best_fitness': 83.08925802879291, 'mean_fitness': 32.10334828349944, 'best_base_fitness': 99.08925802879291, 'mean_base_fitness': 36.16084828349945, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 14.155, 'current_eval_count': 1400}
# 1400
# {'best_fitness': 74.24872646733112, 'mean_fitness': 22.88462126245847, 'best_base_fitness': 75.24872646733112, 'mean_base_fitness': 23.534621262458472, 'minimum_size': 1, 'maximum_size': 13, 'mean_size': 3.44, 'current_eval_count': 1900}
# 1900
# {'best_fitness': 104.1937984496124, 'mean_fitness': 19.701953488372094, 'best_base_fitness': 115.1937984496124, 'mean_base_fitness': 22.021953488372095, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 11.29, 'current_eval_count': 1200}
# 1200
# {'best_fitness': 88.29457364341086, 'mean_fitness': 27.55383111849391, 'best_base_fitness': 88.29457364341086, 'mean_base_fitness': 29.01133111849391, 'minimum_size': 1, 'maximum_size': 31, 'mean_size': 10.555, 'current_eval_count': 1400}
# 1400
# {'best_fitness': 90.3875968992248, 'mean_fitness': 26.565475083056477, 'best_base_fitness': 90.3875968992248, 'mean_base_fitness': 29.46047508305648, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 13.51, 'current_eval_count': 1300}
# 1300
# {'best_fitness': 68.81395348837209, 'mean_fitness': 15.302679401993355, 'best_base_fitness': 75.81395348837209, 'mean_base_fitness': 17.705179401993355, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 11.83, 'current_eval_count': 1300}
# 1300
# {'best_fitness': 74.24872646733112, 'mean_fitness': 24.14247619047619, 'best_base_fitness': 75.24872646733112, 'mean_base_fitness': 24.85747619047619, 'minimum_size': 1, 'maximum_size': 13, 'mean_size': 3.64, 'current_eval_count': 2000}
# 2000
# {'best_fitness': 92.85249169435215, 'mean_fitness': 23.513746400885935, 'best_base_fitness': 95.85249169435215, 'mean_base_fitness': 27.398746400885937, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 14.355, 'current_eval_count': 1200}
# 1200
# {'best_fitness': 61.09302325581395, 'mean_fitness': 20.46178626799557, 'best_base_fitness': 72.09302325581395, 'mean_base_fitness': 23.50178626799557, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 12.465, 'current_eval_count': 1300}
# 1300
# {'best_fitness': 74.54263565891473, 'mean_fitness': 33.52890753045404, 'best_base_fitness': 100.54263565891473, 'mean_base_fitness': 38.27140753045404, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 16.19, 'current_eval_count': 1500}
# 1500
# {'best_fitness': 88.29457364341086, 'mean_fitness': 34.64985991140642, 'best_base_fitness': 88.29457364341086, 'mean_base_fitness': 36.27735991140642, 'minimum_size': 1, 'maximum_size': 31, 'mean_size': 11.925, 'current_eval_count': 1500}
# 1500
# {'best_fitness': 117.59689922480621, 'mean_fitness': 5.626673864894795, 'best_base_fitness': 117.59689922480621, 'mean_base_fitness': 9.429173864894794, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 14.7, 'current_eval_count': 1200}
# 1200
# {'best_fitness': 79.84496124031008, 'mean_fitness': 25.279875968992247, 'best_base_fitness': 79.84496124031008, 'mean_base_fitness': 26.08987596899225, 'minimum_size': 1, 'maximum_size': 13, 'mean_size': 3.8, 'current_eval_count': 2100}
# 2100
# {'best_fitness': 104.1937984496124, 'mean_fitness': 20.14844573643411, 'best_base_fitness': 115.1937984496124, 'mean_base_fitness': 22.12094573643411, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 10.72, 'current_eval_count': 1300}
# 1300
# {'best_fitness': 113.34883720930233, 'mean_fitness': 21.70832834994463, 'best_base_fitness': 115.34883720930233, 'mean_base_fitness': 23.39082834994463, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 12.05, 'current_eval_count': 1200}
# 1200
# {'best_fitness': 68.81395348837209, 'mean_fitness': 17.80546068660022, 'best_base_fitness': 75.81395348837209, 'mean_base_fitness': 20.98546068660022, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 12.55, 'current_eval_count': 1400}
# 1400
# {'best_fitness': 78.7906976744186, 'mean_fitness': 25.74325138427464, 'best_base_fitness': 82.7906976744186, 'mean_base_fitness': 26.50825138427464, 'minimum_size': 1, 'maximum_size': 11, 'mean_size': 3.55, 'current_eval_count': 2200}
# 2200
# {'best_fitness': 72.68992248062015, 'mean_fitness': 22.31388150609081, 'best_base_fitness': 79.68992248062015, 'mean_base_fitness': 25.263881506090808, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 12.365, 'current_eval_count': 1400}
# 1400
# {'best_fitness': 90.3875968992248, 'mean_fitness': 27.63796677740864, 'best_base_fitness': 90.3875968992248, 'mean_base_fitness': 30.21296677740864, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 13.11, 'current_eval_count': 1400}
# 1400
# {'best_fitness': 74.54263565891473, 'mean_fitness': 36.241872646733114, 'best_base_fitness': 100.54263565891473, 'mean_base_fitness': 40.30187264673311, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 15.8, 'current_eval_count': 1600}
# 1600
# {'best_fitness': 88.29457364341086, 'mean_fitness': 36.955306755260246, 'best_base_fitness': 88.29457364341086, 'mean_base_fitness': 38.95030675526024, 'minimum_size': 1, 'maximum_size': 31, 'mean_size': 13.545, 'current_eval_count': 1600}
# 1600
# {'best_fitness': 104.1937984496124, 'mean_fitness': 21.174253045404207, 'best_base_fitness': 115.1937984496124, 'mean_base_fitness': 23.376753045404207, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 10.525, 'current_eval_count': 1400}
# 1400
# {'best_fitness': 78.7906976744186, 'mean_fitness': 26.879357142857142, 'best_base_fitness': 82.7906976744186, 'mean_base_fitness': 27.546857142857142, 'minimum_size': 1, 'maximum_size': 11, 'mean_size': 3.35, 'current_eval_count': 2300}
# 2300
# {'best_fitness': 92.85249169435215, 'mean_fitness': 31.28087541528239, 'best_base_fitness': 95.85249169435215, 'mean_base_fitness': 35.33337541528239, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 17.58, 'current_eval_count': 1300}
# 1300
# {'best_fitness': 117.59689922480621, 'mean_fitness': 12.87758527131783, 'best_base_fitness': 117.59689922480621, 'mean_base_fitness': 16.47508527131783, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 14.31, 'current_eval_count': 1300}
# 1300
# {'best_fitness': 113.34883720930233, 'mean_fitness': 22.27428183831672, 'best_base_fitness': 115.34883720930233, 'mean_base_fitness': 24.026781838316722, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 9.605, 'current_eval_count': 1300}
# 1300
# {'best_fitness': 68.81395348837209, 'mean_fitness': 18.885986157253598, 'best_base_fitness': 75.81395348837209, 'mean_base_fitness': 22.5334861572536, 'minimum_size': 1, 'maximum_size': 125, 'mean_size': 12.335, 'current_eval_count': 1500}
# 1500
# {'best_fitness': 83.09302325581395, 'mean_fitness': 24.603405869324472, 'best_base_fitness': 92.09302325581395, 'mean_base_fitness': 27.590905869324473, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 11.675, 'current_eval_count': 1500}
# 1500
# {'best_fitness': 78.7906976744186, 'mean_fitness': 27.660421373200442, 'best_base_fitness': 82.7906976744186, 'mean_base_fitness': 28.347921373200442, 'minimum_size': 1, 'maximum_size': 11, 'mean_size': 3.535, 'current_eval_count': 2400}
# 2400
# {'best_fitness': 90.3875968992248, 'mean_fitness': 30.78727519379845, 'best_base_fitness': 90.3875968992248, 'mean_base_fitness': 33.42977519379845, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 12.82, 'current_eval_count': 1500}
# 1500
# {'best_fitness': 81.21705426356588, 'mean_fitness': 39.04797176079734, 'best_base_fitness': 108.21705426356588, 'mean_base_fitness': 42.86547176079734, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 15.99, 'current_eval_count': 1700}
# 1700
# {'best_fitness': 88.29457364341086, 'mean_fitness': 43.57050996677741, 'best_base_fitness': 88.29457364341086, 'mean_base_fitness': 45.48300996677741, 'minimum_size': 1, 'maximum_size': 31, 'mean_size': 16.265, 'current_eval_count': 1700}
# 1700
# {'best_fitness': 78.7906976744186, 'mean_fitness': 28.16072646733112, 'best_base_fitness': 82.7906976744186, 'mean_base_fitness': 28.91072646733112, 'minimum_size': 1, 'maximum_size': 11, 'mean_size': 3.715, 'current_eval_count': 2500}
# 2500
# {'best_fitness': 117.59689922480621, 'mean_fitness': 14.960068660022149, 'best_base_fitness': 117.59689922480621, 'mean_base_fitness': 18.195068660022148, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 13.865, 'current_eval_count': 1400}
# 1400
# {'best_fitness': 113.34883720930233, 'mean_fitness': 32.94166888150609, 'best_base_fitness': 115.34883720930233, 'mean_base_fitness': 34.23166888150609, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 9.565, 'current_eval_count': 1400}
# 1400
# {'best_fitness': 104.1937984496124, 'mean_fitness': 26.899614064230345, 'best_base_fitness': 115.1937984496124, 'mean_base_fitness': 29.222114064230343, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 12.475, 'current_eval_count': 1500}
# 1500
# {'best_fitness': 68.81395348837209, 'mean_fitness': 20.2237430786268, 'best_base_fitness': 75.81395348837209, 'mean_base_fitness': 23.733743078626798, 'minimum_size': 1, 'maximum_size': 125, 'mean_size': 12.43, 'current_eval_count': 1600}
# 1600
# {'best_fitness': 109.34883720930233, 'mean_fitness': 26.377907530454042, 'best_base_fitness': 115.34883720930233, 'mean_base_fitness': 29.610407530454044, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 12.185, 'current_eval_count': 1600}
# 1600
# {'best_fitness': 78.7906976744186, 'mean_fitness': 29.39366223698782, 'best_base_fitness': 82.7906976744186, 'mean_base_fitness': 30.10866223698782, 'minimum_size': 1, 'maximum_size': 11, 'mean_size': 3.705, 'current_eval_count': 2600}
# 2600
# {'best_fitness': 81.21705426356588, 'mean_fitness': 36.72589091915836, 'best_base_fitness': 108.21705426356588, 'mean_base_fitness': 40.52339091915836, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 14.83, 'current_eval_count': 1800}
# 1800
# {'best_fitness': 90.3875968992248, 'mean_fitness': 33.117643410852715, 'best_base_fitness': 90.3875968992248, 'mean_base_fitness': 35.657643410852714, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 10.94, 'current_eval_count': 1600}
# 1600
# {'best_fitness': 78.7906976744186, 'mean_fitness': 29.92658084163898, 'best_base_fitness': 82.7906976744186, 'mean_base_fitness': 30.62908084163898, 'minimum_size': 1, 'maximum_size': 11, 'mean_size': 3.705, 'current_eval_count': 2700}
# 2700
# {'best_fitness': 88.29457364341086, 'mean_fitness': 48.387426910299006, 'best_base_fitness': 88.29457364341086, 'mean_base_fitness': 50.284926910299006, 'minimum_size': 1, 'maximum_size': 31, 'mean_size': 17.52, 'current_eval_count': 1800}
# 1800
# {'best_fitness': 113.34883720930233, 'mean_fitness': 31.86093964562569, 'best_base_fitness': 115.34883720930233, 'mean_base_fitness': 33.25343964562569, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 9.735, 'current_eval_count': 1500}
# 1500
# {'best_fitness': 104.1937984496124, 'mean_fitness': 30.28184662236988, 'best_base_fitness': 115.1937984496124, 'mean_base_fitness': 32.55434662236988, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 14.375, 'current_eval_count': 1600}
# 1600
# {'best_fitness': 68.81395348837209, 'mean_fitness': 20.431454595791806, 'best_base_fitness': 75.81395348837209, 'mean_base_fitness': 23.518954595791804, 'minimum_size': 1, 'maximum_size': 125, 'mean_size': 12.1, 'current_eval_count': 1700}
# 1700
# {'best_fitness': 117.59689922480621, 'mean_fitness': 16.29067829457364, 'best_base_fitness': 117.59689922480621, 'mean_base_fitness': 19.378178294573644, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 14.325, 'current_eval_count': 1500}
# 1500
# {'best_fitness': 99.92248062015504, 'mean_fitness': 35.62154485049834, 'best_base_fitness': 99.92248062015504, 'mean_base_fitness': 39.656544850498335, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 20.42, 'current_eval_count': 1400}
# 1400
# {'best_fitness': 78.7906976744186, 'mean_fitness': 30.709194352159468, 'best_base_fitness': 82.7906976744186, 'mean_base_fitness': 31.40669435215947, 'minimum_size': 1, 'maximum_size': 11, 'mean_size': 3.71, 'current_eval_count': 2800}
# 2800
# {'best_fitness': 81.21705426356588, 'mean_fitness': 40.43404042081949, 'best_base_fitness': 108.21705426356588, 'mean_base_fitness': 45.12154042081949, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 18.35, 'current_eval_count': 1900}
# 1900
# {'best_fitness': 90.3875968992248, 'mean_fitness': 32.127236434108525, 'best_base_fitness': 90.3875968992248, 'mean_base_fitness': 34.74973643410853, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 11.115, 'current_eval_count': 1700}
# 1700
# {'best_fitness': 109.34883720930233, 'mean_fitness': 31.858359357696568, 'best_base_fitness': 115.34883720930233, 'mean_base_fitness': 35.26085935769657, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 13.615, 'current_eval_count': 1700}
# 1700
# {'best_fitness': 78.7906976744186, 'mean_fitness': 31.703483942414177, 'best_base_fitness': 82.7906976744186, 'mean_base_fitness': 32.39348394241418, 'minimum_size': 1, 'maximum_size': 11, 'mean_size': 3.795, 'current_eval_count': 2900}
# 2900
# {'best_fitness': 68.81395348837209, 'mean_fitness': 20.73817441860465, 'best_base_fitness': 75.81395348837209, 'mean_base_fitness': 23.95567441860465, 'minimum_size': 1, 'maximum_size': 125, 'mean_size': 11.74, 'current_eval_count': 1800}
# 1800
# {'best_fitness': 113.34883720930233, 'mean_fitness': 38.09760409745294, 'best_base_fitness': 115.34883720930233, 'mean_base_fitness': 39.43010409745293, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 10.995, 'current_eval_count': 1600}
# 1600
# {'best_fitness': 88.29457364341086, 'mean_fitness': 54.3663488372093, 'best_base_fitness': 88.29457364341086, 'mean_base_fitness': 55.986348837209306, 'minimum_size': 1, 'maximum_size': 31, 'mean_size': 18.845, 'current_eval_count': 1900}
# 1900
# {'best_fitness': 104.1937984496124, 'mean_fitness': 32.02959357696567, 'best_base_fitness': 115.1937984496124, 'mean_base_fitness': 35.31459357696567, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 16.25, 'current_eval_count': 1700}
# 1700
# {'best_fitness': 117.59689922480621, 'mean_fitness': 18.734356035437433, 'best_base_fitness': 117.59689922480621, 'mean_base_fitness': 22.281856035437432, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 16.405, 'current_eval_count': 1600}
# 1600
# {'best_fitness': 78.7906976744186, 'mean_fitness': 32.11195736434109, 'best_base_fitness': 82.7906976744186, 'mean_base_fitness': 32.754457364341086, 'minimum_size': 1, 'maximum_size': 11, 'mean_size': 3.79, 'current_eval_count': 3000}
# 3000
# {'best_fitness': 90.48327796234774, 'mean_fitness': 33.36347508305648, 'best_base_fitness': 90.48327796234774, 'mean_base_fitness': 36.17347508305648, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 12.47, 'current_eval_count': 1800}
# 1800
# {'best_fitness': 109.34883720930233, 'mean_fitness': 33.774624031007754, 'best_base_fitness': 115.34883720930233, 'mean_base_fitness': 36.77712403100775, 'minimum_size': 1, 'maximum_size': 31, 'mean_size': 13.405, 'current_eval_count': 1800}
# 1800
# {'best_fitness': 81.21705426356588, 'mean_fitness': 39.46392857142857, 'best_base_fitness': 108.21705426356588, 'mean_base_fitness': 44.621428571428574, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 18.78, 'current_eval_count': 2000}
# 2000
# {'best_fitness': 78.7906976744186, 'mean_fitness': 32.348389258028796, 'best_base_fitness': 82.7906976744186, 'mean_base_fitness': 33.08588925802879, 'minimum_size': 1, 'maximum_size': 11, 'mean_size': 3.915, 'current_eval_count': 3100}
# 3100
# {'best_fitness': 68.81395348837209, 'mean_fitness': 22.030468438538207, 'best_base_fitness': 75.81395348837209, 'mean_base_fitness': 25.270468438538206, 'minimum_size': 1, 'maximum_size': 125, 'mean_size': 11.695, 'current_eval_count': 1900}
# 1900
# {'best_fitness': 99.92248062015504, 'mean_fitness': 38.666894241417495, 'best_base_fitness': 99.92248062015504, 'mean_base_fitness': 43.0543942414175, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 22.27, 'current_eval_count': 1500}
# 1500
# {'best_fitness': 113.34883720930233, 'mean_fitness': 42.58173643410853, 'best_base_fitness': 115.34883720930233, 'mean_base_fitness': 43.796736434108524, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 12.21, 'current_eval_count': 1700}
# 1700
# {'best_fitness': 102.17054263565892, 'mean_fitness': 56.33950664451827, 'best_base_fitness': 112.17054263565892, 'mean_base_fitness': 58.03700664451827, 'minimum_size': 1, 'maximum_size': 31, 'mean_size': 20.02, 'current_eval_count': 2000}
# 2000
# {'best_fitness': 116.96899224806202, 'mean_fitness': 38.51138316722038, 'best_base_fitness': 125.96899224806202, 'mean_base_fitness': 41.946383167220375, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 16.11, 'current_eval_count': 1800}
# 1800{'best_fitness': 82.74418604651163, 'mean_fitness': 31.638098560354376, 'best_base_fitness': 86.74418604651163, 'mean_base_fitness': 32.57809856035438, 'minimum_size': 1, 'maximum_size': 11, 'mean_size': 4.3, 'current_eval_count': 3200}
#
# 3200
# {'best_fitness': 122.56589147286822, 'mean_fitness': 32.55895016611296, 'best_base_fitness': 123.56589147286822, 'mean_base_fitness': 36.028950166112956, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 13.18, 'current_eval_count': 1900}
# 1900
# {'best_fitness': 109.34883720930233, 'mean_fitness': 35.03500166112957, 'best_base_fitness': 115.34883720930233, 'mean_base_fitness': 38.297501661129566, 'minimum_size': 1, 'maximum_size': 31, 'mean_size': 14.295, 'current_eval_count': 1900}
# 1900
# {'best_fitness': 81.21705426356588, 'mean_fitness': 39.46671483942414, 'best_base_fitness': 108.21705426356588, 'mean_base_fitness': 44.40421483942414, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 19.175, 'current_eval_count': 2100}
# 2100
# {'best_fitness': 117.59689922480621, 'mean_fitness': 20.196011627906977, 'best_base_fitness': 117.59689922480621, 'mean_base_fitness': 23.71351162790698, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 16.49, 'current_eval_count': 1700}
# 1700
# {'best_fitness': 91.3953488372093, 'mean_fitness': 36.017144518272424, 'best_base_fitness': 91.3953488372093, 'mean_base_fitness': 36.954644518272424, 'minimum_size': 1, 'maximum_size': 11, 'mean_size': 4.59, 'current_eval_count': 3300}
# 3300
# {'best_fitness': 68.81395348837209, 'mean_fitness': 21.82967607973422, 'best_base_fitness': 75.81395348837209, 'mean_base_fitness': 25.50217607973422, 'minimum_size': 1, 'maximum_size': 125, 'mean_size': 13.48, 'current_eval_count': 2000}
# 2000
# {'best_fitness': 91.3953488372093, 'mean_fitness': 37.73820044296789, 'best_base_fitness': 91.3953488372093, 'mean_base_fitness': 38.708200442967886, 'minimum_size': 1, 'maximum_size': 11, 'mean_size': 4.735, 'current_eval_count': 3400}
# 3400
# {'best_fitness': 122.56589147286822, 'mean_fitness': 34.76098449612403, 'best_base_fitness': 123.56589147286822, 'mean_base_fitness': 37.95098449612403, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 12.22, 'current_eval_count': 2000}
# 2000
# {'best_fitness': 81.21705426356588, 'mean_fitness': 35.52189700996678, 'best_base_fitness': 108.21705426356588, 'mean_base_fitness': 40.63189700996678, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 19.775, 'current_eval_count': 2200}
# 2200
# {'best_fitness': 109.34883720930233, 'mean_fitness': 39.450838870431895, 'best_base_fitness': 115.34883720930233, 'mean_base_fitness': 42.65833887043189, 'minimum_size': 1, 'maximum_size': 31, 'mean_size': 14.48, 'current_eval_count': 2000}
# 2000
# {'best_fitness': 113.34883720930233, 'mean_fitness': 43.19196788482835, 'best_base_fitness': 115.34883720930233, 'mean_base_fitness': 44.32196788482835, 'minimum_size': 1, 'maximum_size': 255, 'mean_size': 12.56, 'current_eval_count': 1800}
# 1800
# {'best_fitness': 102.17054263565892, 'mean_fitness': 64.48570321151716, 'best_base_fitness': 112.17054263565892, 'mean_base_fitness': 66.04070321151717, 'minimum_size': 1, 'maximum_size': 31, 'mean_size': 22.205, 'current_eval_count': 2100}
# 2100
# {'best_fitness': 117.59689922480621, 'mean_fitness': 19.36254872646733, 'best_base_fitness': 117.59689922480621, 'mean_base_fitness': 22.64004872646733, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 16.105, 'current_eval_count': 1800}
# 1800
# {'best_fitness': 116.96899224806202, 'mean_fitness': 40.705229789590256, 'best_base_fitness': 125.96899224806202, 'mean_base_fitness': 44.10772978959025, 'minimum_size': 1, 'maximum_size': 127, 'mean_size': 17.305, 'current_eval_count': 1900}
# 1900
# {'best_fitness': 91.3953488372093, 'mean_fitness': 41.1247519379845, 'best_base_fitness': 91.3953488372093, 'mean_base_fitness': 42.2047519379845, 'minimum_size': 1, 'maximum_size': 11, 'mean_size': 4.915, 'current_eval_count': 3500}
# 3500
# {'best_fitness': 68.81395348837209, 'mean_fitness': 24.345687707641197, 'best_base_fitness': 75.81395348837209, 'mean_base_fitness': 28.290687707641197, 'minimum_size': 1, 'maximum_size': 125, 'mean_size': 14.995, 'current_eval_count': 2100}
# 2100
# {'best_fitness': 99.92248062015504, 'mean_fitness': 40.48397785160576, 'best_base_fitness': 99.92248062015504, 'mean_base_fitness': 46.36397785160576, 'minimum_size': 1, 'maximum_size': 63, 'mean_size': 26.535, 'current_eval_count': 1600}
# 1600
# {'best_fitness': 107.59689922480621, 'mean_fitness': 40.432930786267995, 'best_base_fitness': 107.59689922480621, 'mean_base_fitness': 41.565430786267996, 'minimum_size': 1, 'maximum_size': 11, 'mean_size': 5.22, 'current_eval_count': 3600}
# 3600
# ...
# 4200
# {'best_fitness': 116.82170542635659, 'mean_fitness': 73.57869601328903, 'best_base_fitness': 116.82170542635659, 'mean_base_fitness': 73.60619601328904, 'minimum_size': 23, 'maximum_size': 29, 'mean_size': 26.985, 'current_eval_count': 4400}
# 4400
# {'best_fitness': 111.44429678848284, 'mean_fitness': 67.49772203765227, 'best_base_fitness': 114.44429678848284, 'mean_base_fitness': 71.04772203765226, 'minimum_size': 5, 'maximum_size': 63, 'mean_size': 40.38, 'current_eval_count': 4900}
# 4900
# {'best_fitness': 133.5736434108527, 'mean_fitness': 88.21371428571429, 'best_base_fitness': 134.5736434108527, 'mean_base_fitness': 88.77371428571429, 'minimum_size': 15, 'maximum_size': 21, 'mean_size': 18.175, 'current_eval_count': 4400}
# 4400
# {'best_fitness': 130.69767441860466, 'mean_fitness': 81.8184772978959, 'best_base_fitness': 130.69767441860466, 'mean_base_fitness': 82.9084772978959, 'minimum_size': 3, 'maximum_size': 19, 'mean_size': 11.255, 'current_eval_count': 4700}
# 4700
# {'best_fitness': 124.34883720930233, 'mean_fitness': 72.03528626799557, 'best_base_fitness': 125.34883720930233, 'mean_base_fitness': 76.23278626799556, 'minimum_size': 5, 'maximum_size': 61, 'mean_size': 23.59, 'current_eval_count': 3000}
# 3000
# {'best_fitness': 131.19623477297895, 'mean_fitness': 82.67024363233665, 'best_base_fitness': 132.19623477297895, 'mean_base_fitness': 85.27524363233665, 'minimum_size': 21, 'maximum_size': 27, 'mean_size': 24.545, 'current_eval_count': 4000}
# 4000
# {'best_fitness': 116.82170542635659, 'mean_fitness': 75.59392248062015, 'best_base_fitness': 116.82170542635659, 'mean_base_fitness': 75.62392248062015, 'minimum_size': 25, 'maximum_size': 29, 'mean_size': 26.99, 'current_eval_count': 4500}
# 4500
# {'best_fitness': 111.44429678848284, 'mean_fitness': 66.18784606866002, 'best_base_fitness': 114.44429678848284, 'mean_base_fitness': 70.92284606866002, 'minimum_size': 7, 'maximum_size': 63, 'mean_size': 40.135, 'current_eval_count': 5000}
# {'best_fitness': 134.5736434108527, 'mean_fitness': 88.8776511627907, 'best_base_fitness': 134.5736434108527, 'mean_base_fitness': 89.05765116279069, 'minimum_size': 3, 'maximum_size': 19, 'mean_size': 16.935, 'current_eval_count': 4300}
# 4300
# {'best_fitness': 130.69767441860466, 'mean_fitness': 82.84665227021041, 'best_base_fitness': 130.69767441860466, 'mean_base_fitness': 84.11165227021041, 'minimum_size': 3, 'maximum_size': 19, 'mean_size': 11.29, 'current_eval_count': 4800}
# 4800
# {'best_fitness': 133.5736434108527, 'mean_fitness': 90.40465946843854, 'best_base_fitness': 134.5736434108527, 'mean_base_fitness': 90.89215946843854, 'minimum_size': 15, 'maximum_size': 23, 'mean_size': 18.305, 'current_eval_count': 4500}
# 4500
# {'best_fitness': 131.19623477297895, 'mean_fitness': 84.4003211517165, 'best_base_fitness': 132.19623477297895, 'mean_base_fitness': 86.9003211517165, 'minimum_size': 23, 'maximum_size': 27, 'mean_size': 24.505, 'current_eval_count': 4100}
# 4100
# {'best_fitness': 116.82170542635659, 'mean_fitness': 73.66376190476191, 'best_base_fitness': 116.82170542635659, 'mean_base_fitness': 73.7087619047619, 'minimum_size': 25, 'maximum_size': 29, 'mean_size': 27, 'current_eval_count': 4600}
# 4600
# {'best_fitness': 130.69767441860466, 'mean_fitness': 83.47743410852713, 'best_base_fitness': 130.69767441860466, 'mean_base_fitness': 84.56243410852713, 'minimum_size': 5, 'maximum_size': 21, 'mean_size': 11.12, 'current_eval_count': 4900}
# 4900
# {'best_fitness': 126.12403100775194, 'mean_fitness': 73.06269712070875, 'best_base_fitness': 126.12403100775194, 'mean_base_fitness': 76.81019712070875, 'minimum_size': 5, 'maximum_size': 61, 'mean_size': 25.375, 'current_eval_count': 3100}
# 3100
# {'best_fitness': 137.37209302325581, 'mean_fitness': 92.75176688815061, 'best_base_fitness': 138.37209302325581, 'mean_base_fitness': 92.87926688815061, 'minimum_size': 13, 'maximum_size': 21, 'mean_size': 16.97, 'current_eval_count': 4400}
# 4400
# {'best_fitness': 133.5736434108527, 'mean_fitness': 90.50309413067552, 'best_base_fitness': 134.5736434108527, 'mean_base_fitness': 90.89809413067553, 'minimum_size': 15, 'maximum_size': 23, 'mean_size': 18.355, 'current_eval_count': 4600}
# 4600
# {'best_fitness': 130.69767441860466, 'mean_fitness': 84.31948892580287, 'best_base_fitness': 130.69767441860466, 'mean_base_fitness': 85.46698892580288, 'minimum_size': 5, 'maximum_size': 21, 'mean_size': 11.29, 'current_eval_count': 5000}
# {'best_fitness': 131.19623477297895, 'mean_fitness': 86.13979125138428, 'best_base_fitness': 132.19623477297895, 'mean_base_fitness': 88.75729125138427, 'minimum_size': 23, 'maximum_size': 27, 'mean_size': 24.59, 'current_eval_count': 4200}
# 4200
# {'best_fitness': 116.82170542635659, 'mean_fitness': 71.48934440753045, 'best_base_fitness': 116.82170542635659, 'mean_base_fitness': 71.53434440753045, 'minimum_size': 25, 'maximum_size': 29, 'mean_size': 27.005, 'current_eval_count': 4700}
# 4700
# {'best_fitness': 126.12403100775194, 'mean_fitness': 72.77145791805094, 'best_base_fitness': 126.12403100775194, 'mean_base_fitness': 76.28395791805094, 'minimum_size': 5, 'maximum_size': 61, 'mean_size': 23.475, 'current_eval_count': 3200}
# 3200
# {'best_fitness': 133.5736434108527, 'mean_fitness': 92.36882059800665, 'best_base_fitness': 134.5736434108527, 'mean_base_fitness': 92.65882059800664, 'minimum_size': 15, 'maximum_size': 19, 'mean_size': 18.305, 'current_eval_count': 4700}
# 4700
# {'best_fitness': 137.37209302325581, 'mean_fitness': 92.60007585825028, 'best_base_fitness': 138.37209302325581, 'mean_base_fitness': 92.71257585825028, 'minimum_size': 13, 'maximum_size': 19, 'mean_size': 16.86, 'current_eval_count': 4500}
# 4500
# {'best_fitness': 116.82170542635659, 'mean_fitness': 73.33971816168328, 'best_base_fitness': 116.82170542635659, 'mean_base_fitness': 73.37221816168328, 'minimum_size': 25, 'maximum_size': 29, 'mean_size': 27.015, 'current_eval_count': 4800}
# 4800
# {'best_fitness': 131.19623477297895, 'mean_fitness': 87.52022535991141, 'best_base_fitness': 132.19623477297895, 'mean_base_fitness': 90.26772535991141, 'minimum_size': 21, 'maximum_size': 27, 'mean_size': 24.64, 'current_eval_count': 4300}
# 4300
# {'best_fitness': 133.02325581395348, 'mean_fitness': 73.91804872646733, 'best_base_fitness': 133.02325581395348, 'mean_base_fitness': 77.12304872646733, 'minimum_size': 5, 'maximum_size': 61, 'mean_size': 22.325, 'current_eval_count': 3300}
# 3300
# {'best_fitness': 133.5736434108527, 'mean_fitness': 92.37985326688815, 'best_base_fitness': 134.5736434108527, 'mean_base_fitness': 92.60235326688814, 'minimum_size': 15, 'maximum_size': 19, 'mean_size': 18.25, 'current_eval_count': 4800}
# 4800
# {'best_fitness': 116.82170542635659, 'mean_fitness': 73.83416057585825, 'best_base_fitness': 116.82170542635659, 'mean_base_fitness': 73.84916057585825, 'minimum_size': 25, 'maximum_size': 29, 'mean_size': 27.015, 'current_eval_count': 4900}
# 4900
# {'best_fitness': 137.37209302325581, 'mean_fitness': 95.21521926910299, 'best_base_fitness': 138.37209302325581, 'mean_base_fitness': 95.33021926910298, 'minimum_size': 15, 'maximum_size': 21, 'mean_size': 16.895, 'current_eval_count': 4600}
# 4600
# {'best_fitness': 131.19623477297895, 'mean_fitness': 84.67549335548173, 'best_base_fitness': 132.19623477297895, 'mean_base_fitness': 87.44799335548173, 'minimum_size': 21, 'maximum_size': 27, 'mean_size': 24.745, 'current_eval_count': 4400}
# 4400
# {'best_fitness': 133.5736434108527, 'mean_fitness': 92.27281782945737, 'best_base_fitness': 134.5736434108527, 'mean_base_fitness': 92.51531782945736, 'minimum_size': 15, 'maximum_size': 21, 'mean_size': 18.285, 'current_eval_count': 4900}
# 4900
# {'best_fitness': 133.02325581395348, 'mean_fitness': 75.14248449612403, 'best_base_fitness': 133.02325581395348, 'mean_base_fitness': 78.45498449612403, 'minimum_size': 3, 'maximum_size': 61, 'mean_size': 21.655, 'current_eval_count': 3400}
# 3400
# {'best_fitness': 116.82170542635659, 'mean_fitness': 74.77196400885936, 'best_base_fitness': 116.82170542635659, 'mean_base_fitness': 74.78946400885935, 'minimum_size': 25, 'maximum_size': 29, 'mean_size': 27.005, 'current_eval_count': 5000}
# {'best_fitness': 137.37209302325581, 'mean_fitness': 95.42525581395348, 'best_base_fitness': 138.37209302325581, 'mean_base_fitness': 95.57525581395349, 'minimum_size': 15, 'maximum_size': 21, 'mean_size': 16.92, 'current_eval_count': 4700}
# 4700
# {'best_fitness': 131.19623477297895, 'mean_fitness': 83.06813012181617, 'best_base_fitness': 132.19623477297895, 'mean_base_fitness': 85.59563012181617, 'minimum_size': 23, 'maximum_size': 27, 'mean_size': 24.78, 'current_eval_count': 4500}
# 4500
# {'best_fitness': 139.14728682170542, 'mean_fitness': 93.58060243632336, 'best_base_fitness': 139.14728682170542, 'mean_base_fitness': 93.80560243632337, 'minimum_size': 15, 'maximum_size': 19, 'mean_size': 18.32, 'current_eval_count': 5000}
# {'best_fitness': 133.02325581395348, 'mean_fitness': 73.40853100775193, 'best_base_fitness': 133.02325581395348, 'mean_base_fitness': 76.06103100775194, 'minimum_size': 5, 'maximum_size': 61, 'mean_size': 19.9, 'current_eval_count': 3500}
# 3500
# {'best_fitness': 142.8, 'mean_fitness': 94.53297840531562, 'best_base_fitness': 142.8, 'mean_base_fitness': 94.69547840531561, 'minimum_size': 13, 'maximum_size': 23, 'mean_size': 16.87, 'current_eval_count': 4800}
# 4800
# {'best_fitness': 131.19623477297895, 'mean_fitness': 86.85051605758582, 'best_base_fitness': 132.19623477297895, 'mean_base_fitness': 89.36051605758583, 'minimum_size': 23, 'maximum_size': 27, 'mean_size': 24.845, 'current_eval_count': 4600}
# 4600
# {'best_fitness': 133.02325581395348, 'mean_fitness': 75.74827519379845, 'best_base_fitness': 133.02325581395348, 'mean_base_fitness': 79.02077519379844, 'minimum_size': 5, 'maximum_size': 61, 'mean_size': 20.2, 'current_eval_count': 3600}
# 3600
# {'best_fitness': 142.8, 'mean_fitness': 94.91194518272425, 'best_base_fitness': 142.8, 'mean_base_fitness': 95.09444518272426, 'minimum_size': 13, 'maximum_size': 23, 'mean_size': 16.845, 'current_eval_count': 4900}
# 4900
# {'best_fitness': 131.19623477297895, 'mean_fitness': 89.19634606866002, 'best_base_fitness': 132.19623477297895, 'mean_base_fitness': 91.65384606866002, 'minimum_size': 23, 'maximum_size': 27, 'mean_size': 24.915, 'current_eval_count': 4700}
# 4700
# {'best_fitness': 133.02325581395348, 'mean_fitness': 72.82549723145073, 'best_base_fitness': 133.02325581395348, 'mean_base_fitness': 75.83549723145072, 'minimum_size': 5, 'maximum_size': 61, 'mean_size': 21.24, 'current_eval_count': 3700}
# 3700
# {'best_fitness': 142.8, 'mean_fitness': 93.55887209302325, 'best_base_fitness': 142.8, 'mean_base_fitness': 93.79637209302325, 'minimum_size': 15, 'maximum_size': 21, 'mean_size': 16.875, 'current_eval_count': 5000}
# {'best_fitness': 131.19623477297895, 'mean_fitness': 89.53191085271318, 'best_base_fitness': 132.19623477297895, 'mean_base_fitness': 92.20441085271318, 'minimum_size': 23, 'maximum_size': 27, 'mean_size': 24.955, 'current_eval_count': 4800}
# 4800
# {'best_fitness': 133.02325581395348, 'mean_fitness': 72.97352380952381, 'best_base_fitness': 133.02325581395348, 'mean_base_fitness': 75.43852380952382, 'minimum_size': 5, 'maximum_size': 61, 'mean_size': 20.02, 'current_eval_count': 3800}
# 3800
#
# 4900
# {'best_fitness': 133.02325581395348, 'mean_fitness': 77.5207834994463, 'best_base_fitness': 133.02325581395348, 'mean_base_fitness': 79.7882834994463, 'minimum_size': 5, 'maximum_size': 61, 'mean_size': 20.895, 'current_eval_count': 3900}
# 3900
# {'best_fitness': 131.19623477297895, 'mean_fitness': 87.26602990033223, 'best_base_fitness': 132.19623477297895, 'mean_base_fitness': 89.80102990033222, 'minimum_size': 21, 'maximum_size': 27, 'mean_size': 25.04, 'current_eval_count': 5000}{'best_fitness': 133.02325581395348, 'mean_fitness': 74.86062513842747, 'best_base_fitness': 133.02325581395348, 'mean_base_fitness': 77.91812513842747, 'minimum_size': 5, 'maximum_size': 61, 'mean_size': 22.595, 'current_eval_count': 4000}
# 4000
# {'best_fitness': 133.02325581395348, 'mean_fitness': 74.17993355481728, 'best_base_fitness': 133.02325581395348, 'mean_base_fitness': 76.70493355481727, 'minimum_size': 5, 'maximum_size': 61, 'mean_size': 20.895, 'current_eval_count': 4100}
# 4100
# {'best_fitness': 133.02325581395348, 'mean_fitness': 73.50916112956811, 'best_base_fitness': 133.02325581395348, 'mean_base_fitness': 75.96666112956811, 'minimum_size': 5, 'maximum_size': 61, 'mean_size': 20.185, 'current_eval_count': 4200}
# 4200
# {'best_fitness': 133.02325581395348, 'mean_fitness': 74.79744407530454, 'best_base_fitness': 133.02325581395348, 'mean_base_fitness': 77.29244407530454, 'minimum_size': 5, 'maximum_size': 61, 'mean_size': 19.005, 'current_eval_count': 4300}
# 4300
# {'best_fitness': 133.02325581395348, 'mean_fitness': 80.9128992248062, 'best_base_fitness': 133.02325581395348, 'mean_base_fitness': 83.8728992248062, 'minimum_size': 5, 'maximum_size': 61, 'mean_size': 18.725, 'current_eval_count': 4400}
# 4400
# {'best_fitness': 133.02325581395348, 'mean_fitness': 81.34092912513843, 'best_base_fitness': 133.02325581395348, 'mean_base_fitness': 84.35092912513842, 'minimum_size': 5, 'maximum_size': 61, 'mean_size': 17.16, 'current_eval_count': 4500}
# 4500
# {'best_fitness': 133.02325581395348, 'mean_fitness': 83.31413122923588, 'best_base_fitness': 133.02325581395348, 'mean_base_fitness': 87.19663122923588, 'minimum_size': 5, 'maximum_size': 61, 'mean_size': 18.97, 'current_eval_count': 4600}
# 4600
# {'best_fitness': 133.02325581395348, 'mean_fitness': 86.80143300110743, 'best_base_fitness': 133.02325581395348, 'mean_base_fitness': 89.91143300110743, 'minimum_size': 5, 'maximum_size': 61, 'mean_size': 16.35, 'current_eval_count': 4700}
# 4700
# {'best_fitness': 133.02325581395348, 'mean_fitness': 88.56239645625692, 'best_base_fitness': 133.02325581395348, 'mean_base_fitness': 91.21739645625692, 'minimum_size': 5, 'maximum_size': 61, 'mean_size': 14.14, 'current_eval_count': 4800}
# 4800
# {'best_fitness': 133.02325581395348, 'mean_fitness': 89.35373643410853, 'best_base_fitness': 133.02325581395348, 'mean_base_fitness': 91.76873643410853, 'minimum_size': 3, 'maximum_size': 61, 'mean_size': 14.415, 'current_eval_count': 4900}
# 4900
# {'best_fitness': 133.02325581395348, 'mean_fitness': 88.91254706533776, 'best_base_fitness': 133.02325581395348, 'mean_base_fitness': 91.27254706533776, 'minimum_size': 5, 'maximum_size': 61, 'mean_size': 14.02, 'current_eval_count': 5000}
# Fitness: 130.69767441860466
# Base Fitness: 130.69767441860466
# Genes:
#  *
# |-
# ||+
# |||G
# |||G
# ||RAND
# |||W
# |||P
# |/
# ||RAND
# |||W
# |||G
# ||RAND
# |||1.61
# |||P
#
# Fitness: 142.8
# Base Fitness: 142.8
# Genes:
#  /
# |-
# ||*
# |||G
# |||/
# ||||G
# ||||P
# ||RAND
# |||G
# |||4.78
# |*
# ||P
# ||RAND
# |||P
# |||G
#
# Fitness: 139.14728682170542
# Base Fitness: 139.14728682170542
# Genes:
#  /
# |/
# ||/
# |||F
# |||+
# ||||/
# |||||-
# ||||||-1.33
# ||||||-2.44
# |||||+
# ||||||P
# ||||||F
# ||||/
# |||||F
# |||||P
# ||-2.06
# |RAND
# ||G
# ||P
#
# Fitness: 133.02325581395348
# Base Fitness: 133.02325581395348
# Genes:
#  /
# |RAND
# ||G
# ||3.18
# |+
# ||W
# ||P
#
# Fitness: 116.82170542635659
# Base Fitness: 116.82170542635659
# Genes:
#  -
# |RAND
# ||/
# |||RAND
# ||||-
# |||||P
# |||||-3.43
# ||||G
# |||P
# ||+
# |||P
# |||W
# |RAND
# ||P
# ||RAND
# |||/
# ||||-
# |||||-1.55
# |||||W
# ||||/
# |||||W
# |||||W
# |||RAND
# ||||W
# ||||/
# |||||P
# |||||F
#
# Fitness: 111.44429678848284
# Base Fitness: 114.44429678848284
# Genes:
#  /
# |RAND
# ||RAND
# |||P
# |||F
# ||+
# |||-0.94
# |||P
# |+
# ||-
# |||-3.01
# |||G
# ||-
# |||W
# |||G
#
# Fitness: 158.29457364341084
# Base Fitness: 158.29457364341084
# Genes:
#  /
# |+
# ||RAND
# |||+
# ||||F
# ||||F
# |||F
# ||/
# |||+
# ||||F
# ||||P
# |||G
# |-3.37
#
# Fitness: 131.19623477297895
# Base Fitness: 132.19623477297895
# Genes:
#  /
# |RAND
# ||G
# ||*
# |||RAND
# ||||-0.95
# ||||P
# |||-
# ||||-4.34
# ||||W
# |*
# ||+
# |||*
# ||||W
# ||||P
# |||+
# ||||P
# ||||W
# ||/
# |||+
# ||||*
# |||||W
# |||||P
# ||||F
# |||+
# ||||P
# ||||G
#
# Fitness: 121.02325581395348
# Base Fitness: 123.02325581395348
# Genes:
#  RAND
# |/
# ||G
# ||P
# |/
# ||2.76
# ||F
#
# Fitness: 117.59689922480621
# Base Fitness: 117.59689922480621
# Genes:
#  /
# |+
# ||G
# ||G
# |RAND
# ||W
# ||P

# %%
with open('data/2b/yellow/statistics.txt', 'r') as f:
    gp_data = [float(line) for line in f.readlines()]

print('2b Yellow data mean:', statistics.mean(gp_data))
print('2b Yellow data stdv:', statistics.stdev(gp_data))

# Reading the data from your 2b experiment
with open('data/2b/green/statistics.txt', 'r') as f:
    random_data = [float(line) for line in f.readlines()]

print('2b Green data mean:', statistics.mean(random_data))
print('2b Green data stdv:', statistics.stdev(random_data))

test_result = stats.ttest_ind(random_data, gp_data, equal_var=False)
print('p-value:', test_result.pvalue)
# Out:
# 2b Yellow data mean: 130.80451827242524
# 2b Yellow data stdv: 13.639129771828376
# 2b Green data mean: 126.27849390919158
# 2b Green data stdv: 20.483515865371682
# p-value: 0.5691097456742005

# %%
best_individual = None
for output in outputs:
    individual = output['best_individual']
    if best_individual == None:
        best_individual = individual
    elif individual.base_fitness > best_individual.base_fitness:
        best_individual = individual
best_log = best_individual.log

game_log_path = 'data/2b/yellow/'
with open(game_log_path + 'best_individual_genes.txt', 'w') as f:
    f.write(best_individual.to_string())
    
with open(game_log_path + 'best_individual_log.txt', 'w') as f:
    [f.write(f'{line}\n') for line in best_log]

print('The log of the most fit individual was written to', game_log_path)
# Out:
# The log of the most fit individual was written to data/2b/yellow/

# %%
'''
Store the y-values for mean fitness in average_penalized_means,
and the y-values for best fitness in average_penalized_maxes.
Do similar for average_base_means and average_base_maxes.
x-values should represent the number of **evaluations**, NOT **generations**.
Store the evaluation counts in the evals variable.
'''
def get_means_list(identifier):
    experiments_list_lists = []
    with open(f'data/2b/yellow/stairstep_data.txt', 'r') as f:
        content = f.readlines()[0]
        content = re.sub(r"(?<!\\)'", '"', content)
        content = json.loads(content)
        for i in range(len(content)):
            current_experiment_list = []
            for n in range(len(content[i])):
                current_experiment_list.append(content[i][n][identifier])
            experiments_list_lists.append(current_experiment_list)
            
        final_list = [0] * len(experiments_list_lists[0])
        for i in range(len(experiments_list_lists[0])):
            for n in range(0, len(content)):
                final_list[i] += experiments_list_lists[n][i]
            final_list[i] = final_list[i] / len(content)

    return final_list
    
average_penalized_means = get_means_list('mean_fitness')
average_penalized_maxes = get_means_list('best_fitness')
average_base_means = get_means_list('mean_base_fitness')
average_base_maxes = get_means_list('best_base_fitness')
average_size_mins = get_means_list('minimum_size')
average_size_maxes = get_means_list('maximum_size')
average_size_means = get_means_list('mean_size')

evals = [eval['current_eval_count'] for eval in outputs[0]['score_progression']]

fig, ax = plt.subplots()
ax.plot(evals, average_penalized_maxes, 'g-')
ax.plot(evals, average_penalized_means, 'g--')
ax.plot(evals, average_base_maxes, 'b-')
ax.plot(evals, average_base_means, 'b--')
ax.plot(evals, average_size_mins, 'r-')
ax.plot(evals, average_size_maxes, 'c-')
ax.plot(evals, average_size_means, 'm--')
ax.set(xlabel = 'Evaluations', ylabel = 'Value',\
       title = '2b Yellow Experiment: Evaluations vs Population Fitness Averaged Across 10 Runs')
ax.legend(['Max Penalized Fitness', 'Mean Penalized Fitness', 'Max Base Fitness', 'Mean Base Fitness', 'Mean Minimum Size', 'Mean Maximum Size', 'Average Mean Size'])
plt.show()

# %% [markdown]
# # RED Deliverables (Bonus)
# Bonus RED deliverables are typically somewhat open-ended, but this is particularly true in Assignment Series 2. As such, you may encounter unanticipated design decisions and obstacles that you should figure out how to overcome. TA assistance is available to answer questions, though you are expected to experiment and investigate solutions/answers prior to seeking this assistance. You are welcome to re-use tuned parameters between these experiments instead of conducting more rigorous tuning, though you may observe more interesting results with per-deliverable tuning.
#
# For each RED deliverable you attempt, **do not overwrite or break compatibility with your previous experimentation**: create a new notebook cell below, create a new config file, and implement the relevant section in the `base_population_evaluation` function.

# %% [markdown]
# # Side Note: Canonical Genetic Programming
# Should you apply GP after this class, you should know that the GP algorithm taught in this class (as described in the course textbook) differs somewhat from the algorithm canonically used in GP. Notably, the textbook has certain important omissions regarding the Ramped Half-and-half algorithm and the GP evolutionary cycle. In practice, the Ramped Half-and-half algorithm uses a `grow` method which ensures at least 1 branch reaches the depth limit. This can be difficult to implement, and has little impact on this assignment, so we don't require the implementation of the canonical version of the algorithm.
#
# More importantly, however, is that the canonical GP evolutionary cycle is generational in nature. In the canonical Generational GP algorithm, $\mu$ children are created each generation via recombination, mutation, or *reproduction* and the children directly replace the parents without survival selection. Notably, the reproduction operation involves directly copying the selected parent to the children pool and this enables behavior similar to the steady-state survival of a $(\mu + \lambda)$-EA. The algorithm you implement for this assignment series is much more similar to a Genetic Algorithm in nature and you should be aware of this distinction if you continue to work with GP. For more information, see [here](https://geneticprogramming.com/about-gp/gp-workflow/).
